# %%
import os
import numpy as np
import tensorflow as tf
import keras as ks
from tensorflow.python.keras.utils import np_utils

# %%
print(tf.keras.__version__)
print(ks.__version__)
# Out:
# 3.6.0
# 3.6.0

# %%
to_categorical = ks.utils.to_categorical
img_to_array = ks.preprocessing.image.img_to_array
load_img = ks.preprocessing.image.load_img

# %%
# Function to load original data and save as .npy files
def load_and_save_data(data_dir, img_shape=(80, 112), num_frames=60, save_path=''):
    X = []
    y = []

    # Collect unique word names from the dataset folder
    all_folders = [folder for folder in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, folder))]
    unique_words = set(folder.split('_')[0] for folder in all_folders)

    # Create a label dictionary
    label_dict = {word: idx for idx, word in enumerate(sorted(unique_words))}

    # Filter for only _1 and _11 folders for each word
    original_folders = [folder for folder in all_folders if folder.endswith('_1') or folder.endswith('_11')]

    # Load data from original folders
    for folder in original_folders:
        print(f"Processing folder: {folder}")  # Print statement to indicate the current folder being processed
        folder_path = os.path.join(data_dir, folder)
        frames = []
        for i in range(num_frames):
            img_path = os.path.join(folder_path, f"{i}.png")
            if os.path.exists(img_path):
                img = load_img(img_path, target_size=img_shape)
                img_array = img_to_array(img)
                frames.append(img_array)
            else:
                break
        if len(frames) == num_frames:
            X.append(np.stack(frames, axis=0))
            y.append(label_dict[folder.split('_')[0]])

    # Convert to numpy arrays and normalize X
    X = np.array(X) / 255.0  # Normalize images
    y = to_categorical(y, num_classes=len(label_dict))

    # Save X and y as .npy files
    np.save(os.path.join(save_path, 'X_data.npy'), X)
    np.save(os.path.join(save_path, 'y_data.npy'), y)

    print(f"Data saved successfully at {save_path} as 'X_data.npy' and 'y_data.npy'.")

    return X, y

base_dir = r'D:\PycharmProjects\pro_dis_2\collected_data\complete_datasets_crop_six'
save_path = r'D:\PycharmProjects\pro_dis_2\collected_data\npy_files_seven'

X, y = load_and_save_data(base_dir, save_path=save_path)
# Out:
# Processing folder: bat_1
# Processing folder: bat_11
# Processing folder: big_1
# Processing folder: big_11
# Processing folder: book_1
# Processing folder: book_11
# Processing folder: car_1
# Processing folder: car_11
# Processing folder: cat_1
# Processing folder: cat_11
# Processing folder: cup_1
# Processing folder: cup_11
# Processing folder: dog_1
# Processing folder: dog_11
# Processing folder: drop_1
# Processing folder: drop_11
# Processing folder: eat_1
# Processing folder: eat_11
# Processing folder: fast_1
# Processing folder: fast_11
# Processing folder: fish_1
# Processing folder: fish_11
# Processing folder: fun_1
# Processing folder: fun_11
# Processing folder: go_1
# Processing folder: go_11
# Processing folder: hat_1
# Processing folder: hat_11
# Processing folder: hot_1
# Processing folder: hot_11
# Processing folder: jump_1
# Processing folder: jump_11
# Processing folder: kick_1
# Processing folder: kick_11
# Processing folder: leg_1
# Processing folder: leg_11
# Processing folder: milk_1
# Processing folder: milk_11
# Processing folder: no_1
# Processing folder: no_11
# Processing folder: pen_1
# Processing folder: pen_11
# Processing folder: pick_1
# Processing folder: pick_11
# Processing folder: red_1
# Processing folder: red_11
# Processing folder: run_1
# Processing folder: run_11
# Processing folder: sit_1
# Processing folder: sit_11
# Processing folder: stop_1
# Processing folder: stop_11
# Processing folder: sun_1
# Processing folder: sun_11
# Processing folder: top_1
# Processing folder: top_11
# Processing folder: win_1
# Processing folder: win_11
# Processing folder: yes_1
# Processing folder: yes_11
# Data saved successfully at D:\PycharmProjects\pro_dis_2\collected_data\npy_files_seven as 'X_data.npy' and 'y_data.npy'.

# %%
# Function to load and save augmented data
def load_and_save_augmented_data(data_dir, suffixes, img_shape=(80, 112), num_frames=60, save_path=''):
    X = []
    y = []

    # Collect all folders matching the specified suffixes
    all_folders = [folder for folder in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, folder))]
    selected_folders = [folder for folder in all_folders if any(folder.endswith(f'_{suffix}') for suffix in suffixes)]

    # Create a label dictionary
    unique_words = set(folder.split('_')[0] for folder in selected_folders)
    label_dict = {word: idx for idx, word in enumerate(sorted(unique_words))}

    # Load data from the selected folders
    for folder in selected_folders:
        print(f"Processing folder: {folder}")  # Print statement to track progress
        folder_path = os.path.join(data_dir, folder)
        frames = []
        for i in range(num_frames):
            img_path = os.path.join(folder_path, f"{i}.png")
            if os.path.exists(img_path):
                img = load_img(img_path, target_size=img_shape)
                img_array = img_to_array(img)
                frames.append(img_array)
            else:
                break
        if len(frames) == num_frames:
            X.append(np.stack(frames, axis=0))
            y.append(label_dict[folder.split('_')[0]])

    # Convert to numpy arrays and normalize X
    X = np.array(X) / 255.0  # Normalize images
    y = to_categorical(y, num_classes=len(label_dict))

    # Save X and y as .npy files
    np.save(os.path.join(save_path, 'X_augmented_data.npy'), X)
    np.save(os.path.join(save_path, 'y_augmented_data.npy'), y)

    print(f"Augmented data saved successfully at {save_path} as 'X_augmented_data.npy' and 'y_augmented_data.npy'.")

# Specify the suffixes to include (_2 to _10)
suffixes = range(2, 11)  # _2 to _10
base_dir = r'D:\PycharmProjects\pro_dis_2\collected_data\complete_datasets_crop_six'
save_path = r'D:\PycharmProjects\pro_dis_2\collected_data\npy_files_seven'

# Run the function to save the data locally
load_and_save_augmented_data(base_dir, suffixes, save_path=save_path)
# Out:
# Processing folder: bat_10
# Processing folder: bat_2
# Processing folder: bat_3
# Processing folder: bat_4
# Processing folder: bat_5
# Processing folder: bat_6
# Processing folder: bat_7
# Processing folder: bat_8
# Processing folder: bat_9
# Processing folder: big_10
# Processing folder: big_2
# Processing folder: big_3
# Processing folder: big_4
# Processing folder: big_5
# Processing folder: big_6
# Processing folder: big_7
# Processing folder: big_8
# Processing folder: big_9
# Processing folder: book_10
# Processing folder: book_2
# Processing folder: book_3
# Processing folder: book_4
# Processing folder: book_5
# Processing folder: book_6
# Processing folder: book_7
# Processing folder: book_8
# Processing folder: book_9
# Processing folder: car_10
# Processing folder: car_2
# Processing folder: car_3
# Processing folder: car_4
# Processing folder: car_5
# Processing folder: car_6
# Processing folder: car_7
# Processing folder: car_8
# Processing folder: car_9
# Processing folder: cat_10
# Processing folder: cat_2
# Processing folder: cat_3
# Processing folder: cat_4
# Processing folder: cat_5
# Processing folder: cat_6
# Processing folder: cat_7
# Processing folder: cat_8
# Processing folder: cat_9
# Processing folder: cup_10
# Processing folder: cup_2
# Processing folder: cup_3
# Processing folder: cup_4
# Processing folder: cup_5
# Processing folder: cup_6
# Processing folder: cup_7
# Processing folder: cup_8
# Processing folder: cup_9
# Processing folder: dog_10
# Processing folder: dog_2
# Processing folder: dog_3
# Processing folder: dog_4
# Processing folder: dog_5
# Processing folder: dog_6
# Processing folder: dog_7
# Processing folder: dog_8
# Processing folder: dog_9
# Processing folder: drop_10
# Processing folder: drop_2
# Processing folder: drop_3
# Processing folder: drop_4
# Processing folder: drop_5
# Processing folder: drop_6
# Processing folder: drop_7
# Processing folder: drop_8
# Processing folder: drop_9
# Processing folder: eat_10
# Processing folder: eat_2
# Processing folder: eat_3
# Processing folder: eat_4
# Processing folder: eat_5
# Processing folder: eat_6
# Processing folder: eat_7
# Processing folder: eat_8
# Processing folder: eat_9
# Processing folder: fast_10
# Processing folder: fast_2
# Processing folder: fast_3
# Processing folder: fast_4
# Processing folder: fast_5
# Processing folder: fast_6
# Processing folder: fast_7
# Processing folder: fast_8
# Processing folder: fast_9
# Processing folder: fish_10
# Processing folder: fish_2
# Processing folder: fish_3
# Processing folder: fish_4
# Processing folder: fish_5
# Processing folder: fish_6
# Processing folder: fish_7
# Processing folder: fish_8
# Processing folder: fish_9
# Processing folder: fun_10
# Processing folder: fun_2
# Processing folder: fun_3
# Processing folder: fun_4
# Processing folder: fun_5
# Processing folder: fun_6
# Processing folder: fun_7
# Processing folder: fun_8
# Processing folder: fun_9
# Processing folder: go_10
# Processing folder: go_2
# Processing folder: go_3
# Processing folder: go_4
# Processing folder: go_5
# Processing folder: go_6
# Processing folder: go_7
# Processing folder: go_8
# Processing folder: go_9
# Processing folder: hat_10
# Processing folder: hat_2
# Processing folder: hat_3
# Processing folder: hat_4
# Processing folder: hat_5
# Processing folder: hat_6
# Processing folder: hat_7
# Processing folder: hat_8
# Processing folder: hat_9
# Processing folder: hot_10
# Processing folder: hot_2
# Processing folder: hot_3
# Processing folder: hot_4
# Processing folder: hot_5
# Processing folder: hot_6
# Processing folder: hot_7
# Processing folder: hot_8
# Processing folder: hot_9
# Processing folder: jump_10
# Processing folder: jump_2
# Processing folder: jump_3
# Processing folder: jump_4
# Processing folder: jump_5
# Processing folder: jump_6
# Processing folder: jump_7
# Processing folder: jump_8
# Processing folder: jump_9
# Processing folder: kick_10
# Processing folder: kick_2
# Processing folder: kick_3
# Processing folder: kick_4
# Processing folder: kick_5
# Processing folder: kick_6
# Processing folder: kick_7
# Processing folder: kick_8
# Processing folder: kick_9
# Processing folder: leg_10
# Processing folder: leg_2
# Processing folder: leg_3
# Processing folder: leg_4
# Processing folder: leg_5
# Processing folder: leg_6
# Processing folder: leg_7
# Processing folder: leg_8
# Processing folder: leg_9
# Processing folder: milk_10
# Processing folder: milk_2
# Processing folder: milk_3
# Processing folder: milk_4
# Processing folder: milk_5
# Processing folder: milk_6
# Processing folder: milk_7
# Processing folder: milk_8
# Processing folder: milk_9
# Processing folder: no_10
# Processing folder: no_2
# Processing folder: no_3
# Processing folder: no_4
# Processing folder: no_5
# Processing folder: no_6
# Processing folder: no_7
# Processing folder: no_8
# Processing folder: no_9
# Processing folder: pen_10
# Processing folder: pen_2
# Processing folder: pen_3
# Processing folder: pen_4
# Processing folder: pen_5
# Processing folder: pen_6
# Processing folder: pen_7
# Processing folder: pen_8
# Processing folder: pen_9
# Processing folder: pick_10
# Processing folder: pick_2
# Processing folder: pick_3
# Processing folder: pick_4
# Processing folder: pick_5
# Processing folder: pick_6
# Processing folder: pick_7
# Processing folder: pick_8
# Processing folder: pick_9
# Processing folder: red_10
# Processing folder: red_2
# Processing folder: red_3
# Processing folder: red_4
# Processing folder: red_5
# Processing folder: red_6
# Processing folder: red_7
# Processing folder: red_8
# Processing folder: red_9
# Processing folder: run_10
# Processing folder: run_2
# Processing folder: run_3
# Processing folder: run_4
# Processing folder: run_5
# Processing folder: run_6
# Processing folder: run_7
# Processing folder: run_8
# Processing folder: run_9
# Processing folder: sit_10
# Processing folder: sit_2
# Processing folder: sit_3
# Processing folder: sit_4
# Processing folder: sit_5
# Processing folder: sit_6
# Processing folder: sit_7
# Processing folder: sit_8
# Processing folder: sit_9
# Processing folder: stop_10
# Processing folder: stop_2
# Processing folder: stop_3
# Processing folder: stop_4
# Processing folder: stop_5
# Processing folder: stop_6
# Processing folder: stop_7
# Processing folder: stop_8
# Processing folder: stop_9
# Processing folder: sun_10
# Processing folder: sun_2
# Processing folder: sun_3
# Processing folder: sun_4
# Processing folder: sun_5
# Processing folder: sun_6
# Processing folder: sun_7
# Processing folder: sun_8
# Processing folder: sun_9
# Processing folder: top_10
# Processing folder: top_2
# Processing folder: top_3
# Processing folder: top_4
# Processing folder: top_5
# Processing folder: top_6
# Processing folder: top_7
# Processing folder: top_8
# Processing folder: top_9
# Processing folder: win_10
# Processing folder: win_2
# Processing folder: win_3
# Processing folder: win_4
# Processing folder: win_5
# Processing folder: win_6
# Processing folder: win_7
# Processing folder: win_8
# Processing folder: win_9
# Processing folder: yes_10
# Processing folder: yes_2
# Processing folder: yes_3
# Processing folder: yes_4
# Processing folder: yes_5
# Processing folder: yes_6
# Processing folder: yes_7
# Processing folder: yes_8
# Processing folder: yes_9
# Augmented data saved successfully at D:\PycharmProjects\pro_dis_2\collected_data\npy_files_seven as 'X_augmented_data.npy' and 'y_augmented_data.npy'.

# %%
# Function to load and save additional augmented data
def load_and_save_augmented_data(data_dir, suffixes, img_shape=(80, 112), num_frames=60, save_path=''):
    X = []
    y = []

    # Collect all folders matching the specified suffixes
    all_folders = [folder for folder in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, folder))]
    selected_folders = [folder for folder in all_folders if any(folder.endswith(f'_{suffix}') for suffix in suffixes)]

    # Create a label dictionary
    unique_words = set(folder.split('_')[0] for folder in selected_folders)
    label_dict = {word: idx for idx, word in enumerate(sorted(unique_words))}

    # Load data from the selected folders
    for folder in selected_folders:
        print(f"Processing folder: {folder}")  # Print statement to track progress
        folder_path = os.path.join(data_dir, folder)
        frames = []
        for i in range(num_frames):
            img_path = os.path.join(folder_path, f"{i}.png")
            if os.path.exists(img_path):
                img = load_img(img_path, target_size=img_shape)
                img_array = img_to_array(img)
                frames.append(img_array)
            else:
                break
        if len(frames) == num_frames:
            X.append(np.stack(frames, axis=0))
            y.append(label_dict[folder.split('_')[0]])

    # Convert to numpy arrays and normalize X
    X = np.array(X) / 255.0  # Normalize images
    y = to_categorical(y, num_classes=len(label_dict))

    # Save X and y as .npy files
    np.save(os.path.join(save_path, 'X_additional_augmented_data.npy'), X)
    np.save(os.path.join(save_path, 'y_additional_augmented_data.npy'), y)

    print(f"Additional augmented data saved successfully at {save_path} as 'X_additional_augmented_data.npy' and 'y_additional_augmented_data.npy'.")

# Specify the suffixes to include (_12 to _20)
suffixes = range(12, 21)  # _12 to _20
base_dir = r'D:\PycharmProjects\pro_dis_2\collected_data\complete_datasets_crop_six'
save_path = r'D:\PycharmProjects\pro_dis_2\collected_data\npy_files_seven'

# Run the function to save the data locally
load_and_save_augmented_data(base_dir, suffixes, save_path=save_path)
# Out:
# Processing folder: bat_12
# Processing folder: bat_13
# Processing folder: bat_14
# Processing folder: bat_15
# Processing folder: bat_16
# Processing folder: bat_17
# Processing folder: bat_18
# Processing folder: bat_19
# Processing folder: bat_20
# Processing folder: big_12
# Processing folder: big_13
# Processing folder: big_14
# Processing folder: big_15
# Processing folder: big_16
# Processing folder: big_17
# Processing folder: big_18
# Processing folder: big_19
# Processing folder: big_20
# Processing folder: book_12
# Processing folder: book_13
# Processing folder: book_14
# Processing folder: book_15
# Processing folder: book_16
# Processing folder: book_17
# Processing folder: book_18
# Processing folder: book_19
# Processing folder: book_20
# Processing folder: car_12
# Processing folder: car_13
# Processing folder: car_14
# Processing folder: car_15
# Processing folder: car_16
# Processing folder: car_17
# Processing folder: car_18
# Processing folder: car_19
# Processing folder: car_20
# Processing folder: cat_12
# Processing folder: cat_13
# Processing folder: cat_14
# Processing folder: cat_15
# Processing folder: cat_16
# Processing folder: cat_17
# Processing folder: cat_18
# Processing folder: cat_19
# Processing folder: cat_20
# Processing folder: cup_12
# Processing folder: cup_13
# Processing folder: cup_14
# Processing folder: cup_15
# Processing folder: cup_16
# Processing folder: cup_17
# Processing folder: cup_18
# Processing folder: cup_19
# Processing folder: cup_20
# Processing folder: dog_12
# Processing folder: dog_13
# Processing folder: dog_14
# Processing folder: dog_15
# Processing folder: dog_16
# Processing folder: dog_17
# Processing folder: dog_18
# Processing folder: dog_19
# Processing folder: dog_20
# Processing folder: drop_12
# Processing folder: drop_13
# Processing folder: drop_14
# Processing folder: drop_15
# Processing folder: drop_16
# Processing folder: drop_17
# Processing folder: drop_18
# Processing folder: drop_19
# Processing folder: drop_20
# Processing folder: eat_12
# Processing folder: eat_13
# Processing folder: eat_14
# Processing folder: eat_15
# Processing folder: eat_16
# Processing folder: eat_17
# Processing folder: eat_18
# Processing folder: eat_19
# Processing folder: eat_20
# Processing folder: fast_12
# Processing folder: fast_13
# Processing folder: fast_14
# Processing folder: fast_15
# Processing folder: fast_16
# Processing folder: fast_17
# Processing folder: fast_18
# Processing folder: fast_19
# Processing folder: fast_20
# Processing folder: fish_12
# Processing folder: fish_13
# Processing folder: fish_14
# Processing folder: fish_15
# Processing folder: fish_16
# Processing folder: fish_17
# Processing folder: fish_18
# Processing folder: fish_19
# Processing folder: fish_20
# Processing folder: fun_12
# Processing folder: fun_13
# Processing folder: fun_14
# Processing folder: fun_15
# Processing folder: fun_16
# Processing folder: fun_17
# Processing folder: fun_18
# Processing folder: fun_19
# Processing folder: fun_20
# Processing folder: go_12
# Processing folder: go_13
# Processing folder: go_14
# Processing folder: go_15
# Processing folder: go_16
# Processing folder: go_17
# Processing folder: go_18
# Processing folder: go_19
# Processing folder: go_20
# Processing folder: hat_12
# Processing folder: hat_13
# Processing folder: hat_14
# Processing folder: hat_15
# Processing folder: hat_16
# Processing folder: hat_17
# Processing folder: hat_18
# Processing folder: hat_19
# Processing folder: hat_20
# Processing folder: hot_12
# Processing folder: hot_13
# Processing folder: hot_14
# Processing folder: hot_15
# Processing folder: hot_16
# Processing folder: hot_17
# Processing folder: hot_18
# Processing folder: hot_19
# Processing folder: hot_20
# Processing folder: jump_12
# Processing folder: jump_13
# Processing folder: jump_14
# Processing folder: jump_15
# Processing folder: jump_16
# Processing folder: jump_17
# Processing folder: jump_18
# Processing folder: jump_19
# Processing folder: jump_20
# Processing folder: kick_12
# Processing folder: kick_13
# Processing folder: kick_14
# Processing folder: kick_15
# Processing folder: kick_16
# Processing folder: kick_17
# Processing folder: kick_18
# Processing folder: kick_19
# Processing folder: kick_20
# Processing folder: leg_12
# Processing folder: leg_13
# Processing folder: leg_14
# Processing folder: leg_15
# Processing folder: leg_16
# Processing folder: leg_17
# Processing folder: leg_18
# Processing folder: leg_19
# Processing folder: leg_20
# Processing folder: milk_12
# Processing folder: milk_13
# Processing folder: milk_14
# Processing folder: milk_15
# Processing folder: milk_16
# Processing folder: milk_17
# Processing folder: milk_18
# Processing folder: milk_19
# Processing folder: milk_20
# Processing folder: no_12
# Processing folder: no_13
# Processing folder: no_14
# Processing folder: no_15
# Processing folder: no_16
# Processing folder: no_17
# Processing folder: no_18
# Processing folder: no_19
# Processing folder: no_20
# Processing folder: pen_12
# Processing folder: pen_13
# Processing folder: pen_14
# Processing folder: pen_15
# Processing folder: pen_16
# Processing folder: pen_17
# Processing folder: pen_18
# Processing folder: pen_19
# Processing folder: pen_20
# Processing folder: pick_12
# Processing folder: pick_13
# Processing folder: pick_14
# Processing folder: pick_15
# Processing folder: pick_16
# Processing folder: pick_17
# Processing folder: pick_18
# Processing folder: pick_19
# Processing folder: pick_20
# Processing folder: red_12
# Processing folder: red_13
# Processing folder: red_14
# Processing folder: red_15
# Processing folder: red_16
# Processing folder: red_17
# Processing folder: red_18
# Processing folder: red_19
# Processing folder: red_20
# Processing folder: run_12
# Processing folder: run_13
# Processing folder: run_14
# Processing folder: run_15
# Processing folder: run_16
# Processing folder: run_17
# Processing folder: run_18
# Processing folder: run_19
# Processing folder: run_20
# Processing folder: sit_12
# Processing folder: sit_13
# Processing folder: sit_14
# Processing folder: sit_15
# Processing folder: sit_16
# Processing folder: sit_17
# Processing folder: sit_18
# Processing folder: sit_19
# Processing folder: sit_20
# Processing folder: stop_12
# Processing folder: stop_13
# Processing folder: stop_14
# Processing folder: stop_15
# Processing folder: stop_16
# Processing folder: stop_17
# Processing folder: stop_18
# Processing folder: stop_19
# Processing folder: stop_20
# Processing folder: sun_12
# Processing folder: sun_13
# Processing folder: sun_14
# Processing folder: sun_15
# Processing folder: sun_16
# Processing folder: sun_17
# Processing folder: sun_18
# Processing folder: sun_19
# Processing folder: sun_20
# Processing folder: top_12
# Processing folder: top_13
# Processing folder: top_14
# Processing folder: top_15
# Processing folder: top_16
# Processing folder: top_17
# Processing folder: top_18
# Processing folder: top_19
# Processing folder: top_20
# Processing folder: win_12
# Processing folder: win_13
# Processing folder: win_14
# Processing folder: win_15
# Processing folder: win_16
# Processing folder: win_17
# Processing folder: win_18
# Processing folder: win_19
# Processing folder: win_20
# Processing folder: yes_12
# Processing folder: yes_13
# Processing folder: yes_14
# Processing folder: yes_15
# Processing folder: yes_16
# Processing folder: yes_17
# Processing folder: yes_18
# Processing folder: yes_19
# Processing folder: yes_20
# Additional augmented data saved successfully at D:\PycharmProjects\pro_dis_2\collected_data\npy_files_seven as 'X_additional_augmented_data.npy' and 'y_additional_augmented_data.npy'.

# %%
import dlib
import cv2
import os
from imutils import face_utils
from PIL import Image
from concurrent.futures import ThreadPoolExecutor

# Initialize Dlib's face detector and shape predictor once in the main process
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

# Function to detect, crop, and resize the mouth region without compression
def crop_and_resize_mouth(image_path, output_path, output_size=(112, 112)):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = detector(gray)

    for face in faces:
        shape = predictor(gray, face)
        shape = face_utils.shape_to_np(shape)

        # Extract the mouth region (landmarks 48 to 67)
        (x, y, w, h) = cv2.boundingRect(shape[48:68])

        # Determine the center of the mouth region
        center_x = x + w // 2
        center_y = y + h // 2

        # Calculate the side length of the square to fit the mouth and surrounding context
        side_length = max(w, h) * 1.1  # Adjust this value to capture the desired area
        half_side = side_length // 2

        # Calculate new coordinates for the square crop
        new_x = max(0, int(center_x - half_side))
        new_y = max(0, int(center_y - half_side))
        new_w = min(image.shape[1] - new_x, int(side_length))
        new_h = min(image.shape[0] - new_y, int(side_length))

        # Crop the image with equal padding around the mouth region
        mouth_region = image[new_y:new_y + new_h, new_x:new_x + new_w]

        # Resize to 112x112 pixels without distortion
        resized_mouth = cv2.resize(mouth_region, output_size)

        # Convert to RGB format for saving with PIL
        resized_mouth_rgb = cv2.cvtColor(resized_mouth, cv2.COLOR_BGR2RGB)
        pil_image = Image.fromarray(resized_mouth_rgb)

        # Save as .png
        pil_image.save(output_path, format='PNG')

# Function to process all frames in a word folder
def process_word_folder(word_path, output_word_path, set_name, word_name):
    print(f"Processing set: {set_name}, word folder: {word_name}")  # Print progress message

    if not os.path.exists(output_word_path):
        os.makedirs(output_word_path, exist_ok=True)

    image_names = os.listdir(word_path)
    futures = []

    # Use ThreadPoolExecutor to process images in parallel within the word folder
    with ThreadPoolExecutor() as executor:
        for image_name in image_names:
            input_image_path = os.path.join(word_path, image_name)
            output_image_path = os.path.join(output_word_path, image_name)
            # Submit tasks to the executor
            futures.append(executor.submit(crop_and_resize_mouth, input_image_path, output_image_path))

        # Wait for all futures to complete to ensure completeness
        for future in futures:
            future.result()

# Main folder processing loop
input_folder = r'D:\PycharmProjects\pro_dis_2\collected_data\complete_datasets_not_crop_three'
output_folder = r'D:\PycharmProjects\pro_dis_2\collected_data\cropped_datasets_four'

for set_folder in os.listdir(input_folder):
    set_path = os.path.join(input_folder, set_folder)
    if os.path.isdir(set_path):
        for word_folder in os.listdir(set_path):
            word_path = os.path.join(set_path, word_folder)
            output_word_path = os.path.join(output_folder, set_folder, word_folder)
            # Print current set and word folder being processed
            process_word_folder(word_path, output_word_path, set_folder, word_folder)
# Out:
# Processing set: set_1, word folder: bat
# Processing set: set_1, word folder: big
# Processing set: set_1, word folder: book
# Processing set: set_1, word folder: car
# Processing set: set_1, word folder: cat
# Processing set: set_1, word folder: cup
# Processing set: set_1, word folder: dog
# Processing set: set_1, word folder: drop
# Processing set: set_1, word folder: eat
# Processing set: set_1, word folder: fast
# Processing set: set_1, word folder: fish
# Processing set: set_1, word folder: fun
# Processing set: set_1, word folder: go
# Processing set: set_1, word folder: hat
# Processing set: set_1, word folder: hot
# Processing set: set_1, word folder: jump
# Processing set: set_1, word folder: kick
# Processing set: set_1, word folder: leg
# Processing set: set_1, word folder: milk
# Processing set: set_1, word folder: no
# Processing set: set_1, word folder: pen
# Processing set: set_1, word folder: pick
# Processing set: set_1, word folder: red
# Processing set: set_1, word folder: run
# Processing set: set_1, word folder: sit
# Processing set: set_1, word folder: stop
# Processing set: set_1, word folder: sun
# Processing set: set_1, word folder: top
# Processing set: set_1, word folder: win
# Processing set: set_1, word folder: yes
# Processing set: set_10, word folder: bat
# Processing set: set_10, word folder: big
# Processing set: set_10, word folder: book
# Processing set: set_10, word folder: car
# Processing set: set_10, word folder: cat
# Processing set: set_10, word folder: cup
# Processing set: set_10, word folder: dog
# Processing set: set_10, word folder: drop
# Processing set: set_10, word folder: eat
# Processing set: set_10, word folder: fast
# Processing set: set_10, word folder: fish
# Processing set: set_10, word folder: fun
# Processing set: set_10, word folder: go
# Processing set: set_10, word folder: hat
# Processing set: set_10, word folder: hot
# Processing set: set_10, word folder: jump
# Processing set: set_10, word folder: kick
# Processing set: set_10, word folder: leg
# Processing set: set_10, word folder: milk
# Processing set: set_10, word folder: no
# Processing set: set_10, word folder: pen
# Processing set: set_10, word folder: pick
# Processing set: set_10, word folder: red
# Processing set: set_10, word folder: run
# Processing set: set_10, word folder: sit
# Processing set: set_10, word folder: stop
# Processing set: set_10, word folder: sun
# Processing set: set_10, word folder: top
# Processing set: set_10, word folder: win
# Processing set: set_10, word folder: yes
# Processing set: set_11, word folder: bat
# Processing set: set_11, word folder: big
# Processing set: set_11, word folder: book
# Processing set: set_11, word folder: car
# Processing set: set_11, word folder: cat
# Processing set: set_11, word folder: cup
# Processing set: set_11, word folder: dog
# Processing set: set_11, word folder: drop
# Processing set: set_11, word folder: eat
# Processing set: set_11, word folder: fast
# Processing set: set_11, word folder: fish
# Processing set: set_11, word folder: fun
# Processing set: set_11, word folder: go
# Processing set: set_11, word folder: hat
# Processing set: set_11, word folder: hot
# Processing set: set_11, word folder: jump
# Processing set: set_11, word folder: kick
# Processing set: set_11, word folder: leg
# Processing set: set_11, word folder: milk
# Processing set: set_11, word folder: no
# Processing set: set_11, word folder: pen
# Processing set: set_11, word folder: pick
# Processing set: set_11, word folder: red
# Processing set: set_11, word folder: run
# Processing set: set_11, word folder: sit
# Processing set: set_11, word folder: stop
# Processing set: set_11, word folder: sun
# Processing set: set_11, word folder: top
# Processing set: set_11, word folder: win
# Processing set: set_11, word folder: yes
# Processing set: set_12, word folder: bat
# Processing set: set_12, word folder: big
# Processing set: set_12, word folder: book
# Processing set: set_12, word folder: car
# Processing set: set_12, word folder: cat
# Processing set: set_12, word folder: cup
# Processing set: set_12, word folder: dog
# Processing set: set_12, word folder: drop
# Processing set: set_12, word folder: eat
# Processing set: set_12, word folder: fast
# Processing set: set_12, word folder: fish
# Processing set: set_12, word folder: fun
# Processing set: set_12, word folder: go
# Processing set: set_12, word folder: hat
# Processing set: set_12, word folder: hot
# Processing set: set_12, word folder: jump
# Processing set: set_12, word folder: kick
# Processing set: set_12, word folder: leg
# Processing set: set_12, word folder: milk
# Processing set: set_12, word folder: no
# Processing set: set_12, word folder: pen
# Processing set: set_12, word folder: pick
# Processing set: set_12, word folder: red
# Processing set: set_12, word folder: run
# Processing set: set_12, word folder: sit
# Processing set: set_12, word folder: stop
# Processing set: set_12, word folder: sun
# Processing set: set_12, word folder: top
# Processing set: set_12, word folder: win
# Processing set: set_12, word folder: yes
# Processing set: set_13, word folder: bat
# Processing set: set_13, word folder: big
# Processing set: set_13, word folder: book
# Processing set: set_13, word folder: car
# Processing set: set_13, word folder: cat
# Processing set: set_13, word folder: cup
# Processing set: set_13, word folder: dog
# Processing set: set_13, word folder: drop
# Processing set: set_13, word folder: eat
# Processing set: set_13, word folder: fast
# Processing set: set_13, word folder: fish
# Processing set: set_13, word folder: fun
# Processing set: set_13, word folder: go
# Processing set: set_13, word folder: hat
# Processing set: set_13, word folder: hot
# Processing set: set_13, word folder: jump
# Processing set: set_13, word folder: kick
# Processing set: set_13, word folder: leg
# Processing set: set_13, word folder: milk
# Processing set: set_13, word folder: no
# Processing set: set_13, word folder: pen
# Processing set: set_13, word folder: pick
# Processing set: set_13, word folder: red
# Processing set: set_13, word folder: run
# Processing set: set_13, word folder: sit
# Processing set: set_13, word folder: stop
# Processing set: set_13, word folder: sun
# Processing set: set_13, word folder: top
# Processing set: set_13, word folder: win
# Processing set: set_13, word folder: yes
# Processing set: set_14, word folder: bat
# Processing set: set_14, word folder: big
# Processing set: set_14, word folder: book
# Processing set: set_14, word folder: car
# Processing set: set_14, word folder: cat
# Processing set: set_14, word folder: cup
# Processing set: set_14, word folder: dog
# Processing set: set_14, word folder: drop
# Processing set: set_14, word folder: eat
# Processing set: set_14, word folder: fast
# Processing set: set_14, word folder: fish
# Processing set: set_14, word folder: fun
# Processing set: set_14, word folder: go
# Processing set: set_14, word folder: hat
# Processing set: set_14, word folder: hot
# Processing set: set_14, word folder: jump
# Processing set: set_14, word folder: kick
# Processing set: set_14, word folder: leg
# Processing set: set_14, word folder: milk
# Processing set: set_14, word folder: no
# Processing set: set_14, word folder: pen
# Processing set: set_14, word folder: pick
# Processing set: set_14, word folder: red
# Processing set: set_14, word folder: run
# Processing set: set_14, word folder: sit
# Processing set: set_14, word folder: stop
# Processing set: set_14, word folder: sun
# Processing set: set_14, word folder: top
# Processing set: set_14, word folder: win
# Processing set: set_14, word folder: yes
# Processing set: set_15, word folder: bat
# Processing set: set_15, word folder: big
# Processing set: set_15, word folder: book
# Processing set: set_15, word folder: car
# Processing set: set_15, word folder: cat
# Processing set: set_15, word folder: cup
# Processing set: set_15, word folder: dog
# Processing set: set_15, word folder: drop
# Processing set: set_15, word folder: eat
# Processing set: set_15, word folder: fast
# Processing set: set_15, word folder: fish
# Processing set: set_15, word folder: fun
# Processing set: set_15, word folder: go
# Processing set: set_15, word folder: hat
# Processing set: set_15, word folder: hot
# Processing set: set_15, word folder: jump
# Processing set: set_15, word folder: kick
# Processing set: set_15, word folder: leg
# Processing set: set_15, word folder: milk
# Processing set: set_15, word folder: no
# Processing set: set_15, word folder: pen
# Processing set: set_15, word folder: pick
# Processing set: set_15, word folder: red
# Processing set: set_15, word folder: run
# Processing set: set_15, word folder: sit
# Processing set: set_15, word folder: stop
# Processing set: set_15, word folder: sun
# Processing set: set_15, word folder: top
# Processing set: set_15, word folder: win
# Processing set: set_15, word folder: yes
# Processing set: set_16, word folder: bat
# Processing set: set_16, word folder: big
# Processing set: set_16, word folder: book
# Processing set: set_16, word folder: car
# Processing set: set_16, word folder: cat
# Processing set: set_16, word folder: cup
# Processing set: set_16, word folder: dog
# Processing set: set_16, word folder: drop
# Processing set: set_16, word folder: eat
# Processing set: set_16, word folder: fast
# Processing set: set_16, word folder: fish
# Processing set: set_16, word folder: fun
# Processing set: set_16, word folder: go
# Processing set: set_16, word folder: hat
# Processing set: set_16, word folder: hot
# Processing set: set_16, word folder: jump
# Processing set: set_16, word folder: kick
# Processing set: set_16, word folder: leg
# Processing set: set_16, word folder: milk
# Processing set: set_16, word folder: no
# Processing set: set_16, word folder: pen
# Processing set: set_16, word folder: pick
# Processing set: set_16, word folder: red
# Processing set: set_16, word folder: run
# Processing set: set_16, word folder: sit
# Processing set: set_16, word folder: stop
# Processing set: set_16, word folder: sun
# Processing set: set_16, word folder: top
# Processing set: set_16, word folder: win
# Processing set: set_16, word folder: yes
# Processing set: set_17, word folder: bat
# Processing set: set_17, word folder: big
# Processing set: set_17, word folder: book
# Processing set: set_17, word folder: car
# Processing set: set_17, word folder: cat
# Processing set: set_17, word folder: cup
# Processing set: set_17, word folder: dog
# Processing set: set_17, word folder: drop
# Processing set: set_17, word folder: eat
# Processing set: set_17, word folder: fast
# Processing set: set_17, word folder: fish
# Processing set: set_17, word folder: fun
# Processing set: set_17, word folder: go
# Processing set: set_17, word folder: hat
# Processing set: set_17, word folder: hot
# Processing set: set_17, word folder: jump
# Processing set: set_17, word folder: kick
# Processing set: set_17, word folder: leg
# Processing set: set_17, word folder: milk
# Processing set: set_17, word folder: no
# Processing set: set_17, word folder: pen
# Processing set: set_17, word folder: pick
# Processing set: set_17, word folder: red
# Processing set: set_17, word folder: run
# Processing set: set_17, word folder: sit
# Processing set: set_17, word folder: stop
# Processing set: set_17, word folder: sun
# Processing set: set_17, word folder: top
# Processing set: set_17, word folder: win
# Processing set: set_17, word folder: yes
# Processing set: set_18, word folder: bat
# Processing set: set_18, word folder: big
# Processing set: set_18, word folder: book
# Processing set: set_18, word folder: car
# Processing set: set_18, word folder: cat
# Processing set: set_18, word folder: cup
# Processing set: set_18, word folder: dog
# Processing set: set_18, word folder: drop
# Processing set: set_18, word folder: eat
# Processing set: set_18, word folder: fast
# Processing set: set_18, word folder: fish
# Processing set: set_18, word folder: fun
# Processing set: set_18, word folder: go
# Processing set: set_18, word folder: hat
# Processing set: set_18, word folder: hot
# Processing set: set_18, word folder: jump
# Processing set: set_18, word folder: kick
# Processing set: set_18, word folder: leg
# Processing set: set_18, word folder: milk
# Processing set: set_18, word folder: no
# Processing set: set_18, word folder: pen
# Processing set: set_18, word folder: pick
# Processing set: set_18, word folder: red
# Processing set: set_18, word folder: run
# Processing set: set_18, word folder: sit
# Processing set: set_18, word folder: stop
# Processing set: set_18, word folder: sun
# Processing set: set_18, word folder: top
# Processing set: set_18, word folder: win
# Processing set: set_18, word folder: yes
# Processing set: set_19, word folder: bat
# Processing set: set_19, word folder: big
# Processing set: set_19, word folder: book
# Processing set: set_19, word folder: car
# Processing set: set_19, word folder: cat
# Processing set: set_19, word folder: cup
# Processing set: set_19, word folder: dog
# Processing set: set_19, word folder: drop
# Processing set: set_19, word folder: eat
# Processing set: set_19, word folder: fast
# Processing set: set_19, word folder: fish
# Processing set: set_19, word folder: fun
# Processing set: set_19, word folder: go
# Processing set: set_19, word folder: hat
# Processing set: set_19, word folder: hot
# Processing set: set_19, word folder: jump
# Processing set: set_19, word folder: kick
# Processing set: set_19, word folder: leg
# Processing set: set_19, word folder: milk
# Processing set: set_19, word folder: no
# Processing set: set_19, word folder: pen
# Processing set: set_19, word folder: pick
# Processing set: set_19, word folder: red
# Processing set: set_19, word folder: run
# Processing set: set_19, word folder: sit
# Processing set: set_19, word folder: stop
# Processing set: set_19, word folder: sun
# Processing set: set_19, word folder: top
# Processing set: set_19, word folder: win
# Processing set: set_19, word folder: yes
# Processing set: set_2, word folder: bat
# Processing set: set_2, word folder: big
# Processing set: set_2, word folder: book
# Processing set: set_2, word folder: car
# Processing set: set_2, word folder: cat
# Processing set: set_2, word folder: cup
# Processing set: set_2, word folder: dog
# Processing set: set_2, word folder: drop
# Processing set: set_2, word folder: eat
# Processing set: set_2, word folder: fast
# Processing set: set_2, word folder: fish
# Processing set: set_2, word folder: fun
# Processing set: set_2, word folder: go
# Processing set: set_2, word folder: hat
# Processing set: set_2, word folder: hot
# Processing set: set_2, word folder: jump
# Processing set: set_2, word folder: kick
# Processing set: set_2, word folder: leg
# Processing set: set_2, word folder: milk
# Processing set: set_2, word folder: no
# Processing set: set_2, word folder: pen
# Processing set: set_2, word folder: pick
# Processing set: set_2, word folder: red
# Processing set: set_2, word folder: run
# Processing set: set_2, word folder: sit
# Processing set: set_2, word folder: stop
# Processing set: set_2, word folder: sun
# Processing set: set_2, word folder: top
# Processing set: set_2, word folder: win
# Processing set: set_2, word folder: yes
# Processing set: set_20, word folder: bat
# Processing set: set_20, word folder: big
# Processing set: set_20, word folder: book
# Processing set: set_20, word folder: car
# Processing set: set_20, word folder: cat
# Processing set: set_20, word folder: cup
# Processing set: set_20, word folder: dog
# Processing set: set_20, word folder: drop
# Processing set: set_20, word folder: eat
# Processing set: set_20, word folder: fast
# Processing set: set_20, word folder: fish
# Processing set: set_20, word folder: fun
# Processing set: set_20, word folder: go
# Processing set: set_20, word folder: hat
# Processing set: set_20, word folder: hot
# Processing set: set_20, word folder: jump
# Processing set: set_20, word folder: kick
# Processing set: set_20, word folder: leg
# Processing set: set_20, word folder: milk
# Processing set: set_20, word folder: no
# Processing set: set_20, word folder: pen
# Processing set: set_20, word folder: pick
# Processing set: set_20, word folder: red
# Processing set: set_20, word folder: run
# Processing set: set_20, word folder: sit
# Processing set: set_20, word folder: stop
# Processing set: set_20, word folder: sun
# Processing set: set_20, word folder: top
# Processing set: set_20, word folder: win
# Processing set: set_20, word folder: yes
# Processing set: set_3, word folder: bat
# Processing set: set_3, word folder: big
# Processing set: set_3, word folder: book
# Processing set: set_3, word folder: car
# Processing set: set_3, word folder: cat
# Processing set: set_3, word folder: cup
# Processing set: set_3, word folder: dog
# Processing set: set_3, word folder: drop
# Processing set: set_3, word folder: eat
# Processing set: set_3, word folder: fast
# Processing set: set_3, word folder: fish
# Processing set: set_3, word folder: fun
# Processing set: set_3, word folder: go
# Processing set: set_3, word folder: hat
# Processing set: set_3, word folder: hot
# Processing set: set_3, word folder: jump
# Processing set: set_3, word folder: kick
# Processing set: set_3, word folder: leg
# Processing set: set_3, word folder: milk
# Processing set: set_3, word folder: no
# Processing set: set_3, word folder: pen
# Processing set: set_3, word folder: pick
# Processing set: set_3, word folder: red
# Processing set: set_3, word folder: run
# Processing set: set_3, word folder: sit
# Processing set: set_3, word folder: stop
# Processing set: set_3, word folder: sun
# Processing set: set_3, word folder: top
# Processing set: set_3, word folder: win
# Processing set: set_3, word folder: yes
# Processing set: set_4, word folder: bat
# Processing set: set_4, word folder: big
# Processing set: set_4, word folder: book
# Processing set: set_4, word folder: car
# Processing set: set_4, word folder: cat
# Processing set: set_4, word folder: cup
# Processing set: set_4, word folder: dog
# Processing set: set_4, word folder: drop
# Processing set: set_4, word folder: eat
# Processing set: set_4, word folder: fast
# Processing set: set_4, word folder: fish
# Processing set: set_4, word folder: fun
# Processing set: set_4, word folder: go
# Processing set: set_4, word folder: hat
# Processing set: set_4, word folder: hot
# Processing set: set_4, word folder: jump
# Processing set: set_4, word folder: kick
# Processing set: set_4, word folder: leg
# Processing set: set_4, word folder: milk
# Processing set: set_4, word folder: no
# Processing set: set_4, word folder: pen
# Processing set: set_4, word folder: pick
# Processing set: set_4, word folder: red
# Processing set: set_4, word folder: run
# Processing set: set_4, word folder: sit
# Processing set: set_4, word folder: stop
# Processing set: set_4, word folder: sun
# Processing set: set_4, word folder: top
# Processing set: set_4, word folder: win
# Processing set: set_4, word folder: yes
# Processing set: set_5, word folder: bat
# Processing set: set_5, word folder: big
# Processing set: set_5, word folder: book
# Processing set: set_5, word folder: car
# Processing set: set_5, word folder: cat
# Processing set: set_5, word folder: cup
# Processing set: set_5, word folder: dog
# Processing set: set_5, word folder: drop
# Processing set: set_5, word folder: eat
# Processing set: set_5, word folder: fast
# Processing set: set_5, word folder: fish
# Processing set: set_5, word folder: fun
# Processing set: set_5, word folder: go
# Processing set: set_5, word folder: hat
# Processing set: set_5, word folder: hot
# Processing set: set_5, word folder: jump
# Processing set: set_5, word folder: kick
# Processing set: set_5, word folder: leg
# Processing set: set_5, word folder: milk
# Processing set: set_5, word folder: no
# Processing set: set_5, word folder: pen
# Processing set: set_5, word folder: pick
# Processing set: set_5, word folder: red
# Processing set: set_5, word folder: run
# Processing set: set_5, word folder: sit
# Processing set: set_5, word folder: stop
# Processing set: set_5, word folder: sun
# Processing set: set_5, word folder: top
# Processing set: set_5, word folder: win
# Processing set: set_5, word folder: yes
# Processing set: set_6, word folder: bat
# Processing set: set_6, word folder: big
# Processing set: set_6, word folder: book
# Processing set: set_6, word folder: car
# Processing set: set_6, word folder: cat
# Processing set: set_6, word folder: cup
# Processing set: set_6, word folder: dog
# Processing set: set_6, word folder: drop
# Processing set: set_6, word folder: eat
# Processing set: set_6, word folder: fast
# Processing set: set_6, word folder: fish
# Processing set: set_6, word folder: fun
# Processing set: set_6, word folder: go
# Processing set: set_6, word folder: hat
# Processing set: set_6, word folder: hot
# Processing set: set_6, word folder: jump
# Processing set: set_6, word folder: kick
# Processing set: set_6, word folder: leg
# Processing set: set_6, word folder: milk
# Processing set: set_6, word folder: no
# Processing set: set_6, word folder: pen
# Processing set: set_6, word folder: pick
# Processing set: set_6, word folder: red
# Processing set: set_6, word folder: run
# Processing set: set_6, word folder: sit
# Processing set: set_6, word folder: stop
# Processing set: set_6, word folder: sun
# Processing set: set_6, word folder: top
# Processing set: set_6, word folder: win
# Processing set: set_6, word folder: yes
# Processing set: set_7, word folder: bat
# Processing set: set_7, word folder: big
# Processing set: set_7, word folder: book
# Processing set: set_7, word folder: car
# Processing set: set_7, word folder: cat
# Processing set: set_7, word folder: cup
# Processing set: set_7, word folder: dog
# Processing set: set_7, word folder: drop
# Processing set: set_7, word folder: eat
# Processing set: set_7, word folder: fast
# Processing set: set_7, word folder: fish
# Processing set: set_7, word folder: fun
# Processing set: set_7, word folder: go
# Processing set: set_7, word folder: hat
# Processing set: set_7, word folder: hot
# Processing set: set_7, word folder: jump
# Processing set: set_7, word folder: kick
# Processing set: set_7, word folder: leg
# Processing set: set_7, word folder: milk
# Processing set: set_7, word folder: no
# Processing set: set_7, word folder: pen
# Processing set: set_7, word folder: pick
# Processing set: set_7, word folder: red
# Processing set: set_7, word folder: run
# Processing set: set_7, word folder: sit
# Processing set: set_7, word folder: stop
# Processing set: set_7, word folder: sun
# Processing set: set_7, word folder: top
# Processing set: set_7, word folder: win
# Processing set: set_7, word folder: yes
# Processing set: set_8, word folder: bat
# Processing set: set_8, word folder: big
# Processing set: set_8, word folder: book
# Processing set: set_8, word folder: car
# Processing set: set_8, word folder: cat
# Processing set: set_8, word folder: cup
# Processing set: set_8, word folder: dog
# Processing set: set_8, word folder: drop
# Processing set: set_8, word folder: eat
# Processing set: set_8, word folder: fast
# Processing set: set_8, word folder: fish
# Processing set: set_8, word folder: fun
# Processing set: set_8, word folder: go
# Processing set: set_8, word folder: hat
# Processing set: set_8, word folder: hot
# Processing set: set_8, word folder: jump
# Processing set: set_8, word folder: kick
# Processing set: set_8, word folder: leg
# Processing set: set_8, word folder: milk
# Processing set: set_8, word folder: no
# Processing set: set_8, word folder: pen
# Processing set: set_8, word folder: pick
# Processing set: set_8, word folder: red
# Processing set: set_8, word folder: run
# Processing set: set_8, word folder: sit
# Processing set: set_8, word folder: stop
# Processing set: set_8, word folder: sun
# Processing set: set_8, word folder: top
# Processing set: set_8, word folder: win
# Processing set: set_8, word folder: yes
# Processing set: set_9, word folder: bat
# Processing set: set_9, word folder: big
# Processing set: set_9, word folder: book
# Processing set: set_9, word folder: car
# Processing set: set_9, word folder: cat
# Processing set: set_9, word folder: cup
# Processing set: set_9, word folder: dog
# Processing set: set_9, word folder: drop
# Processing set: set_9, word folder: eat
# Processing set: set_9, word folder: fast
# Processing set: set_9, word folder: fish
# Processing set: set_9, word folder: fun
# Processing set: set_9, word folder: go
# Processing set: set_9, word folder: hat
# Processing set: set_9, word folder: hot
# Processing set: set_9, word folder: jump
# Processing set: set_9, word folder: kick
# Processing set: set_9, word folder: leg
# Processing set: set_9, word folder: milk
# Processing set: set_9, word folder: no
# Processing set: set_9, word folder: pen
# Processing set: set_9, word folder: pick
# Processing set: set_9, word folder: red
# Processing set: set_9, word folder: run
# Processing set: set_9, word folder: sit
# Processing set: set_9, word folder: stop
# Processing set: set_9, word folder: sun
# Processing set: set_9, word folder: top
# Processing set: set_9, word folder: win
# Processing set: set_9, word folder: yes
