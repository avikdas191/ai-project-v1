# %%
import os
import cv2
import shutil
import random
import numpy as np
import tensorflow as tf
from PIL import Image
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
print(tf.__version__)
ImageDataGenerator = tf.keras.preprocessing.image.ImageDataGenerator
img_to_array = tf.keras.preprocessing.image.img_to_array
array_to_img = tf.keras.preprocessing.image.array_to_img
# Out:
# 2.18.0

# %% [markdown]
# **raw video renamed and moved to project videos**

# %%
# Source and destination paths
source_folder = r'D:\PycharmProjects\pro_dis_2\collected_data\!test\set_70'
destination_folder = r'D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70'

# List of words for renaming
words = ["cup", "eat", "go", "hot", "sit"]

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)
    print(f"Created destination folder: {destination_folder}")

# Copy all video files from the source folder to the destination folder
video_files = [f for f in os.listdir(source_folder) if f.endswith('.mp4')]
for file in video_files:
    shutil.copy2(os.path.join(source_folder, file), destination_folder)
    print(f"Copied {file} to {destination_folder}")

# Get all video files in the copied folder
video_files = [f for f in os.listdir(destination_folder) if f.endswith('.mp4')]

# Create a list of tuples (file_name, date_modified)
video_files_with_date = [(file, os.path.getmtime(os.path.join(destination_folder, file))) for file in video_files]

# Sort files by date modified (earliest first)
video_files_with_date.sort(key=lambda x: x[1])

# Rename each file based on the words list
for i, (file, _) in enumerate(video_files_with_date):
    if i < len(words):
        new_name = f"{words[i]}.mp4"
        old_path = os.path.join(destination_folder, file)
        new_path = os.path.join(destination_folder, new_name)
        os.rename(old_path, new_path)
        print(f"Renamed {file} to {new_name}")
    else:
        print("Not enough words in the list to rename all video files.")
        break

print("\nAll videos are renamed and saved in project videos folder.")
# Out:
# Created destination folder: D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70
# Copied VID_20241119_091928.mp4 to D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70
# Copied VID_20241119_091933.mp4 to D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70
# Copied VID_20241119_091939.mp4 to D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70
# Copied VID_20241119_091944.mp4 to D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70
# Copied VID_20241119_091949.mp4 to D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70
# Renamed VID_20241119_091928.mp4 to cup.mp4
# Renamed VID_20241119_091933.mp4 to eat.mp4
# Renamed VID_20241119_091939.mp4 to go.mp4
# Renamed VID_20241119_091944.mp4 to hot.mp4
# Renamed VID_20241119_091949.mp4 to sit.mp4
#
# All videos are renamed and saved in project videos folder.

# %% [markdown]
# **frame extraction and save in set_01 and 01.png**

# %%
def extract_frame(frame, output_dir, frame_index):
    """
    Save a single frame as a .png image in the specified directory.
    Ensures complete image save before moving to the next frame.
    """
    frame_filename = os.path.join(output_dir, f"{frame_index:02d}.png")  # Format frame index with leading zeros
    cv2.imwrite(frame_filename, frame)
    return frame_filename

def extract_frames_with_priority_deletion(video_path, output_dir, target_frames=60):
    """
    Extract frames from the video, handling cases with more or fewer frames than the target.
    If the video has more frames, remove 20% from the start and 80% from the end.
    If the video has fewer frames, copy the last frame to fill the deficit.
    """
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    os.makedirs(output_dir, exist_ok=True)
    frames = []

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)

    # Handle case when the video has fewer than the target number of frames
    if total_frames < target_frames:
        # Save all existing frames
        for i in range(total_frames):
            extract_frame(frames[i], output_dir, i + 1)  # Start frame index from 1

        # Copy the last frame to fill the deficit until the target number is reached
        last_frame = frames[-1]
        for i in range(total_frames, target_frames):
            extract_frame(last_frame, output_dir, i + 1)

        print(f"Copied last frame to fill the deficit for {video_path}.")
        cap.release()
        return

    # Handle case when the video has more than the target number of frames
    if total_frames > target_frames:
        frames_to_delete = total_frames - target_frames
        delete_from_end = int(frames_to_delete * 0.8)  # 80% of frames to delete from the end
        delete_from_start = frames_to_delete - delete_from_end  # 20% from the start

        # Retain the middle portion after deleting the required frames
        frames = frames[delete_from_start:total_frames - delete_from_end]

    # Extract frames after deletion logic or for target-sized videos
    extracted_frame_count = 0

    with ThreadPoolExecutor() as executor:
        futures = []
        for i in range(len(frames)):
            future = executor.submit(extract_frame, frames[i], output_dir, extracted_frame_count + 1)
            futures.append(future)
            extracted_frame_count += 1

        for future in as_completed(futures):
            _ = future.result()

    cap.release()
    print(f"Extracted {extracted_frame_count} frames from {video_path}")

def process_multiple_video_folders(base_video_folder, output_base_folder):
    for i in range(61, 71):  # Loop to cover set_01 to set_50
        set_name = f"set_{i:02d}"  # Format set number with leading zeros (e.g., set_01, set_02)
        video_folder = os.path.join(base_video_folder, set_name)

        if not os.path.exists(video_folder):
            print(f"Skipping {video_folder} as it does not exist.")
            continue

        output_set_folder = os.path.join(output_base_folder, set_name)

        for video_file in os.listdir(video_folder):
            if video_file.endswith('.mp4'):
                video_path = os.path.join(video_folder, video_file)
                word_name = os.path.splitext(video_file)[0]
                word_output_dir = os.path.join(output_set_folder, word_name)
                print(f"Processing {video_file} in {set_name}...")
                extract_frames_with_priority_deletion(video_path, word_output_dir, target_frames=60)

# Base folder paths
base_video_folder = r'D:\PycharmProjects\pro_dis_2\collected_data\!test\videos'
output_base_folder = r'D:\PycharmProjects\pro_dis_2\collected_data\!test\extracted frames'

# Call the function
process_multiple_video_folders(base_video_folder, output_base_folder)

print("\nAll frames are extracted")
# Out:
# Processing cup.mp4 in set_61...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_61\cup.mp4
# Processing eat.mp4 in set_61...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_61\eat.mp4
# Processing go.mp4 in set_61...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_61\go.mp4
# Processing hot.mp4 in set_61...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_61\hot.mp4
# Processing sit.mp4 in set_61...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_61\sit.mp4
# Processing cup.mp4 in set_62...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_62\cup.mp4
# Processing eat.mp4 in set_62...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_62\eat.mp4
# Processing go.mp4 in set_62...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_62\go.mp4
# Processing hot.mp4 in set_62...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_62\hot.mp4
# Processing sit.mp4 in set_62...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_62\sit.mp4
# Processing cup.mp4 in set_63...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_63\cup.mp4
# Processing eat.mp4 in set_63...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_63\eat.mp4
# Processing go.mp4 in set_63...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_63\go.mp4
# Processing hot.mp4 in set_63...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_63\hot.mp4
# Processing sit.mp4 in set_63...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_63\sit.mp4
# Processing cup.mp4 in set_64...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_64\cup.mp4
# Processing eat.mp4 in set_64...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_64\eat.mp4
# Processing go.mp4 in set_64...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_64\go.mp4
# Processing hot.mp4 in set_64...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_64\hot.mp4
# Processing sit.mp4 in set_64...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_64\sit.mp4
# Processing cup.mp4 in set_65...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_65\cup.mp4
# Processing eat.mp4 in set_65...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_65\eat.mp4
# Processing go.mp4 in set_65...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_65\go.mp4
# Processing hot.mp4 in set_65...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_65\hot.mp4
# Processing sit.mp4 in set_65...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_65\sit.mp4
# Processing cup.mp4 in set_66...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_66\cup.mp4
# Processing eat.mp4 in set_66...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_66\eat.mp4
# Processing go.mp4 in set_66...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_66\go.mp4
# Processing hot.mp4 in set_66...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_66\hot.mp4
# Processing sit.mp4 in set_66...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_66\sit.mp4
# Processing cup.mp4 in set_67...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_67\cup.mp4
# Processing eat.mp4 in set_67...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_67\eat.mp4
# Processing go.mp4 in set_67...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_67\go.mp4
# Processing hot.mp4 in set_67...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_67\hot.mp4
# Processing sit.mp4 in set_67...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_67\sit.mp4
# Processing cup.mp4 in set_68...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_68\cup.mp4
# Processing eat.mp4 in set_68...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_68\eat.mp4
# Processing go.mp4 in set_68...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_68\go.mp4
# Processing hot.mp4 in set_68...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_68\hot.mp4
# Processing sit.mp4 in set_68...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_68\sit.mp4
# Processing cup.mp4 in set_69...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_69\cup.mp4
# Processing eat.mp4 in set_69...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_69\eat.mp4
# Processing go.mp4 in set_69...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_69\go.mp4
# Processing hot.mp4 in set_69...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_69\hot.mp4
# Processing sit.mp4 in set_69...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_69\sit.mp4
# Processing cup.mp4 in set_70...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70\cup.mp4
# Processing eat.mp4 in set_70...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70\eat.mp4
# Processing go.mp4 in set_70...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70\go.mp4
# Processing hot.mp4 in set_70...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70\hot.mp4
# Processing sit.mp4 in set_70...
# Extracted 60 frames from D:\PycharmProjects\pro_dis_2\collected_data\!test\videos\set_70\sit.mp4
#
# All frames are extracted

# %% [markdown]
# **original augmentation before cropping**

# %%
# Define source and output directories
source_dir = r'D:\PycharmProjects\pro_dis_2\collected_data\!source_27_11_night\1_extracted_frames_10w'
output_base_dir = r'D:\PycharmProjects\pro_dis_2\collected_data\2_new_augmented_datasets'

# ImageDataGenerator for basic augmentations
datagen = ImageDataGenerator(
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    # rotation_range=5,
    # zoom_range=[0.8, 1.2],
    # width_shift_range=0.1,
    # height_shift_range=0.1,
    # shear_range=0.2
)

# Function to apply noise to an image
def add_noise(image):
    row, col, ch = image.shape
    mean = 0
    sigma = 0.1
    gauss = np.random.normal(mean, sigma, (row, col, ch))
    noisy_image = np.clip(image + gauss * 255, 0, 255).astype(np.uint8)
    return noisy_image

# Function to downsample (simulate lower resolution)
def downsample_image(image, scale=0.5):
    h, w = image.shape[:2]
    image = cv2.resize(image, (int(w * scale), int(h * scale)))
    return cv2.resize(image, (w, h))

# Function to apply blur
def apply_blur(image, kernel_size=3):
    return cv2.GaussianBlur(image, (kernel_size, kernel_size), 0)

# Function to augment a single frame
def augment_frame(image_path, output_dir, frame_idx):
    img = cv2.imread(image_path)
    img = img_to_array(img)

    # Apply basic augmentations
    img = datagen.random_transform(img)

    # Additional augmentations
    if random.random() < 0.3:
        img = add_noise(img)
    if random.random() < 0.2:
        img = downsample_image(img)
    if random.random() < 0.2:
        img = apply_blur(img)

    # Convert to image format and save
    aug_img = array_to_img(img)
    aug_img.save(f"{output_dir}/{frame_idx:02d}.png")

# Function to process each frame folder
def process_frame_folder(source_word_dir, output_word_dir):
    frames = sorted(os.listdir(source_word_dir))
    num_frames = len(frames)

    # Process frames in parallel using ThreadPoolExecutor
    with ThreadPoolExecutor() as executor:
        futures = [
            executor.submit(augment_frame, os.path.join(source_word_dir, frame), output_word_dir, idx + 1)
            for idx, frame in enumerate(frames)
        ]

        # Ensure all frames are processed
        for future in as_completed(futures):
            future.result()

# Main loop to generate augmented datasets
set_folders = sorted(os.listdir(source_dir))

for set_folder in set_folders:
    set_path = os.path.join(source_dir, set_folder)
    if os.path.isdir(set_path):
        output_set_dir = os.path.join(output_base_dir, set_folder)
        os.makedirs(output_set_dir, exist_ok=True)

        # Process each word folder in the set
        word_folders = os.listdir(set_path)
        for word_folder in word_folders:
            source_word_dir = os.path.join(set_path, word_folder)
            output_word_dir = os.path.join(output_set_dir, word_folder)
            os.makedirs(output_word_dir, exist_ok=True)

            if os.path.isdir(source_word_dir):
                print(f"Processing {set_folder}/{word_folder}...")
                process_frame_folder(source_word_dir, output_word_dir)

print("\nAugmented datasets created successfully.")

# Validation step to check for 60 frames in each word folder
all_ok = True
for set_folder in os.listdir(output_base_dir):
    set_dir = os.path.join(output_base_dir, set_folder)
    for word_folder in os.listdir(set_dir):
        word_folder_path = os.path.join(set_dir, word_folder)
        if os.path.isdir(word_folder_path):
            frame_count = len(os.listdir(word_folder_path))
            if frame_count != 60:
                print(f"Warning: {set_folder}/{word_folder} has {frame_count} frames instead of 60.")
                all_ok = False

if all_ok:
    print("All sets and word folders have exactly 60 frames. Validation successful!")
# Out:
# Processing set_01/bat...
# Processing set_01/cup...
# Processing set_01/drop...
# Processing set_01/eat...
# Processing set_01/fish...
# Processing set_01/hot...
# Processing set_01/jump...
# Processing set_01/milk...
# Processing set_01/pen...
# Processing set_01/red...
# Processing set_02/bat...
# Processing set_02/cup...
# Processing set_02/drop...
# Processing set_02/eat...
# Processing set_02/fish...
# Processing set_02/hot...
# Processing set_02/jump...
# Processing set_02/milk...
# Processing set_02/pen...
# Processing set_02/red...
# Processing set_03/bat...
# Processing set_03/cup...
# Processing set_03/drop...
# Processing set_03/eat...
# Processing set_03/fish...
# Processing set_03/hot...
# Processing set_03/jump...
# Processing set_03/milk...
# Processing set_03/pen...
# Processing set_03/red...
# Processing set_04/bat...
# Processing set_04/cup...
# Processing set_04/drop...
# Processing set_04/eat...
# Processing set_04/fish...
# Processing set_04/hot...
# Processing set_04/jump...
# Processing set_04/milk...
# Processing set_04/pen...
# Processing set_04/red...
# Processing set_05/bat...
# Processing set_05/cup...
# Processing set_05/drop...
# Processing set_05/eat...
# Processing set_05/fish...
# Processing set_05/hot...
# Processing set_05/jump...
# Processing set_05/milk...
# Processing set_05/pen...
# Processing set_05/red...
# Processing set_06/bat...
# Processing set_06/cup...
# Processing set_06/drop...
# Processing set_06/eat...
# Processing set_06/fish...
# Processing set_06/hot...
# Processing set_06/jump...
# Processing set_06/milk...
# Processing set_06/pen...
# Processing set_06/red...
# Processing set_07/bat...
# Processing set_07/cup...
# Processing set_07/drop...
# Processing set_07/eat...
# Processing set_07/fish...
# Processing set_07/hot...
# Processing set_07/jump...
# Processing set_07/milk...
# Processing set_07/pen...
# Processing set_07/red...
# Processing set_08/bat...
# Processing set_08/cup...
# Processing set_08/drop...
# Processing set_08/eat...
# Processing set_08/fish...
# Processing set_08/hot...
# Processing set_08/jump...
# Processing set_08/milk...
# Processing set_08/pen...
# Processing set_08/red...
# Processing set_09/bat...
# Processing set_09/cup...
# Processing set_09/drop...
# Processing set_09/eat...
# Processing set_09/fish...
# Processing set_09/hot...
# Processing set_09/jump...
# Processing set_09/milk...
# Processing set_09/pen...
# Processing set_09/red...
# Processing set_10/bat...
# Processing set_10/cup...
# Processing set_10/drop...
# Processing set_10/eat...
# Processing set_10/fish...
# Processing set_10/hot...
# Processing set_10/jump...
# Processing set_10/milk...
# Processing set_10/pen...
# Processing set_10/red...
# Processing set_11/bat...
# Processing set_11/cup...
# Processing set_11/drop...
# Processing set_11/eat...
# Processing set_11/fish...
# Processing set_11/hot...
# Processing set_11/jump...
# Processing set_11/milk...
# Processing set_11/pen...
# Processing set_11/red...
# Processing set_12/bat...
# Processing set_12/cup...
# Processing set_12/drop...
# Processing set_12/eat...
# Processing set_12/fish...
# Processing set_12/hot...
# Processing set_12/jump...
# Processing set_12/milk...
# Processing set_12/pen...
# Processing set_12/red...
# Processing set_13/bat...
# Processing set_13/cup...
# Processing set_13/drop...
# Processing set_13/eat...
# Processing set_13/fish...
# Processing set_13/hot...
# Processing set_13/jump...
# Processing set_13/milk...
# Processing set_13/pen...
# Processing set_13/red...
# Processing set_14/bat...
# Processing set_14/cup...
# Processing set_14/drop...
# Processing set_14/eat...
# Processing set_14/fish...
# Processing set_14/hot...
# Processing set_14/jump...
# Processing set_14/milk...
# Processing set_14/pen...
# Processing set_14/red...
# Processing set_15/bat...
# Processing set_15/cup...
# Processing set_15/drop...
# Processing set_15/eat...
# Processing set_15/fish...
# Processing set_15/hot...
# Processing set_15/jump...
# Processing set_15/milk...
# Processing set_15/pen...
# Processing set_15/red...
# Processing set_16/bat...
# Processing set_16/cup...
# Processing set_16/drop...
# Processing set_16/eat...
# Processing set_16/fish...
# Processing set_16/hot...
# Processing set_16/jump...
# Processing set_16/milk...
# Processing set_16/pen...
# Processing set_16/red...
# Processing set_17/bat...
# Processing set_17/cup...
# Processing set_17/drop...
# Processing set_17/eat...
# Processing set_17/fish...
# Processing set_17/hot...
# Processing set_17/jump...
# Processing set_17/milk...
# Processing set_17/pen...
# Processing set_17/red...
# Processing set_18/bat...
# Processing set_18/cup...
# Processing set_18/drop...
# Processing set_18/eat...
# Processing set_18/fish...
# Processing set_18/hot...
# Processing set_18/jump...
# Processing set_18/milk...
# Processing set_18/pen...
# Processing set_18/red...
# Processing set_19/bat...
# Processing set_19/cup...
# Processing set_19/drop...
# Processing set_19/eat...
# Processing set_19/fish...
# Processing set_19/hot...
# Processing set_19/jump...
# Processing set_19/milk...
# Processing set_19/pen...
# Processing set_19/red...
# Processing set_20/bat...
# Processing set_20/cup...
# Processing set_20/drop...
# Processing set_20/eat...
# Processing set_20/fish...
# Processing set_20/hot...
# Processing set_20/jump...
# Processing set_20/milk...
# Processing set_20/pen...
# Processing set_20/red...
# Processing set_21/bat...
# Processing set_21/cup...
# Processing set_21/drop...
# Processing set_21/eat...
# Processing set_21/fish...
# Processing set_21/hot...
# Processing set_21/jump...
# Processing set_21/milk...
# Processing set_21/pen...
# Processing set_21/red...
# Processing set_22/bat...
# Processing set_22/cup...
# Processing set_22/drop...
# Processing set_22/eat...
# Processing set_22/fish...
# Processing set_22/hot...
# Processing set_22/jump...
# Processing set_22/milk...
# Processing set_22/pen...
# Processing set_22/red...
# Processing set_23/bat...
# Processing set_23/cup...
# Processing set_23/drop...
# Processing set_23/eat...
# Processing set_23/fish...
# Processing set_23/hot...
# Processing set_23/jump...
# Processing set_23/milk...
# Processing set_23/pen...
# Processing set_23/red...
# Processing set_24/bat...
# Processing set_24/cup...
# Processing set_24/drop...
# Processing set_24/eat...
# Processing set_24/fish...
# Processing set_24/hot...
# Processing set_24/jump...
# Processing set_24/milk...
# Processing set_24/pen...
# Processing set_24/red...
# Processing set_25/bat...
# Processing set_25/cup...
# Processing set_25/drop...
# Processing set_25/eat...
# Processing set_25/fish...
# Processing set_25/hot...
# Processing set_25/jump...
# Processing set_25/milk...
# Processing set_25/pen...
# Processing set_25/red...
# Processing set_26/bat...
# Processing set_26/cup...
# Processing set_26/drop...
# Processing set_26/eat...
# Processing set_26/fish...
# Processing set_26/hot...
# Processing set_26/jump...
# Processing set_26/milk...
# Processing set_26/pen...
# Processing set_26/red...
# Processing set_27/bat...
# Processing set_27/cup...
# Processing set_27/drop...
# Processing set_27/eat...
# Processing set_27/fish...
# Processing set_27/hot...
# Processing set_27/jump...
# Processing set_27/milk...
# Processing set_27/pen...
# Processing set_27/red...
# Processing set_28/bat...
# Processing set_28/cup...
# Processing set_28/drop...
# Processing set_28/eat...
# Processing set_28/fish...
# Processing set_28/hot...
# Processing set_28/jump...
# Processing set_28/milk...
# Processing set_28/pen...
# Processing set_28/red...
# Processing set_29/bat...
# Processing set_29/cup...
# Processing set_29/drop...
# Processing set_29/eat...
# Processing set_29/fish...
# Processing set_29/hot...
# Processing set_29/jump...
# Processing set_29/milk...
# Processing set_29/pen...
# Processing set_29/red...
# Processing set_30/bat...
# Processing set_30/cup...
# Processing set_30/drop...
# Processing set_30/eat...
# Processing set_30/fish...
# Processing set_30/hot...
# Processing set_30/jump...
# Processing set_30/milk...
# Processing set_30/pen...
# Processing set_30/red...
# Processing set_31/bat...
# Processing set_31/cup...
# Processing set_31/drop...
# Processing set_31/eat...
# Processing set_31/fish...
# Processing set_31/hot...
# Processing set_31/jump...
# Processing set_31/milk...
# Processing set_31/pen...
# Processing set_31/red...
# Processing set_32/bat...
# Processing set_32/cup...
# Processing set_32/drop...
# Processing set_32/eat...
# Processing set_32/fish...
# Processing set_32/hot...
# Processing set_32/jump...
# Processing set_32/milk...
# Processing set_32/pen...
# Processing set_32/red...
# Processing set_33/bat...
# Processing set_33/cup...
# Processing set_33/drop...
# Processing set_33/eat...
# Processing set_33/fish...
# Processing set_33/hot...
# Processing set_33/jump...
# Processing set_33/milk...
# Processing set_33/pen...
# Processing set_33/red...
# Processing set_34/bat...
# Processing set_34/cup...
# Processing set_34/drop...
# Processing set_34/eat...
# Processing set_34/fish...
# Processing set_34/hot...
# Processing set_34/jump...
# Processing set_34/milk...
# Processing set_34/pen...
# Processing set_34/red...
# Processing set_35/bat...
# Processing set_35/cup...
# Processing set_35/drop...
# Processing set_35/eat...
# Processing set_35/fish...
# Processing set_35/hot...
# Processing set_35/jump...
# Processing set_35/milk...
# Processing set_35/pen...
# Processing set_35/red...
# Processing set_36/bat...
# Processing set_36/cup...
# Processing set_36/drop...
# Processing set_36/eat...
# Processing set_36/fish...
# Processing set_36/hot...
# Processing set_36/jump...
# Processing set_36/milk...
# Processing set_36/pen...
# Processing set_36/red...
# Processing set_37/bat...
# Processing set_37/cup...
# Processing set_37/drop...
# Processing set_37/eat...
# Processing set_37/fish...
# Processing set_37/hot...
# Processing set_37/jump...
# Processing set_37/milk...
# Processing set_37/pen...
# Processing set_37/red...
# Processing set_38/bat...
# Processing set_38/cup...
# Processing set_38/drop...
# Processing set_38/eat...
# Processing set_38/fish...
# Processing set_38/hot...
# Processing set_38/jump...
# Processing set_38/milk...
# Processing set_38/pen...
# Processing set_38/red...
# Processing set_39/bat...
# Processing set_39/cup...
# Processing set_39/drop...
# Processing set_39/eat...
# Processing set_39/fish...
# Processing set_39/hot...
# Processing set_39/jump...
# Processing set_39/milk...
# Processing set_39/pen...
# Processing set_39/red...
# Processing set_40/bat...
# Processing set_40/cup...
# Processing set_40/drop...
# Processing set_40/eat...
# Processing set_40/fish...
# Processing set_40/hot...
# Processing set_40/jump...
# Processing set_40/milk...
# Processing set_40/pen...
# Processing set_40/red...
# Processing set_41/bat...
# Processing set_41/cup...
# Processing set_41/drop...
# Processing set_41/eat...
# Processing set_41/fish...
# Processing set_41/hot...
# Processing set_41/jump...
# Processing set_41/milk...
# Processing set_41/pen...
# Processing set_41/red...
# Processing set_42/bat...
# Processing set_42/cup...
# Processing set_42/drop...
# Processing set_42/eat...
# Processing set_42/fish...
# Processing set_42/hot...
# Processing set_42/jump...
# Processing set_42/milk...
# Processing set_42/pen...
# Processing set_42/red...
# Processing set_43/bat...
# Processing set_43/cup...
# Processing set_43/drop...
# Processing set_43/eat...
# Processing set_43/fish...
# Processing set_43/hot...
# Processing set_43/jump...
# Processing set_43/milk...
# Processing set_43/pen...
# Processing set_43/red...
# Processing set_44/bat...
# Processing set_44/cup...
# Processing set_44/drop...
# Processing set_44/eat...
# Processing set_44/fish...
# Processing set_44/hot...
# Processing set_44/jump...
# Processing set_44/milk...
# Processing set_44/pen...
# Processing set_44/red...
# Processing set_45/bat...
# Processing set_45/cup...
# Processing set_45/drop...
# Processing set_45/eat...
# Processing set_45/fish...
# Processing set_45/hot...
# Processing set_45/jump...
# Processing set_45/milk...
# Processing set_45/pen...
# Processing set_45/red...
# Processing set_46/bat...
# Processing set_46/cup...
# Processing set_46/drop...
# Processing set_46/eat...
# Processing set_46/fish...
# Processing set_46/hot...
# Processing set_46/jump...
# Processing set_46/milk...
# Processing set_46/pen...
# Processing set_46/red...
# Processing set_47/bat...
# Processing set_47/cup...
# Processing set_47/drop...
# Processing set_47/eat...
# Processing set_47/fish...
# Processing set_47/hot...
# Processing set_47/jump...
# Processing set_47/milk...
# Processing set_47/pen...
# Processing set_47/red...
# Processing set_48/bat...
# Processing set_48/cup...
# Processing set_48/drop...
# Processing set_48/eat...
# Processing set_48/fish...
# Processing set_48/hot...
# Processing set_48/jump...
# Processing set_48/milk...
# Processing set_48/pen...
# Processing set_48/red...
# Processing set_49/bat...
# Processing set_49/cup...
# Processing set_49/drop...
# Processing set_49/eat...
# Processing set_49/fish...
# Processing set_49/hot...
# Processing set_49/jump...
# Processing set_49/milk...
# Processing set_49/pen...
# Processing set_49/red...
# Processing set_50/bat...
# Processing set_50/cup...
# Processing set_50/drop...
# Processing set_50/eat...
# Processing set_50/fish...
# Processing set_50/hot...
# Processing set_50/jump...
# Processing set_50/milk...
# Processing set_50/pen...
# Processing set_50/red...
# Processing set_51/bat...
# Processing set_51/cup...
# Processing set_51/drop...
# Processing set_51/eat...
# Processing set_51/fish...
# Processing set_51/hot...
# Processing set_51/jump...
# Processing set_51/milk...
# Processing set_51/pen...
# Processing set_51/red...
# Processing set_52/bat...
# Processing set_52/cup...
# Processing set_52/drop...
# Processing set_52/eat...
# Processing set_52/fish...
# Processing set_52/hot...
# Processing set_52/jump...
# Processing set_52/milk...
# Processing set_52/pen...
# Processing set_52/red...
# Processing set_53/bat...
# Processing set_53/cup...
# Processing set_53/drop...
# Processing set_53/eat...
# Processing set_53/fish...
# Processing set_53/hot...
# Processing set_53/jump...
# Processing set_53/milk...
# Processing set_53/pen...
# Processing set_53/red...
# Processing set_54/bat...
# Processing set_54/cup...
# Processing set_54/drop...
# Processing set_54/eat...
# Processing set_54/fish...
# Processing set_54/hot...
# Processing set_54/jump...
# Processing set_54/milk...
# Processing set_54/pen...
# Processing set_54/red...
# Processing set_55/bat...
# Processing set_55/cup...
# Processing set_55/drop...
# Processing set_55/eat...
# Processing set_55/fish...
# Processing set_55/hot...
# Processing set_55/jump...
# Processing set_55/milk...
# Processing set_55/pen...
# Processing set_55/red...
# Processing set_56/bat...
# Processing set_56/cup...
# Processing set_56/drop...
# Processing set_56/eat...
# Processing set_56/fish...
# Processing set_56/hot...
# Processing set_56/jump...
# Processing set_56/milk...
# Processing set_56/pen...
# Processing set_56/red...
# Processing set_57/bat...
# Processing set_57/cup...
# Processing set_57/drop...
# Processing set_57/eat...
# Processing set_57/fish...
# Processing set_57/hot...
# Processing set_57/jump...
# Processing set_57/milk...
# Processing set_57/pen...
# Processing set_57/red...
# Processing set_58/bat...
# Processing set_58/cup...
# Processing set_58/drop...
# Processing set_58/eat...
# Processing set_58/fish...
# Processing set_58/hot...
# Processing set_58/jump...
# Processing set_58/milk...
# Processing set_58/pen...
# Processing set_58/red...
# Processing set_59/bat...
# Processing set_59/cup...
# Processing set_59/drop...
# Processing set_59/eat...
# Processing set_59/fish...
# Processing set_59/hot...
# Processing set_59/jump...
# Processing set_59/milk...
# Processing set_59/pen...
# Processing set_59/red...
# Processing set_60/bat...
# Processing set_60/cup...
# Processing set_60/drop...
# Processing set_60/eat...
# Processing set_60/fish...
# Processing set_60/hot...
# Processing set_60/jump...
# Processing set_60/milk...
# Processing set_60/pen...
# Processing set_60/red...
#
# Augmented datasets created successfully.
# All sets and word folders have exactly 60 frames. Validation successful!

# %% [markdown]
# **run crop_lip.py**

# %% [markdown]
# **3rd try augmentation after cropping - used in final - it is a different augmentation. Shouldn't apply any other before this.**

# %%
import os
import cv2
import numpy as np
import random
from collections import defaultdict
from concurrent.futures import ThreadPoolExecutor, as_completed
from albumentations import Compose, HorizontalFlip, RandomBrightnessContrast, Rotate, Affine, GaussianBlur, GaussNoise, RGBShift, OpticalDistortion, Perspective, Equalize

# Source and destination directories
source_dir = r"E:\1_cropped_frames"
destination_dir = r"E:\2_augmented_frames"
os.makedirs(destination_dir, exist_ok=True)

# Target size for resizing images
TARGET_SIZE = (112, 80)  # (Width, Height)

# Albumentations augmentations
def get_augmentations(augmentation_type):
    """Return augmentation pipeline based on the specified type."""
    augmentations = {
        "HorizontalFlip": Compose([HorizontalFlip(p=1.0)]),
        "Brightness": Compose([RandomBrightnessContrast(
            brightness_limit=(0.3, 0.3), contrast_limit=0.0, p=1.0)]),
        "Contrast": Compose([RandomBrightnessContrast(
            brightness_limit=0.0, contrast_limit=(0.3, 0.3), p=1.0)]),
        "Rotate": Compose([Rotate(limit=5, p=1.0)]),
        "Translate": Compose([Affine(translate_px={"x": (-10, 10), "y": (-10, 10)}, p=1.0)]),
        "Scale": Compose([Affine(scale=(0.9, 1.1), p=1.0)]),
        "GaussianBlur": Compose([GaussianBlur(blur_limit=(7, 15), p=1.0)]),
        "GaussNoise": Compose([GaussNoise(var_limit=(100.0, 250.0), p=1.0)]),
        "RGBShift": Compose([RGBShift(r_shift_limit=50, g_shift_limit=50, b_shift_limit=50, p=1.0)]),
        "OpticalDistortion": Compose([OpticalDistortion(distort_limit=0.2, shift_limit=0.2, p=1.0)]),
        "Perspective": Compose([Perspective(scale=(0.05, 0.1), p=1.0)]),
        "Equalize": Compose([Equalize(p=1.0)])
    }
    return augmentations.get(augmentation_type)

# Custom augmentations
def downsample_image(image, scale=0.5):
    """Downsample and restore the image to simulate lower resolution."""
    h, w = image.shape[:2]
    image = cv2.resize(image, (int(w * scale), int(h * scale)))
    return cv2.resize(image, (w, h))

def sharpen_image(image):
    """Apply sharpening to the image."""
    kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
    return cv2.filter2D(image, -1, kernel)

def temporal_shift(frames):
    """Shift frames temporally by a random offset."""
    shift_amount = random.randint(-2, 2)
    return np.roll(frames, shift_amount, axis=0)

def process_cropped_image(cropped_image):
    """Process cropped image with LAB adjustment, CLAHE, blurring, and sharpening."""
    lab_image = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2LAB)
    l_channel, a_channel, b_channel = cv2.split(lab_image)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(3, 3))
    l_channel_eq = clahe.apply(l_channel)
    lab_image_eq = cv2.merge((l_channel_eq, a_channel, b_channel))
    bgr_image_eq = cv2.cvtColor(lab_image_eq, cv2.COLOR_LAB2BGR)
    blurred_image = cv2.GaussianBlur(bgr_image_eq, (7, 7), 0)
    edge_preserved_image = cv2.bilateralFilter(blurred_image, d=5, sigmaColor=75, sigmaSpace=75)
    sharpening_kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    sharpened_image = cv2.filter2D(edge_preserved_image, -1, sharpening_kernel)
    final_image = cv2.GaussianBlur(sharpened_image, (5, 5), 0)
    return final_image

# Resizing function
def resize_with_interpolation(image, target_size):
    """Resize image with appropriate interpolation based on size."""
    original_h, original_w = image.shape[:2]
    target_w, target_h = target_size

    # Check if resizing is necessary
    if (original_h, original_w) == (target_h, target_w):
        return image  # No resizing needed

    # Determine interpolation method
    if original_h > target_h or original_w > target_w:  # Downscaling
        interpolation = cv2.INTER_AREA
    else:  # Upscaling
        interpolation = cv2.INTER_LINEAR

    return cv2.resize(image, (target_w, target_h), interpolation=interpolation)

# Function to augment an image
def augment_image(image, augmentation_type):
    """Apply augmentation based on the type."""
    if augmentation_type in [
        "HorizontalFlip", "Brightness", "Contrast", "Rotate", "Translate", "Scale",
        "GaussianBlur", "GaussNoise", "RGBShift", "OpticalDistortion", "Perspective", "Equalize"
    ]:
        augmentation_pipeline = get_augmentations(augmentation_type)
        augmented = augmentation_pipeline(image=image)['image']
        return augmented
    elif augmentation_type == "Downsample":
        return downsample_image(image)
    elif augmentation_type == "Sharpen":
        return sharpen_image(image)
    elif augmentation_type == "TemporalShift":
        return image  # Temporal shift requires frame-level logic
    elif augmentation_type == "ProcessCroppedImage":
        return process_cropped_image(image)
    else:
        raise ValueError(f"Unknown augmentation type: {augmentation_type}")

# Process a single word folder using ThreadPoolExecutor
def process_word_folder(word_path, output_word_path, augmentation_type):
    """Process all frames in a word folder with parallel execution."""
    os.makedirs(output_word_path, exist_ok=True)
    image_files = sorted([f for f in os.listdir(word_path) if f.endswith('.png')])

    def process_frame(image_path, output_path):
        """Process a single frame."""
        image = cv2.imread(image_path)
        augmented_image = augment_image(image, augmentation_type)
        resized_image = resize_with_interpolation(augmented_image, TARGET_SIZE)
        cv2.imwrite(output_path, resized_image)

    with ThreadPoolExecutor() as executor:
        futures = [
            executor.submit(process_frame, os.path.join(word_path, image_file), os.path.join(output_word_path, f"{idx:02d}.png"))
            for idx, image_file in enumerate(image_files, start=1)
        ]
        for future in as_completed(futures):
            future.result()  # Ensure all frames are processed without error

    # Print progress for this word folder
    print(f"Finished processing '{os.path.basename(word_path)}' in '{os.path.basename(output_word_path)}'. Images processed -> {len(image_files)}")

# Process a single set folder
def process_set_folder(set_path, output_set_path, augmentation_type):
    """Process all word folders in a set folder sequentially."""
    word_folders = sorted([f for f in os.listdir(set_path) if os.path.isdir(os.path.join(set_path, f))])
    for word_folder in word_folders:
        word_path = os.path.join(set_path, word_folder)
        output_word_path = os.path.join(output_set_path, word_folder)
        process_word_folder(word_path, output_word_path, augmentation_type)

# Main function
def main():
    """Main driver function."""
    set_folders = sorted([f for f in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, f))])
    augmentations = [
        "HorizontalFlip", "Brightness", "Contrast", "Rotate", "Translate", "Scale",
        "GaussianBlur", "GaussNoise", "RGBShift", "OpticalDistortion", "Perspective",
        "Equalize", "Downsample", "Sharpen", "TemporalShift", "ProcessCroppedImage"
    ]

    total_augmented_sets = 940
    source_usage = {set_name: 0 for set_name in set_folders}  # Initialize usage with all sets
    augmentation_usage = defaultdict(int)  # Track augmentation usage

    augmentation_cycle = augmentations[:]  # Create a fresh copy of augmentations
    random.shuffle(augmentation_cycle)

    for idx in range(1, total_augmented_sets + 1):
        # Ensure all augmentations are used once before repeating
        if not augmentation_cycle:
            augmentation_cycle = augmentations[:]
            random.shuffle(augmentation_cycle)

        augmentation_type = augmentation_cycle.pop()  # Get augmentation type
        augmentation_usage[augmentation_type] += 1  # Increment augmentation usage

        # Find source set with the least usage
        min_usage = min(source_usage.values())
        least_used_sets = [s for s in set_folders if source_usage[s] == min_usage]
        selected_set = random.choice(least_used_sets)
        source_usage[selected_set] += 1  # Increment usage count

        set_path = os.path.join(source_dir, selected_set)
        output_set_path = os.path.join(destination_dir, f"set_{idx:03d}")
        os.makedirs(output_set_path, exist_ok=True)

        # Process the set folder
        process_set_folder(set_path, output_set_path, augmentation_type)

        # Print progress with augmentation and usage details
        print(
            f"\nSet folder '{selected_set}' used for set_{idx:03d}. Current usage: {source_usage[selected_set]}. "
            f"Augmentation used: '{augmentation_type}' ({augmentation_usage[augmentation_type]} times so far).\n"
        )

    # Final summary
    print("\nSource Set Usage Summary:")
    for set_name, usage in sorted(source_usage.items()):
        print(f"Source set '{set_name}' used {usage} times.")

    print("\nAugmentation Usage Summary:")
    for aug_name, usage in sorted(augmentation_usage.items()):
        print(f"Augmentation '{aug_name}' applied {usage} times.")

if __name__ == "__main__":
    main()

# %% [markdown]
# **(optional) image processing sharpen + 5% brightness & contrast**

# %%
import os
import cv2
import numpy as np
from albumentations import Compose, RandomBrightnessContrast

# Function for sharpening the image
def sharpen_image(image):
    """Apply sharpening to the image."""
    kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
    return cv2.filter2D(image, -1, kernel)

# Albumentations pipeline for brightness and contrast adjustment
def get_brightness_contrast_augmentation():
    """
    Returns a pipeline to adjust brightness and contrast without probability.
    """
    return Compose([
        RandomBrightnessContrast(
            brightness_limit=(0.05, 0.05),  # Fixed Brightness adjustment range: +5%
            contrast_limit=(0.05, 0.05),    # Fixed Contrast adjustment range: +5%
            p=1.0                         # Always apply
        )
    ])

# Unified function to apply sharpening and brightness/contrast adjustment
def process_extracted_frames(input_folder, output_folder):
    """
    Applies sharpening and brightness/contrast adjustment to all images in a folder.
    :param input_folder: Path to the folder containing images.
    :param output_folder: Path to save the processed images.
    """
    os.makedirs(output_folder, exist_ok=True)

    # Get the brightness/contrast augmentation pipeline
    augmentation_pipeline = get_brightness_contrast_augmentation()

    for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith(".png"):
            input_path = os.path.join(input_folder, file_name)
            output_path = os.path.join(output_folder, file_name)

            # Read the image
            image = cv2.imread(input_path)
            if image is None:
                print(f"Error reading image: {input_path}")
                continue

            # Step 1: Apply sharpening
            sharpened_image = sharpen_image(image)

            # Step 2: Apply brightness and contrast adjustment
            augmented = augmentation_pipeline(image=sharpened_image)
            final_image = augmented['image']

            # Save the processed image
            cv2.imwrite(output_path, final_image)
            print(f"Processed {file_name} with sharpening and brightness/contrast adjustment.")

# Main function
def main():
    # Define input and output directories
    input_folder = r"D:\PycharmProjects\pro_dis_2\collected_test_data\extracted_frames"
    output_folder = r"D:\PycharmProjects\pro_dis_2\collected_test_data\final_frames_with_sharpening_brightness_contrast"

    # Apply combined processing
    print("Starting processing of images...")
    process_extracted_frames(input_folder, output_folder)
    print("Processing completed. All images are saved in the output folder.")

# Run the main function
if __name__ == "__main__":
    main()

# %% [markdown]
# **combined image saving and renaming**

# %%
def combine_images(word_path, output_set_path, word_folder_name, set_number):
    # List all frame files and sort them to maintain order
    frame_files = [f for f in os.listdir(word_path) if f.endswith('.png')]
    frame_files.sort()  # Ensure the frames are in order

    # Check that there are exactly 60 frames
    if len(frame_files) != 60:
        print(f"Warning: {word_path} does not contain exactly 60 frames. Skipping.")
        return

    # Load the first image to get dimensions
    first_image = cv2.imread(os.path.join(word_path, frame_files[0]))
    if first_image is None:
        print(f"Error: Could not read {frame_files[0]}.")
        return

    img_height, img_width, channels = first_image.shape

    # Create an empty array for the combined image (10 rows × 6 columns)
    combined_image = np.zeros((img_height * 10, img_width * 6, channels), dtype=np.uint8)

    # Place each frame into the correct position in the combined image
    for idx, frame_file in enumerate(frame_files):
        img = cv2.imread(os.path.join(word_path, frame_file))
        if img is None:
            print(f"Error: Could not read {frame_file}.")
            continue

        row = idx // 6
        col = idx % 6

        # Place the image in the combined image array
        combined_image[row * img_height:(row + 1) * img_height, col * img_width:(col + 1) * img_width] = img

    # Save the combined image with the set number and word name as the file name
    os.makedirs(output_set_path, exist_ok=True)
    combined_image_path = os.path.join(output_set_path, f'{set_number}_{word_folder_name}.png')
    cv2.imwrite(combined_image_path, combined_image)

    print(f"Combined image saved at: {combined_image_path}")

def process_all_word_folders(input_base_path, output_base_path):
    # Create the base output directory if it does not exist
    os.makedirs(output_base_path, exist_ok=True)

    # Loop through each set folder (e.g., set_01, set_02, ..., set_20)
    for set_folder in os.listdir(input_base_path):
        set_path = os.path.join(input_base_path, set_folder)
        if os.path.isdir(set_path):
            # Extract the set number from the folder name (e.g., '01' from 'set_01')
            set_number = set_folder.split('_')[-1]
            output_set_path = os.path.join(output_base_path, set_folder)
            os.makedirs(output_set_path, exist_ok=True)

            # Loop through each word folder inside the set folder
            for word_folder in os.listdir(set_path):
                word_path = os.path.join(set_path, word_folder)
                if os.path.isdir(word_path):
                    combine_images(word_path, output_set_path, word_folder, set_number)

# Define input and output base paths
input_base_path = r'C:\Users\avikd\Videos\project_videos\original_dataset_DLib_cropped_frames'
output_base_path = r'C:\Users\avikd\Videos\project_videos\original_dataset_single_images'

# Run the processing function
process_all_word_folders(input_base_path, output_base_path)

print("\nAll frames are combined and renamed")
# Out:
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_bat.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_big.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_book.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_car.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_cat.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_cup.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_dog.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_drop.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_eat.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_fast.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_fish.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_fun.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_go.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_hat.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_hot.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_jump.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_kick.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_leg.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_milk.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_no.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_pen.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_pick.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_red.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_run.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_sit.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_stop.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_sun.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_top.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_win.png
# Combined image saved at: C:\Users\avikd\Videos\project_videos\original_dataset_single_images\set_01\01_yes.png
#
# All frames are combined and renamed

# %% [markdown]
# **copying all the same word images to same word folder**

# %%
# Define the source directory
final_dataset1_dir = r'E:\!special\4_resized_augmented_100'
# Define the destination directory
final_dataset2_dir = r'E:\!special\5_orgnsd_augmented_100'

words = ['bat', 'cup', 'drop', 'eat', 'fish', 'hot', 'jump', 'milk', 'pen', 'red']

# Create final_datasets2 and its subfolders
os.makedirs(final_dataset2_dir, exist_ok=True)
for word in words:
    word_folder_path = os.path.join(final_dataset2_dir, word)
    os.makedirs(word_folder_path, exist_ok=True)
print(f"Created {final_dataset2_dir} with subfolders for each word.")

# Iterate through each set folder in final_datasets1 and copy images to final_datasets2
set_folders = [f for f in os.listdir(final_dataset1_dir) if os.path.isdir(os.path.join(final_dataset1_dir, f))]

for set_folder in set_folders:
    set_path = os.path.join(final_dataset1_dir, set_folder)
    for file_name in os.listdir(set_path):
        if file_name.endswith('.png'):  # Only process .png files
            # Extract the word name and prefix (e.g., '01' from '01_word1.png')
            prefix = file_name.split('_', 1)[0]  # Get the '01' portion
            base_name = file_name.split('_', 1)[-1].split('.')[0]  # Extract the base name (e.g., 'word1')
            if base_name in words:
                source_path = os.path.join(set_path, file_name)
                destination_path = os.path.join(final_dataset2_dir, base_name, file_name)
                # Copy the file to the destination
                shutil.copy2(source_path, destination_path)
                print(f"Copied {file_name} to {os.path.join(base_name, file_name)}")

                # Rename the copied file to remove the '_word' part (e.g., '01.png')
                new_file_name = f"{prefix}.png"
                new_destination_path = os.path.join(final_dataset2_dir, base_name, new_file_name)
                os.rename(destination_path, new_destination_path)
                print(f"Renamed {file_name} to {new_file_name}")

print("\nAll images have been copied and renamed.")
# Out:
# Created E:\!special\5_orgnsd_augmented_100 with subfolders for each word.
# Copied 061_bat.png to bat\061_bat.png
# Renamed 061_bat.png to 061.png
# Copied 061_cup.png to cup\061_cup.png
# Renamed 061_cup.png to 061.png
# Copied 061_drop.png to drop\061_drop.png
# Renamed 061_drop.png to 061.png
# Copied 061_eat.png to eat\061_eat.png
# Renamed 061_eat.png to 061.png
# Copied 061_fish.png to fish\061_fish.png
# Renamed 061_fish.png to 061.png
# Copied 061_hot.png to hot\061_hot.png
# Renamed 061_hot.png to 061.png
# Copied 061_jump.png to jump\061_jump.png
# Renamed 061_jump.png to 061.png
# Copied 061_milk.png to milk\061_milk.png
# Renamed 061_milk.png to 061.png
# Copied 061_pen.png to pen\061_pen.png
# Renamed 061_pen.png to 061.png
# Copied 061_red.png to red\061_red.png
# Renamed 061_red.png to 061.png
# Copied 062_bat.png to bat\062_bat.png
# Renamed 062_bat.png to 062.png
# Copied 062_cup.png to cup\062_cup.png
# Renamed 062_cup.png to 062.png
# Copied 062_drop.png to drop\062_drop.png
# Renamed 062_drop.png to 062.png
# Copied 062_eat.png to eat\062_eat.png
# Renamed 062_eat.png to 062.png
# Copied 062_fish.png to fish\062_fish.png
# Renamed 062_fish.png to 062.png
# Copied 062_hot.png to hot\062_hot.png
# Renamed 062_hot.png to 062.png
# Copied 062_jump.png to jump\062_jump.png
# Renamed 062_jump.png to 062.png
# Copied 062_milk.png to milk\062_milk.png
# Renamed 062_milk.png to 062.png
# Copied 062_pen.png to pen\062_pen.png
# Renamed 062_pen.png to 062.png
# Copied 062_red.png to red\062_red.png
# Renamed 062_red.png to 062.png
# Copied 063_bat.png to bat\063_bat.png
# Renamed 063_bat.png to 063.png
# Copied 063_cup.png to cup\063_cup.png
# Renamed 063_cup.png to 063.png
# Copied 063_drop.png to drop\063_drop.png
# Renamed 063_drop.png to 063.png
# Copied 063_eat.png to eat\063_eat.png
# Renamed 063_eat.png to 063.png
# Copied 063_fish.png to fish\063_fish.png
# Renamed 063_fish.png to 063.png
# Copied 063_hot.png to hot\063_hot.png
# Renamed 063_hot.png to 063.png
# Copied 063_jump.png to jump\063_jump.png
# Renamed 063_jump.png to 063.png
# Copied 063_milk.png to milk\063_milk.png
# Renamed 063_milk.png to 063.png
# Copied 063_pen.png to pen\063_pen.png
# Renamed 063_pen.png to 063.png
# Copied 063_red.png to red\063_red.png
# Renamed 063_red.png to 063.png
# Copied 064_bat.png to bat\064_bat.png
# Renamed 064_bat.png to 064.png
# Copied 064_cup.png to cup\064_cup.png
# Renamed 064_cup.png to 064.png
# Copied 064_drop.png to drop\064_drop.png
# Renamed 064_drop.png to 064.png
# Copied 064_eat.png to eat\064_eat.png
# Renamed 064_eat.png to 064.png
# Copied 064_fish.png to fish\064_fish.png
# Renamed 064_fish.png to 064.png
# Copied 064_hot.png to hot\064_hot.png
# Renamed 064_hot.png to 064.png
# Copied 064_jump.png to jump\064_jump.png
# Renamed 064_jump.png to 064.png
# Copied 064_milk.png to milk\064_milk.png
# Renamed 064_milk.png to 064.png
# Copied 064_pen.png to pen\064_pen.png
# Renamed 064_pen.png to 064.png
# Copied 064_red.png to red\064_red.png
# Renamed 064_red.png to 064.png
# Copied 065_bat.png to bat\065_bat.png
# Renamed 065_bat.png to 065.png
# Copied 065_cup.png to cup\065_cup.png
# Renamed 065_cup.png to 065.png
# Copied 065_drop.png to drop\065_drop.png
# Renamed 065_drop.png to 065.png
# Copied 065_eat.png to eat\065_eat.png
# Renamed 065_eat.png to 065.png
# Copied 065_fish.png to fish\065_fish.png
# Renamed 065_fish.png to 065.png
# Copied 065_hot.png to hot\065_hot.png
# Renamed 065_hot.png to 065.png
# Copied 065_jump.png to jump\065_jump.png
# Renamed 065_jump.png to 065.png
# Copied 065_milk.png to milk\065_milk.png
# Renamed 065_milk.png to 065.png
# Copied 065_pen.png to pen\065_pen.png
# Renamed 065_pen.png to 065.png
# Copied 065_red.png to red\065_red.png
# Renamed 065_red.png to 065.png
# Copied 066_bat.png to bat\066_bat.png
# Renamed 066_bat.png to 066.png
# Copied 066_cup.png to cup\066_cup.png
# Renamed 066_cup.png to 066.png
# Copied 066_drop.png to drop\066_drop.png
# Renamed 066_drop.png to 066.png
# Copied 066_eat.png to eat\066_eat.png
# Renamed 066_eat.png to 066.png
# Copied 066_fish.png to fish\066_fish.png
# Renamed 066_fish.png to 066.png
# Copied 066_hot.png to hot\066_hot.png
# Renamed 066_hot.png to 066.png
# Copied 066_jump.png to jump\066_jump.png
# Renamed 066_jump.png to 066.png
# Copied 066_milk.png to milk\066_milk.png
# Renamed 066_milk.png to 066.png
# Copied 066_pen.png to pen\066_pen.png
# Renamed 066_pen.png to 066.png
# Copied 066_red.png to red\066_red.png
# Renamed 066_red.png to 066.png
# Copied 067_bat.png to bat\067_bat.png
# Renamed 067_bat.png to 067.png
# Copied 067_cup.png to cup\067_cup.png
# Renamed 067_cup.png to 067.png
# Copied 067_drop.png to drop\067_drop.png
# Renamed 067_drop.png to 067.png
# Copied 067_eat.png to eat\067_eat.png
# Renamed 067_eat.png to 067.png
# Copied 067_fish.png to fish\067_fish.png
# Renamed 067_fish.png to 067.png
# Copied 067_hot.png to hot\067_hot.png
# Renamed 067_hot.png to 067.png
# Copied 067_jump.png to jump\067_jump.png
# Renamed 067_jump.png to 067.png
# Copied 067_milk.png to milk\067_milk.png
# Renamed 067_milk.png to 067.png
# Copied 067_pen.png to pen\067_pen.png
# Renamed 067_pen.png to 067.png
# Copied 067_red.png to red\067_red.png
# Renamed 067_red.png to 067.png
# Copied 068_bat.png to bat\068_bat.png
# Renamed 068_bat.png to 068.png
# Copied 068_cup.png to cup\068_cup.png
# Renamed 068_cup.png to 068.png
# Copied 068_drop.png to drop\068_drop.png
# Renamed 068_drop.png to 068.png
# Copied 068_eat.png to eat\068_eat.png
# Renamed 068_eat.png to 068.png
# Copied 068_fish.png to fish\068_fish.png
# Renamed 068_fish.png to 068.png
# Copied 068_hot.png to hot\068_hot.png
# Renamed 068_hot.png to 068.png
# Copied 068_jump.png to jump\068_jump.png
# Renamed 068_jump.png to 068.png
# Copied 068_milk.png to milk\068_milk.png
# Renamed 068_milk.png to 068.png
# Copied 068_pen.png to pen\068_pen.png
# Renamed 068_pen.png to 068.png
# Copied 068_red.png to red\068_red.png
# Renamed 068_red.png to 068.png
# Copied 069_bat.png to bat\069_bat.png
# Renamed 069_bat.png to 069.png
# Copied 069_cup.png to cup\069_cup.png
# Renamed 069_cup.png to 069.png
# Copied 069_drop.png to drop\069_drop.png
# Renamed 069_drop.png to 069.png
# Copied 069_eat.png to eat\069_eat.png
# Renamed 069_eat.png to 069.png
# Copied 069_fish.png to fish\069_fish.png
# Renamed 069_fish.png to 069.png
# Copied 069_hot.png to hot\069_hot.png
# Renamed 069_hot.png to 069.png
# Copied 069_jump.png to jump\069_jump.png
# Renamed 069_jump.png to 069.png
# Copied 069_milk.png to milk\069_milk.png
# Renamed 069_milk.png to 069.png
# Copied 069_pen.png to pen\069_pen.png
# Renamed 069_pen.png to 069.png
# Copied 069_red.png to red\069_red.png
# Renamed 069_red.png to 069.png
# Copied 070_bat.png to bat\070_bat.png
# Renamed 070_bat.png to 070.png
# Copied 070_cup.png to cup\070_cup.png
# Renamed 070_cup.png to 070.png
# Copied 070_drop.png to drop\070_drop.png
# Renamed 070_drop.png to 070.png
# Copied 070_eat.png to eat\070_eat.png
# Renamed 070_eat.png to 070.png
# Copied 070_fish.png to fish\070_fish.png
# Renamed 070_fish.png to 070.png
# Copied 070_hot.png to hot\070_hot.png
# Renamed 070_hot.png to 070.png
# Copied 070_jump.png to jump\070_jump.png
# Renamed 070_jump.png to 070.png
# Copied 070_milk.png to milk\070_milk.png
# Renamed 070_milk.png to 070.png
# Copied 070_pen.png to pen\070_pen.png
# Renamed 070_pen.png to 070.png
# Copied 070_red.png to red\070_red.png
# Renamed 070_red.png to 070.png
# Copied 071_bat.png to bat\071_bat.png
# Renamed 071_bat.png to 071.png
# Copied 071_cup.png to cup\071_cup.png
# Renamed 071_cup.png to 071.png
# Copied 071_drop.png to drop\071_drop.png
# Renamed 071_drop.png to 071.png
# Copied 071_eat.png to eat\071_eat.png
# Renamed 071_eat.png to 071.png
# Copied 071_fish.png to fish\071_fish.png
# Renamed 071_fish.png to 071.png
# Copied 071_hot.png to hot\071_hot.png
# Renamed 071_hot.png to 071.png
# Copied 071_jump.png to jump\071_jump.png
# Renamed 071_jump.png to 071.png
# Copied 071_milk.png to milk\071_milk.png
# Renamed 071_milk.png to 071.png
# Copied 071_pen.png to pen\071_pen.png
# Renamed 071_pen.png to 071.png
# Copied 071_red.png to red\071_red.png
# Renamed 071_red.png to 071.png
# Copied 072_bat.png to bat\072_bat.png
# Renamed 072_bat.png to 072.png
# Copied 072_cup.png to cup\072_cup.png
# Renamed 072_cup.png to 072.png
# Copied 072_drop.png to drop\072_drop.png
# Renamed 072_drop.png to 072.png
# Copied 072_eat.png to eat\072_eat.png
# Renamed 072_eat.png to 072.png
# Copied 072_fish.png to fish\072_fish.png
# Renamed 072_fish.png to 072.png
# Copied 072_hot.png to hot\072_hot.png
# Renamed 072_hot.png to 072.png
# Copied 072_jump.png to jump\072_jump.png
# Renamed 072_jump.png to 072.png
# Copied 072_milk.png to milk\072_milk.png
# Renamed 072_milk.png to 072.png
# Copied 072_pen.png to pen\072_pen.png
# Renamed 072_pen.png to 072.png
# Copied 072_red.png to red\072_red.png
# Renamed 072_red.png to 072.png
# Copied 073_bat.png to bat\073_bat.png
# Renamed 073_bat.png to 073.png
# Copied 073_cup.png to cup\073_cup.png
# Renamed 073_cup.png to 073.png
# Copied 073_drop.png to drop\073_drop.png
# Renamed 073_drop.png to 073.png
# Copied 073_eat.png to eat\073_eat.png
# Renamed 073_eat.png to 073.png
# Copied 073_fish.png to fish\073_fish.png
# Renamed 073_fish.png to 073.png
# Copied 073_hot.png to hot\073_hot.png
# Renamed 073_hot.png to 073.png
# Copied 073_jump.png to jump\073_jump.png
# Renamed 073_jump.png to 073.png
# Copied 073_milk.png to milk\073_milk.png
# Renamed 073_milk.png to 073.png
# Copied 073_pen.png to pen\073_pen.png
# Renamed 073_pen.png to 073.png
# Copied 073_red.png to red\073_red.png
# Renamed 073_red.png to 073.png
# Copied 074_bat.png to bat\074_bat.png
# Renamed 074_bat.png to 074.png
# Copied 074_cup.png to cup\074_cup.png
# Renamed 074_cup.png to 074.png
# Copied 074_drop.png to drop\074_drop.png
# Renamed 074_drop.png to 074.png
# Copied 074_eat.png to eat\074_eat.png
# Renamed 074_eat.png to 074.png
# Copied 074_fish.png to fish\074_fish.png
# Renamed 074_fish.png to 074.png
# Copied 074_hot.png to hot\074_hot.png
# Renamed 074_hot.png to 074.png
# Copied 074_jump.png to jump\074_jump.png
# Renamed 074_jump.png to 074.png
# Copied 074_milk.png to milk\074_milk.png
# Renamed 074_milk.png to 074.png
# Copied 074_pen.png to pen\074_pen.png
# Renamed 074_pen.png to 074.png
# Copied 074_red.png to red\074_red.png
# Renamed 074_red.png to 074.png
# Copied 075_bat.png to bat\075_bat.png
# Renamed 075_bat.png to 075.png
# Copied 075_cup.png to cup\075_cup.png
# Renamed 075_cup.png to 075.png
# Copied 075_drop.png to drop\075_drop.png
# Renamed 075_drop.png to 075.png
# Copied 075_eat.png to eat\075_eat.png
# Renamed 075_eat.png to 075.png
# Copied 075_fish.png to fish\075_fish.png
# Renamed 075_fish.png to 075.png
# Copied 075_hot.png to hot\075_hot.png
# Renamed 075_hot.png to 075.png
# Copied 075_jump.png to jump\075_jump.png
# Renamed 075_jump.png to 075.png
# Copied 075_milk.png to milk\075_milk.png
# Renamed 075_milk.png to 075.png
# Copied 075_pen.png to pen\075_pen.png
# Renamed 075_pen.png to 075.png
# Copied 075_red.png to red\075_red.png
# Renamed 075_red.png to 075.png
# Copied 076_bat.png to bat\076_bat.png
# Renamed 076_bat.png to 076.png
# Copied 076_cup.png to cup\076_cup.png
# Renamed 076_cup.png to 076.png
# Copied 076_drop.png to drop\076_drop.png
# Renamed 076_drop.png to 076.png
# Copied 076_eat.png to eat\076_eat.png
# Renamed 076_eat.png to 076.png
# Copied 076_fish.png to fish\076_fish.png
# Renamed 076_fish.png to 076.png
# Copied 076_hot.png to hot\076_hot.png
# Renamed 076_hot.png to 076.png
# Copied 076_jump.png to jump\076_jump.png
# Renamed 076_jump.png to 076.png
# Copied 076_milk.png to milk\076_milk.png
# Renamed 076_milk.png to 076.png
# Copied 076_pen.png to pen\076_pen.png
# Renamed 076_pen.png to 076.png
# Copied 076_red.png to red\076_red.png
# Renamed 076_red.png to 076.png
# Copied 077_bat.png to bat\077_bat.png
# Renamed 077_bat.png to 077.png
# Copied 077_cup.png to cup\077_cup.png
# Renamed 077_cup.png to 077.png
# Copied 077_drop.png to drop\077_drop.png
# Renamed 077_drop.png to 077.png
# Copied 077_eat.png to eat\077_eat.png
# Renamed 077_eat.png to 077.png
# Copied 077_fish.png to fish\077_fish.png
# Renamed 077_fish.png to 077.png
# Copied 077_hot.png to hot\077_hot.png
# Renamed 077_hot.png to 077.png
# Copied 077_jump.png to jump\077_jump.png
# Renamed 077_jump.png to 077.png
# Copied 077_milk.png to milk\077_milk.png
# Renamed 077_milk.png to 077.png
# Copied 077_pen.png to pen\077_pen.png
# Renamed 077_pen.png to 077.png
# Copied 077_red.png to red\077_red.png
# Renamed 077_red.png to 077.png
# Copied 078_bat.png to bat\078_bat.png
# Renamed 078_bat.png to 078.png
# Copied 078_cup.png to cup\078_cup.png
# Renamed 078_cup.png to 078.png
# Copied 078_drop.png to drop\078_drop.png
# Renamed 078_drop.png to 078.png
# Copied 078_eat.png to eat\078_eat.png
# Renamed 078_eat.png to 078.png
# Copied 078_fish.png to fish\078_fish.png
# Renamed 078_fish.png to 078.png
# Copied 078_hot.png to hot\078_hot.png
# Renamed 078_hot.png to 078.png
# Copied 078_jump.png to jump\078_jump.png
# Renamed 078_jump.png to 078.png
# Copied 078_milk.png to milk\078_milk.png
# Renamed 078_milk.png to 078.png
# Copied 078_pen.png to pen\078_pen.png
# Renamed 078_pen.png to 078.png
# Copied 078_red.png to red\078_red.png
# Renamed 078_red.png to 078.png
# Copied 079_bat.png to bat\079_bat.png
# Renamed 079_bat.png to 079.png
# Copied 079_cup.png to cup\079_cup.png
# Renamed 079_cup.png to 079.png
# Copied 079_drop.png to drop\079_drop.png
# Renamed 079_drop.png to 079.png
# Copied 079_eat.png to eat\079_eat.png
# Renamed 079_eat.png to 079.png
# Copied 079_fish.png to fish\079_fish.png
# Renamed 079_fish.png to 079.png
# Copied 079_hot.png to hot\079_hot.png
# Renamed 079_hot.png to 079.png
# Copied 079_jump.png to jump\079_jump.png
# Renamed 079_jump.png to 079.png
# Copied 079_milk.png to milk\079_milk.png
# Renamed 079_milk.png to 079.png
# Copied 079_pen.png to pen\079_pen.png
# Renamed 079_pen.png to 079.png
# Copied 079_red.png to red\079_red.png
# Renamed 079_red.png to 079.png
# Copied 080_bat.png to bat\080_bat.png
# Renamed 080_bat.png to 080.png
# Copied 080_cup.png to cup\080_cup.png
# Renamed 080_cup.png to 080.png
# Copied 080_drop.png to drop\080_drop.png
# Renamed 080_drop.png to 080.png
# Copied 080_eat.png to eat\080_eat.png
# Renamed 080_eat.png to 080.png
# Copied 080_fish.png to fish\080_fish.png
# Renamed 080_fish.png to 080.png
# Copied 080_hot.png to hot\080_hot.png
# Renamed 080_hot.png to 080.png
# Copied 080_jump.png to jump\080_jump.png
# Renamed 080_jump.png to 080.png
# Copied 080_milk.png to milk\080_milk.png
# Renamed 080_milk.png to 080.png
# Copied 080_pen.png to pen\080_pen.png
# Renamed 080_pen.png to 080.png
# Copied 080_red.png to red\080_red.png
# Renamed 080_red.png to 080.png
# Copied 081_bat.png to bat\081_bat.png
# Renamed 081_bat.png to 081.png
# Copied 081_cup.png to cup\081_cup.png
# Renamed 081_cup.png to 081.png
# Copied 081_drop.png to drop\081_drop.png
# Renamed 081_drop.png to 081.png
# Copied 081_eat.png to eat\081_eat.png
# Renamed 081_eat.png to 081.png
# Copied 081_fish.png to fish\081_fish.png
# Renamed 081_fish.png to 081.png
# Copied 081_hot.png to hot\081_hot.png
# Renamed 081_hot.png to 081.png
# Copied 081_jump.png to jump\081_jump.png
# Renamed 081_jump.png to 081.png
# Copied 081_milk.png to milk\081_milk.png
# Renamed 081_milk.png to 081.png
# Copied 081_pen.png to pen\081_pen.png
# Renamed 081_pen.png to 081.png
# Copied 081_red.png to red\081_red.png
# Renamed 081_red.png to 081.png
# Copied 082_bat.png to bat\082_bat.png
# Renamed 082_bat.png to 082.png
# Copied 082_cup.png to cup\082_cup.png
# Renamed 082_cup.png to 082.png
# Copied 082_drop.png to drop\082_drop.png
# Renamed 082_drop.png to 082.png
# Copied 082_eat.png to eat\082_eat.png
# Renamed 082_eat.png to 082.png
# Copied 082_fish.png to fish\082_fish.png
# Renamed 082_fish.png to 082.png
# Copied 082_hot.png to hot\082_hot.png
# Renamed 082_hot.png to 082.png
# Copied 082_jump.png to jump\082_jump.png
# Renamed 082_jump.png to 082.png
# Copied 082_milk.png to milk\082_milk.png
# Renamed 082_milk.png to 082.png
# Copied 082_pen.png to pen\082_pen.png
# Renamed 082_pen.png to 082.png
# Copied 082_red.png to red\082_red.png
# Renamed 082_red.png to 082.png
# Copied 083_bat.png to bat\083_bat.png
# Renamed 083_bat.png to 083.png
# Copied 083_cup.png to cup\083_cup.png
# Renamed 083_cup.png to 083.png
# Copied 083_drop.png to drop\083_drop.png
# Renamed 083_drop.png to 083.png
# Copied 083_eat.png to eat\083_eat.png
# Renamed 083_eat.png to 083.png
# Copied 083_fish.png to fish\083_fish.png
# Renamed 083_fish.png to 083.png
# Copied 083_hot.png to hot\083_hot.png
# Renamed 083_hot.png to 083.png
# Copied 083_jump.png to jump\083_jump.png
# Renamed 083_jump.png to 083.png
# Copied 083_milk.png to milk\083_milk.png
# Renamed 083_milk.png to 083.png
# Copied 083_pen.png to pen\083_pen.png
# Renamed 083_pen.png to 083.png
# Copied 083_red.png to red\083_red.png
# Renamed 083_red.png to 083.png
# Copied 084_bat.png to bat\084_bat.png
# Renamed 084_bat.png to 084.png
# Copied 084_cup.png to cup\084_cup.png
# Renamed 084_cup.png to 084.png
# Copied 084_drop.png to drop\084_drop.png
# Renamed 084_drop.png to 084.png
# Copied 084_eat.png to eat\084_eat.png
# Renamed 084_eat.png to 084.png
# Copied 084_fish.png to fish\084_fish.png
# Renamed 084_fish.png to 084.png
# Copied 084_hot.png to hot\084_hot.png
# Renamed 084_hot.png to 084.png
# Copied 084_jump.png to jump\084_jump.png
# Renamed 084_jump.png to 084.png
# Copied 084_milk.png to milk\084_milk.png
# Renamed 084_milk.png to 084.png
# Copied 084_pen.png to pen\084_pen.png
# Renamed 084_pen.png to 084.png
# Copied 084_red.png to red\084_red.png
# Renamed 084_red.png to 084.png
# Copied 085_bat.png to bat\085_bat.png
# Renamed 085_bat.png to 085.png
# Copied 085_cup.png to cup\085_cup.png
# Renamed 085_cup.png to 085.png
# Copied 085_drop.png to drop\085_drop.png
# Renamed 085_drop.png to 085.png
# Copied 085_eat.png to eat\085_eat.png
# Renamed 085_eat.png to 085.png
# Copied 085_fish.png to fish\085_fish.png
# Renamed 085_fish.png to 085.png
# Copied 085_hot.png to hot\085_hot.png
# Renamed 085_hot.png to 085.png
# Copied 085_jump.png to jump\085_jump.png
# Renamed 085_jump.png to 085.png
# Copied 085_milk.png to milk\085_milk.png
# Renamed 085_milk.png to 085.png
# Copied 085_pen.png to pen\085_pen.png
# Renamed 085_pen.png to 085.png
# Copied 085_red.png to red\085_red.png
# Renamed 085_red.png to 085.png
# Copied 086_bat.png to bat\086_bat.png
# Renamed 086_bat.png to 086.png
# Copied 086_cup.png to cup\086_cup.png
# Renamed 086_cup.png to 086.png
# Copied 086_drop.png to drop\086_drop.png
# Renamed 086_drop.png to 086.png
# Copied 086_eat.png to eat\086_eat.png
# Renamed 086_eat.png to 086.png
# Copied 086_fish.png to fish\086_fish.png
# Renamed 086_fish.png to 086.png
# Copied 086_hot.png to hot\086_hot.png
# Renamed 086_hot.png to 086.png
# Copied 086_jump.png to jump\086_jump.png
# Renamed 086_jump.png to 086.png
# Copied 086_milk.png to milk\086_milk.png
# Renamed 086_milk.png to 086.png
# Copied 086_pen.png to pen\086_pen.png
# Renamed 086_pen.png to 086.png
# Copied 086_red.png to red\086_red.png
# Renamed 086_red.png to 086.png
# Copied 087_bat.png to bat\087_bat.png
# Renamed 087_bat.png to 087.png
# Copied 087_cup.png to cup\087_cup.png
# Renamed 087_cup.png to 087.png
# Copied 087_drop.png to drop\087_drop.png
# Renamed 087_drop.png to 087.png
# Copied 087_eat.png to eat\087_eat.png
# Renamed 087_eat.png to 087.png
# Copied 087_fish.png to fish\087_fish.png
# Renamed 087_fish.png to 087.png
# Copied 087_hot.png to hot\087_hot.png
# Renamed 087_hot.png to 087.png
# Copied 087_jump.png to jump\087_jump.png
# Renamed 087_jump.png to 087.png
# Copied 087_milk.png to milk\087_milk.png
# Renamed 087_milk.png to 087.png
# Copied 087_pen.png to pen\087_pen.png
# Renamed 087_pen.png to 087.png
# Copied 087_red.png to red\087_red.png
# Renamed 087_red.png to 087.png
# Copied 088_bat.png to bat\088_bat.png
# Renamed 088_bat.png to 088.png
# Copied 088_cup.png to cup\088_cup.png
# Renamed 088_cup.png to 088.png
# Copied 088_drop.png to drop\088_drop.png
# Renamed 088_drop.png to 088.png
# Copied 088_eat.png to eat\088_eat.png
# Renamed 088_eat.png to 088.png
# Copied 088_fish.png to fish\088_fish.png
# Renamed 088_fish.png to 088.png
# Copied 088_hot.png to hot\088_hot.png
# Renamed 088_hot.png to 088.png
# Copied 088_jump.png to jump\088_jump.png
# Renamed 088_jump.png to 088.png
# Copied 088_milk.png to milk\088_milk.png
# Renamed 088_milk.png to 088.png
# Copied 088_pen.png to pen\088_pen.png
# Renamed 088_pen.png to 088.png
# Copied 088_red.png to red\088_red.png
# Renamed 088_red.png to 088.png
# Copied 089_bat.png to bat\089_bat.png
# Renamed 089_bat.png to 089.png
# Copied 089_cup.png to cup\089_cup.png
# Renamed 089_cup.png to 089.png
# Copied 089_drop.png to drop\089_drop.png
# Renamed 089_drop.png to 089.png
# Copied 089_eat.png to eat\089_eat.png
# Renamed 089_eat.png to 089.png
# Copied 089_fish.png to fish\089_fish.png
# Renamed 089_fish.png to 089.png
# Copied 089_hot.png to hot\089_hot.png
# Renamed 089_hot.png to 089.png
# Copied 089_jump.png to jump\089_jump.png
# Renamed 089_jump.png to 089.png
# Copied 089_milk.png to milk\089_milk.png
# Renamed 089_milk.png to 089.png
# Copied 089_pen.png to pen\089_pen.png
# Renamed 089_pen.png to 089.png
# Copied 089_red.png to red\089_red.png
# Renamed 089_red.png to 089.png
# Copied 090_bat.png to bat\090_bat.png
# Renamed 090_bat.png to 090.png
# Copied 090_cup.png to cup\090_cup.png
# Renamed 090_cup.png to 090.png
# Copied 090_drop.png to drop\090_drop.png
# Renamed 090_drop.png to 090.png
# Copied 090_eat.png to eat\090_eat.png
# Renamed 090_eat.png to 090.png
# Copied 090_fish.png to fish\090_fish.png
# Renamed 090_fish.png to 090.png
# Copied 090_hot.png to hot\090_hot.png
# Renamed 090_hot.png to 090.png
# Copied 090_jump.png to jump\090_jump.png
# Renamed 090_jump.png to 090.png
# Copied 090_milk.png to milk\090_milk.png
# Renamed 090_milk.png to 090.png
# Copied 090_pen.png to pen\090_pen.png
# Renamed 090_pen.png to 090.png
# Copied 090_red.png to red\090_red.png
# Renamed 090_red.png to 090.png
# Copied 091_bat.png to bat\091_bat.png
# Renamed 091_bat.png to 091.png
# Copied 091_cup.png to cup\091_cup.png
# Renamed 091_cup.png to 091.png
# Copied 091_drop.png to drop\091_drop.png
# Renamed 091_drop.png to 091.png
# Copied 091_eat.png to eat\091_eat.png
# Renamed 091_eat.png to 091.png
# Copied 091_fish.png to fish\091_fish.png
# Renamed 091_fish.png to 091.png
# Copied 091_hot.png to hot\091_hot.png
# Renamed 091_hot.png to 091.png
# Copied 091_jump.png to jump\091_jump.png
# Renamed 091_jump.png to 091.png
# Copied 091_milk.png to milk\091_milk.png
# Renamed 091_milk.png to 091.png
# Copied 091_pen.png to pen\091_pen.png
# Renamed 091_pen.png to 091.png
# Copied 091_red.png to red\091_red.png
# Renamed 091_red.png to 091.png
# Copied 092_bat.png to bat\092_bat.png
# Renamed 092_bat.png to 092.png
# Copied 092_cup.png to cup\092_cup.png
# Renamed 092_cup.png to 092.png
# Copied 092_drop.png to drop\092_drop.png
# Renamed 092_drop.png to 092.png
# Copied 092_eat.png to eat\092_eat.png
# Renamed 092_eat.png to 092.png
# Copied 092_fish.png to fish\092_fish.png
# Renamed 092_fish.png to 092.png
# Copied 092_hot.png to hot\092_hot.png
# Renamed 092_hot.png to 092.png
# Copied 092_jump.png to jump\092_jump.png
# Renamed 092_jump.png to 092.png
# Copied 092_milk.png to milk\092_milk.png
# Renamed 092_milk.png to 092.png
# Copied 092_pen.png to pen\092_pen.png
# Renamed 092_pen.png to 092.png
# Copied 092_red.png to red\092_red.png
# Renamed 092_red.png to 092.png
# Copied 093_bat.png to bat\093_bat.png
# Renamed 093_bat.png to 093.png
# Copied 093_cup.png to cup\093_cup.png
# Renamed 093_cup.png to 093.png
# Copied 093_drop.png to drop\093_drop.png
# Renamed 093_drop.png to 093.png
# Copied 093_eat.png to eat\093_eat.png
# Renamed 093_eat.png to 093.png
# Copied 093_fish.png to fish\093_fish.png
# Renamed 093_fish.png to 093.png
# Copied 093_hot.png to hot\093_hot.png
# Renamed 093_hot.png to 093.png
# Copied 093_jump.png to jump\093_jump.png
# Renamed 093_jump.png to 093.png
# Copied 093_milk.png to milk\093_milk.png
# Renamed 093_milk.png to 093.png
# Copied 093_pen.png to pen\093_pen.png
# Renamed 093_pen.png to 093.png
# Copied 093_red.png to red\093_red.png
# Renamed 093_red.png to 093.png
# Copied 094_bat.png to bat\094_bat.png
# Renamed 094_bat.png to 094.png
# Copied 094_cup.png to cup\094_cup.png
# Renamed 094_cup.png to 094.png
# Copied 094_drop.png to drop\094_drop.png
# Renamed 094_drop.png to 094.png
# Copied 094_eat.png to eat\094_eat.png
# Renamed 094_eat.png to 094.png
# Copied 094_fish.png to fish\094_fish.png
# Renamed 094_fish.png to 094.png
# Copied 094_hot.png to hot\094_hot.png
# Renamed 094_hot.png to 094.png
# Copied 094_jump.png to jump\094_jump.png
# Renamed 094_jump.png to 094.png
# Copied 094_milk.png to milk\094_milk.png
# Renamed 094_milk.png to 094.png
# Copied 094_pen.png to pen\094_pen.png
# Renamed 094_pen.png to 094.png
# Copied 094_red.png to red\094_red.png
# Renamed 094_red.png to 094.png
# Copied 095_bat.png to bat\095_bat.png
# Renamed 095_bat.png to 095.png
# Copied 095_cup.png to cup\095_cup.png
# Renamed 095_cup.png to 095.png
# Copied 095_drop.png to drop\095_drop.png
# Renamed 095_drop.png to 095.png
# Copied 095_eat.png to eat\095_eat.png
# Renamed 095_eat.png to 095.png
# Copied 095_fish.png to fish\095_fish.png
# Renamed 095_fish.png to 095.png
# Copied 095_hot.png to hot\095_hot.png
# Renamed 095_hot.png to 095.png
# Copied 095_jump.png to jump\095_jump.png
# Renamed 095_jump.png to 095.png
# Copied 095_milk.png to milk\095_milk.png
# Renamed 095_milk.png to 095.png
# Copied 095_pen.png to pen\095_pen.png
# Renamed 095_pen.png to 095.png
# Copied 095_red.png to red\095_red.png
# Renamed 095_red.png to 095.png
# Copied 096_bat.png to bat\096_bat.png
# Renamed 096_bat.png to 096.png
# Copied 096_cup.png to cup\096_cup.png
# Renamed 096_cup.png to 096.png
# Copied 096_drop.png to drop\096_drop.png
# Renamed 096_drop.png to 096.png
# Copied 096_eat.png to eat\096_eat.png
# Renamed 096_eat.png to 096.png
# Copied 096_fish.png to fish\096_fish.png
# Renamed 096_fish.png to 096.png
# Copied 096_hot.png to hot\096_hot.png
# Renamed 096_hot.png to 096.png
# Copied 096_jump.png to jump\096_jump.png
# Renamed 096_jump.png to 096.png
# Copied 096_milk.png to milk\096_milk.png
# Renamed 096_milk.png to 096.png
# Copied 096_pen.png to pen\096_pen.png
# Renamed 096_pen.png to 096.png
# Copied 096_red.png to red\096_red.png
# Renamed 096_red.png to 096.png
# Copied 097_bat.png to bat\097_bat.png
# Renamed 097_bat.png to 097.png
# Copied 097_cup.png to cup\097_cup.png
# Renamed 097_cup.png to 097.png
# Copied 097_drop.png to drop\097_drop.png
# Renamed 097_drop.png to 097.png
# Copied 097_eat.png to eat\097_eat.png
# Renamed 097_eat.png to 097.png
# Copied 097_fish.png to fish\097_fish.png
# Renamed 097_fish.png to 097.png
# Copied 097_hot.png to hot\097_hot.png
# Renamed 097_hot.png to 097.png
# Copied 097_jump.png to jump\097_jump.png
# Renamed 097_jump.png to 097.png
# Copied 097_milk.png to milk\097_milk.png
# Renamed 097_milk.png to 097.png
# Copied 097_pen.png to pen\097_pen.png
# Renamed 097_pen.png to 097.png
# Copied 097_red.png to red\097_red.png
# Renamed 097_red.png to 097.png
# Copied 098_bat.png to bat\098_bat.png
# Renamed 098_bat.png to 098.png
# Copied 098_cup.png to cup\098_cup.png
# Renamed 098_cup.png to 098.png
# Copied 098_drop.png to drop\098_drop.png
# Renamed 098_drop.png to 098.png
# Copied 098_eat.png to eat\098_eat.png
# Renamed 098_eat.png to 098.png
# Copied 098_fish.png to fish\098_fish.png
# Renamed 098_fish.png to 098.png
# Copied 098_hot.png to hot\098_hot.png
# Renamed 098_hot.png to 098.png
# Copied 098_jump.png to jump\098_jump.png
# Renamed 098_jump.png to 098.png
# Copied 098_milk.png to milk\098_milk.png
# Renamed 098_milk.png to 098.png
# Copied 098_pen.png to pen\098_pen.png
# Renamed 098_pen.png to 098.png
# Copied 098_red.png to red\098_red.png
# Renamed 098_red.png to 098.png
# Copied 099_bat.png to bat\099_bat.png
# Renamed 099_bat.png to 099.png
# Copied 099_cup.png to cup\099_cup.png
# Renamed 099_cup.png to 099.png
# Copied 099_drop.png to drop\099_drop.png
# Renamed 099_drop.png to 099.png
# Copied 099_eat.png to eat\099_eat.png
# Renamed 099_eat.png to 099.png
# Copied 099_fish.png to fish\099_fish.png
# Renamed 099_fish.png to 099.png
# Copied 099_hot.png to hot\099_hot.png
# Renamed 099_hot.png to 099.png
# Copied 099_jump.png to jump\099_jump.png
# Renamed 099_jump.png to 099.png
# Copied 099_milk.png to milk\099_milk.png
# Renamed 099_milk.png to 099.png
# Copied 099_pen.png to pen\099_pen.png
# Renamed 099_pen.png to 099.png
# Copied 099_red.png to red\099_red.png
# Renamed 099_red.png to 099.png
# Copied 100_bat.png to bat\100_bat.png
# Renamed 100_bat.png to 100.png
# Copied 100_cup.png to cup\100_cup.png
# Renamed 100_cup.png to 100.png
# Copied 100_drop.png to drop\100_drop.png
# Renamed 100_drop.png to 100.png
# Copied 100_eat.png to eat\100_eat.png
# Renamed 100_eat.png to 100.png
# Copied 100_fish.png to fish\100_fish.png
# Renamed 100_fish.png to 100.png
# Copied 100_hot.png to hot\100_hot.png
# Renamed 100_hot.png to 100.png
# Copied 100_jump.png to jump\100_jump.png
# Renamed 100_jump.png to 100.png
# Copied 100_milk.png to milk\100_milk.png
# Renamed 100_milk.png to 100.png
# Copied 100_pen.png to pen\100_pen.png
# Renamed 100_pen.png to 100.png
# Copied 100_red.png to red\100_red.png
# Renamed 100_red.png to 100.png
# Copied 101_bat.png to bat\101_bat.png
# Renamed 101_bat.png to 101.png
# Copied 101_cup.png to cup\101_cup.png
# Renamed 101_cup.png to 101.png
# Copied 101_drop.png to drop\101_drop.png
# Renamed 101_drop.png to 101.png
# Copied 101_eat.png to eat\101_eat.png
# Renamed 101_eat.png to 101.png
# Copied 101_fish.png to fish\101_fish.png
# Renamed 101_fish.png to 101.png
# Copied 101_hot.png to hot\101_hot.png
# Renamed 101_hot.png to 101.png
# Copied 101_jump.png to jump\101_jump.png
# Renamed 101_jump.png to 101.png
# Copied 101_milk.png to milk\101_milk.png
# Renamed 101_milk.png to 101.png
# Copied 101_pen.png to pen\101_pen.png
# Renamed 101_pen.png to 101.png
# Copied 101_red.png to red\101_red.png
# Renamed 101_red.png to 101.png
# Copied 102_bat.png to bat\102_bat.png
# Renamed 102_bat.png to 102.png
# Copied 102_cup.png to cup\102_cup.png
# Renamed 102_cup.png to 102.png
# Copied 102_drop.png to drop\102_drop.png
# Renamed 102_drop.png to 102.png
# Copied 102_eat.png to eat\102_eat.png
# Renamed 102_eat.png to 102.png
# Copied 102_fish.png to fish\102_fish.png
# Renamed 102_fish.png to 102.png
# Copied 102_hot.png to hot\102_hot.png
# Renamed 102_hot.png to 102.png
# Copied 102_jump.png to jump\102_jump.png
# Renamed 102_jump.png to 102.png
# Copied 102_milk.png to milk\102_milk.png
# Renamed 102_milk.png to 102.png
# Copied 102_pen.png to pen\102_pen.png
# Renamed 102_pen.png to 102.png
# Copied 102_red.png to red\102_red.png
# Renamed 102_red.png to 102.png
# Copied 103_bat.png to bat\103_bat.png
# Renamed 103_bat.png to 103.png
# Copied 103_cup.png to cup\103_cup.png
# Renamed 103_cup.png to 103.png
# Copied 103_drop.png to drop\103_drop.png
# Renamed 103_drop.png to 103.png
# Copied 103_eat.png to eat\103_eat.png
# Renamed 103_eat.png to 103.png
# Copied 103_fish.png to fish\103_fish.png
# Renamed 103_fish.png to 103.png
# Copied 103_hot.png to hot\103_hot.png
# Renamed 103_hot.png to 103.png
# Copied 103_jump.png to jump\103_jump.png
# Renamed 103_jump.png to 103.png
# Copied 103_milk.png to milk\103_milk.png
# Renamed 103_milk.png to 103.png
# Copied 103_pen.png to pen\103_pen.png
# Renamed 103_pen.png to 103.png
# Copied 103_red.png to red\103_red.png
# Renamed 103_red.png to 103.png
# Copied 104_bat.png to bat\104_bat.png
# Renamed 104_bat.png to 104.png
# Copied 104_cup.png to cup\104_cup.png
# Renamed 104_cup.png to 104.png
# Copied 104_drop.png to drop\104_drop.png
# Renamed 104_drop.png to 104.png
# Copied 104_eat.png to eat\104_eat.png
# Renamed 104_eat.png to 104.png
# Copied 104_fish.png to fish\104_fish.png
# Renamed 104_fish.png to 104.png
# Copied 104_hot.png to hot\104_hot.png
# Renamed 104_hot.png to 104.png
# Copied 104_jump.png to jump\104_jump.png
# Renamed 104_jump.png to 104.png
# Copied 104_milk.png to milk\104_milk.png
# Renamed 104_milk.png to 104.png
# Copied 104_pen.png to pen\104_pen.png
# Renamed 104_pen.png to 104.png
# Copied 104_red.png to red\104_red.png
# Renamed 104_red.png to 104.png
# Copied 105_bat.png to bat\105_bat.png
# Renamed 105_bat.png to 105.png
# Copied 105_cup.png to cup\105_cup.png
# Renamed 105_cup.png to 105.png
# Copied 105_drop.png to drop\105_drop.png
# Renamed 105_drop.png to 105.png
# Copied 105_eat.png to eat\105_eat.png
# Renamed 105_eat.png to 105.png
# Copied 105_fish.png to fish\105_fish.png
# Renamed 105_fish.png to 105.png
# Copied 105_hot.png to hot\105_hot.png
# Renamed 105_hot.png to 105.png
# Copied 105_jump.png to jump\105_jump.png
# Renamed 105_jump.png to 105.png
# Copied 105_milk.png to milk\105_milk.png
# Renamed 105_milk.png to 105.png
# Copied 105_pen.png to pen\105_pen.png
# Renamed 105_pen.png to 105.png
# Copied 105_red.png to red\105_red.png
# Renamed 105_red.png to 105.png
# Copied 106_bat.png to bat\106_bat.png
# Renamed 106_bat.png to 106.png
# Copied 106_cup.png to cup\106_cup.png
# Renamed 106_cup.png to 106.png
# Copied 106_drop.png to drop\106_drop.png
# Renamed 106_drop.png to 106.png
# Copied 106_eat.png to eat\106_eat.png
# Renamed 106_eat.png to 106.png
# Copied 106_fish.png to fish\106_fish.png
# Renamed 106_fish.png to 106.png
# Copied 106_hot.png to hot\106_hot.png
# Renamed 106_hot.png to 106.png
# Copied 106_jump.png to jump\106_jump.png
# Renamed 106_jump.png to 106.png
# Copied 106_milk.png to milk\106_milk.png
# Renamed 106_milk.png to 106.png
# Copied 106_pen.png to pen\106_pen.png
# Renamed 106_pen.png to 106.png
# Copied 106_red.png to red\106_red.png
# Renamed 106_red.png to 106.png
# Copied 107_bat.png to bat\107_bat.png
# Renamed 107_bat.png to 107.png
# Copied 107_cup.png to cup\107_cup.png
# Renamed 107_cup.png to 107.png
# Copied 107_drop.png to drop\107_drop.png
# Renamed 107_drop.png to 107.png
# Copied 107_eat.png to eat\107_eat.png
# Renamed 107_eat.png to 107.png
# Copied 107_fish.png to fish\107_fish.png
# Renamed 107_fish.png to 107.png
# Copied 107_hot.png to hot\107_hot.png
# Renamed 107_hot.png to 107.png
# Copied 107_jump.png to jump\107_jump.png
# Renamed 107_jump.png to 107.png
# Copied 107_milk.png to milk\107_milk.png
# Renamed 107_milk.png to 107.png
# Copied 107_pen.png to pen\107_pen.png
# Renamed 107_pen.png to 107.png
# Copied 107_red.png to red\107_red.png
# Renamed 107_red.png to 107.png
# Copied 108_bat.png to bat\108_bat.png
# Renamed 108_bat.png to 108.png
# Copied 108_cup.png to cup\108_cup.png
# Renamed 108_cup.png to 108.png
# Copied 108_drop.png to drop\108_drop.png
# Renamed 108_drop.png to 108.png
# Copied 108_eat.png to eat\108_eat.png
# Renamed 108_eat.png to 108.png
# Copied 108_fish.png to fish\108_fish.png
# Renamed 108_fish.png to 108.png
# Copied 108_hot.png to hot\108_hot.png
# Renamed 108_hot.png to 108.png
# Copied 108_jump.png to jump\108_jump.png
# Renamed 108_jump.png to 108.png
# Copied 108_milk.png to milk\108_milk.png
# Renamed 108_milk.png to 108.png
# Copied 108_pen.png to pen\108_pen.png
# Renamed 108_pen.png to 108.png
# Copied 108_red.png to red\108_red.png
# Renamed 108_red.png to 108.png
# Copied 109_bat.png to bat\109_bat.png
# Renamed 109_bat.png to 109.png
# Copied 109_cup.png to cup\109_cup.png
# Renamed 109_cup.png to 109.png
# Copied 109_drop.png to drop\109_drop.png
# Renamed 109_drop.png to 109.png
# Copied 109_eat.png to eat\109_eat.png
# Renamed 109_eat.png to 109.png
# Copied 109_fish.png to fish\109_fish.png
# Renamed 109_fish.png to 109.png
# Copied 109_hot.png to hot\109_hot.png
# Renamed 109_hot.png to 109.png
# Copied 109_jump.png to jump\109_jump.png
# Renamed 109_jump.png to 109.png
# Copied 109_milk.png to milk\109_milk.png
# Renamed 109_milk.png to 109.png
# Copied 109_pen.png to pen\109_pen.png
# Renamed 109_pen.png to 109.png
# Copied 109_red.png to red\109_red.png
# Renamed 109_red.png to 109.png
# Copied 110_bat.png to bat\110_bat.png
# Renamed 110_bat.png to 110.png
# Copied 110_cup.png to cup\110_cup.png
# Renamed 110_cup.png to 110.png
# Copied 110_drop.png to drop\110_drop.png
# Renamed 110_drop.png to 110.png
# Copied 110_eat.png to eat\110_eat.png
# Renamed 110_eat.png to 110.png
# Copied 110_fish.png to fish\110_fish.png
# Renamed 110_fish.png to 110.png
# Copied 110_hot.png to hot\110_hot.png
# Renamed 110_hot.png to 110.png
# Copied 110_jump.png to jump\110_jump.png
# Renamed 110_jump.png to 110.png
# Copied 110_milk.png to milk\110_milk.png
# Renamed 110_milk.png to 110.png
# Copied 110_pen.png to pen\110_pen.png
# Renamed 110_pen.png to 110.png
# Copied 110_red.png to red\110_red.png
# Renamed 110_red.png to 110.png
# Copied 111_bat.png to bat\111_bat.png
# Renamed 111_bat.png to 111.png
# Copied 111_cup.png to cup\111_cup.png
# Renamed 111_cup.png to 111.png
# Copied 111_drop.png to drop\111_drop.png
# Renamed 111_drop.png to 111.png
# Copied 111_eat.png to eat\111_eat.png
# Renamed 111_eat.png to 111.png
# Copied 111_fish.png to fish\111_fish.png
# Renamed 111_fish.png to 111.png
# Copied 111_hot.png to hot\111_hot.png
# Renamed 111_hot.png to 111.png
# Copied 111_jump.png to jump\111_jump.png
# Renamed 111_jump.png to 111.png
# Copied 111_milk.png to milk\111_milk.png
# Renamed 111_milk.png to 111.png
# Copied 111_pen.png to pen\111_pen.png
# Renamed 111_pen.png to 111.png
# Copied 111_red.png to red\111_red.png
# Renamed 111_red.png to 111.png
# Copied 112_bat.png to bat\112_bat.png
# Renamed 112_bat.png to 112.png
# Copied 112_cup.png to cup\112_cup.png
# Renamed 112_cup.png to 112.png
# Copied 112_drop.png to drop\112_drop.png
# Renamed 112_drop.png to 112.png
# Copied 112_eat.png to eat\112_eat.png
# Renamed 112_eat.png to 112.png
# Copied 112_fish.png to fish\112_fish.png
# Renamed 112_fish.png to 112.png
# Copied 112_hot.png to hot\112_hot.png
# Renamed 112_hot.png to 112.png
# Copied 112_jump.png to jump\112_jump.png
# Renamed 112_jump.png to 112.png
# Copied 112_milk.png to milk\112_milk.png
# Renamed 112_milk.png to 112.png
# Copied 112_pen.png to pen\112_pen.png
# Renamed 112_pen.png to 112.png
# Copied 112_red.png to red\112_red.png
# Renamed 112_red.png to 112.png
# Copied 113_bat.png to bat\113_bat.png
# Renamed 113_bat.png to 113.png
# Copied 113_cup.png to cup\113_cup.png
# Renamed 113_cup.png to 113.png
# Copied 113_drop.png to drop\113_drop.png
# Renamed 113_drop.png to 113.png
# Copied 113_eat.png to eat\113_eat.png
# Renamed 113_eat.png to 113.png
# Copied 113_fish.png to fish\113_fish.png
# Renamed 113_fish.png to 113.png
# Copied 113_hot.png to hot\113_hot.png
# Renamed 113_hot.png to 113.png
# Copied 113_jump.png to jump\113_jump.png
# Renamed 113_jump.png to 113.png
# Copied 113_milk.png to milk\113_milk.png
# Renamed 113_milk.png to 113.png
# Copied 113_pen.png to pen\113_pen.png
# Renamed 113_pen.png to 113.png
# Copied 113_red.png to red\113_red.png
# Renamed 113_red.png to 113.png
# Copied 114_bat.png to bat\114_bat.png
# Renamed 114_bat.png to 114.png
# Copied 114_cup.png to cup\114_cup.png
# Renamed 114_cup.png to 114.png
# Copied 114_drop.png to drop\114_drop.png
# Renamed 114_drop.png to 114.png
# Copied 114_eat.png to eat\114_eat.png
# Renamed 114_eat.png to 114.png
# Copied 114_fish.png to fish\114_fish.png
# Renamed 114_fish.png to 114.png
# Copied 114_hot.png to hot\114_hot.png
# Renamed 114_hot.png to 114.png
# Copied 114_jump.png to jump\114_jump.png
# Renamed 114_jump.png to 114.png
# Copied 114_milk.png to milk\114_milk.png
# Renamed 114_milk.png to 114.png
# Copied 114_pen.png to pen\114_pen.png
# Renamed 114_pen.png to 114.png
# Copied 114_red.png to red\114_red.png
# Renamed 114_red.png to 114.png
# Copied 115_bat.png to bat\115_bat.png
# Renamed 115_bat.png to 115.png
# Copied 115_cup.png to cup\115_cup.png
# Renamed 115_cup.png to 115.png
# Copied 115_drop.png to drop\115_drop.png
# Renamed 115_drop.png to 115.png
# Copied 115_eat.png to eat\115_eat.png
# Renamed 115_eat.png to 115.png
# Copied 115_fish.png to fish\115_fish.png
# Renamed 115_fish.png to 115.png
# Copied 115_hot.png to hot\115_hot.png
# Renamed 115_hot.png to 115.png
# Copied 115_jump.png to jump\115_jump.png
# Renamed 115_jump.png to 115.png
# Copied 115_milk.png to milk\115_milk.png
# Renamed 115_milk.png to 115.png
# Copied 115_pen.png to pen\115_pen.png
# Renamed 115_pen.png to 115.png
# Copied 115_red.png to red\115_red.png
# Renamed 115_red.png to 115.png
# Copied 116_bat.png to bat\116_bat.png
# Renamed 116_bat.png to 116.png
# Copied 116_cup.png to cup\116_cup.png
# Renamed 116_cup.png to 116.png
# Copied 116_drop.png to drop\116_drop.png
# Renamed 116_drop.png to 116.png
# Copied 116_eat.png to eat\116_eat.png
# Renamed 116_eat.png to 116.png
# Copied 116_fish.png to fish\116_fish.png
# Renamed 116_fish.png to 116.png
# Copied 116_hot.png to hot\116_hot.png
# Renamed 116_hot.png to 116.png
# Copied 116_jump.png to jump\116_jump.png
# Renamed 116_jump.png to 116.png
# Copied 116_milk.png to milk\116_milk.png
# Renamed 116_milk.png to 116.png
# Copied 116_pen.png to pen\116_pen.png
# Renamed 116_pen.png to 116.png
# Copied 116_red.png to red\116_red.png
# Renamed 116_red.png to 116.png
# Copied 117_bat.png to bat\117_bat.png
# Renamed 117_bat.png to 117.png
# Copied 117_cup.png to cup\117_cup.png
# Renamed 117_cup.png to 117.png
# Copied 117_drop.png to drop\117_drop.png
# Renamed 117_drop.png to 117.png
# Copied 117_eat.png to eat\117_eat.png
# Renamed 117_eat.png to 117.png
# Copied 117_fish.png to fish\117_fish.png
# Renamed 117_fish.png to 117.png
# Copied 117_hot.png to hot\117_hot.png
# Renamed 117_hot.png to 117.png
# Copied 117_jump.png to jump\117_jump.png
# Renamed 117_jump.png to 117.png
# Copied 117_milk.png to milk\117_milk.png
# Renamed 117_milk.png to 117.png
# Copied 117_pen.png to pen\117_pen.png
# Renamed 117_pen.png to 117.png
# Copied 117_red.png to red\117_red.png
# Renamed 117_red.png to 117.png
# Copied 118_bat.png to bat\118_bat.png
# Renamed 118_bat.png to 118.png
# Copied 118_cup.png to cup\118_cup.png
# Renamed 118_cup.png to 118.png
# Copied 118_drop.png to drop\118_drop.png
# Renamed 118_drop.png to 118.png
# Copied 118_eat.png to eat\118_eat.png
# Renamed 118_eat.png to 118.png
# Copied 118_fish.png to fish\118_fish.png
# Renamed 118_fish.png to 118.png
# Copied 118_hot.png to hot\118_hot.png
# Renamed 118_hot.png to 118.png
# Copied 118_jump.png to jump\118_jump.png
# Renamed 118_jump.png to 118.png
# Copied 118_milk.png to milk\118_milk.png
# Renamed 118_milk.png to 118.png
# Copied 118_pen.png to pen\118_pen.png
# Renamed 118_pen.png to 118.png
# Copied 118_red.png to red\118_red.png
# Renamed 118_red.png to 118.png
# Copied 119_bat.png to bat\119_bat.png
# Renamed 119_bat.png to 119.png
# Copied 119_cup.png to cup\119_cup.png
# Renamed 119_cup.png to 119.png
# Copied 119_drop.png to drop\119_drop.png
# Renamed 119_drop.png to 119.png
# Copied 119_eat.png to eat\119_eat.png
# Renamed 119_eat.png to 119.png
# Copied 119_fish.png to fish\119_fish.png
# Renamed 119_fish.png to 119.png
# Copied 119_hot.png to hot\119_hot.png
# Renamed 119_hot.png to 119.png
# Copied 119_jump.png to jump\119_jump.png
# Renamed 119_jump.png to 119.png
# Copied 119_milk.png to milk\119_milk.png
# Renamed 119_milk.png to 119.png
# Copied 119_pen.png to pen\119_pen.png
# Renamed 119_pen.png to 119.png
# Copied 119_red.png to red\119_red.png
# Renamed 119_red.png to 119.png
# Copied 120_bat.png to bat\120_bat.png
# Renamed 120_bat.png to 120.png
# Copied 120_cup.png to cup\120_cup.png
# Renamed 120_cup.png to 120.png
# Copied 120_drop.png to drop\120_drop.png
# Renamed 120_drop.png to 120.png
# Copied 120_eat.png to eat\120_eat.png
# Renamed 120_eat.png to 120.png
# Copied 120_fish.png to fish\120_fish.png
# Renamed 120_fish.png to 120.png
# Copied 120_hot.png to hot\120_hot.png
# Renamed 120_hot.png to 120.png
# Copied 120_jump.png to jump\120_jump.png
# Renamed 120_jump.png to 120.png
# Copied 120_milk.png to milk\120_milk.png
# Renamed 120_milk.png to 120.png
# Copied 120_pen.png to pen\120_pen.png
# Renamed 120_pen.png to 120.png
# Copied 120_red.png to red\120_red.png
# Renamed 120_red.png to 120.png
# Copied 121_bat.png to bat\121_bat.png
# Renamed 121_bat.png to 121.png
# Copied 121_cup.png to cup\121_cup.png
# Renamed 121_cup.png to 121.png
# Copied 121_drop.png to drop\121_drop.png
# Renamed 121_drop.png to 121.png
# Copied 121_eat.png to eat\121_eat.png
# Renamed 121_eat.png to 121.png
# Copied 121_fish.png to fish\121_fish.png
# Renamed 121_fish.png to 121.png
# Copied 121_hot.png to hot\121_hot.png
# Renamed 121_hot.png to 121.png
# Copied 121_jump.png to jump\121_jump.png
# Renamed 121_jump.png to 121.png
# Copied 121_milk.png to milk\121_milk.png
# Renamed 121_milk.png to 121.png
# Copied 121_pen.png to pen\121_pen.png
# Renamed 121_pen.png to 121.png
# Copied 121_red.png to red\121_red.png
# Renamed 121_red.png to 121.png
# Copied 122_bat.png to bat\122_bat.png
# Renamed 122_bat.png to 122.png
# Copied 122_cup.png to cup\122_cup.png
# Renamed 122_cup.png to 122.png
# Copied 122_drop.png to drop\122_drop.png
# Renamed 122_drop.png to 122.png
# Copied 122_eat.png to eat\122_eat.png
# Renamed 122_eat.png to 122.png
# Copied 122_fish.png to fish\122_fish.png
# Renamed 122_fish.png to 122.png
# Copied 122_hot.png to hot\122_hot.png
# Renamed 122_hot.png to 122.png
# Copied 122_jump.png to jump\122_jump.png
# Renamed 122_jump.png to 122.png
# Copied 122_milk.png to milk\122_milk.png
# Renamed 122_milk.png to 122.png
# Copied 122_pen.png to pen\122_pen.png
# Renamed 122_pen.png to 122.png
# Copied 122_red.png to red\122_red.png
# Renamed 122_red.png to 122.png
# Copied 123_bat.png to bat\123_bat.png
# Renamed 123_bat.png to 123.png
# Copied 123_cup.png to cup\123_cup.png
# Renamed 123_cup.png to 123.png
# Copied 123_drop.png to drop\123_drop.png
# Renamed 123_drop.png to 123.png
# Copied 123_eat.png to eat\123_eat.png
# Renamed 123_eat.png to 123.png
# Copied 123_fish.png to fish\123_fish.png
# Renamed 123_fish.png to 123.png
# Copied 123_hot.png to hot\123_hot.png
# Renamed 123_hot.png to 123.png
# Copied 123_jump.png to jump\123_jump.png
# Renamed 123_jump.png to 123.png
# Copied 123_milk.png to milk\123_milk.png
# Renamed 123_milk.png to 123.png
# Copied 123_pen.png to pen\123_pen.png
# Renamed 123_pen.png to 123.png
# Copied 123_red.png to red\123_red.png
# Renamed 123_red.png to 123.png
# Copied 124_bat.png to bat\124_bat.png
# Renamed 124_bat.png to 124.png
# Copied 124_cup.png to cup\124_cup.png
# Renamed 124_cup.png to 124.png
# Copied 124_drop.png to drop\124_drop.png
# Renamed 124_drop.png to 124.png
# Copied 124_eat.png to eat\124_eat.png
# Renamed 124_eat.png to 124.png
# Copied 124_fish.png to fish\124_fish.png
# Renamed 124_fish.png to 124.png
# Copied 124_hot.png to hot\124_hot.png
# Renamed 124_hot.png to 124.png
# Copied 124_jump.png to jump\124_jump.png
# Renamed 124_jump.png to 124.png
# Copied 124_milk.png to milk\124_milk.png
# Renamed 124_milk.png to 124.png
# Copied 124_pen.png to pen\124_pen.png
# Renamed 124_pen.png to 124.png
# Copied 124_red.png to red\124_red.png
# Renamed 124_red.png to 124.png
# Copied 125_bat.png to bat\125_bat.png
# Renamed 125_bat.png to 125.png
# Copied 125_cup.png to cup\125_cup.png
# Renamed 125_cup.png to 125.png
# Copied 125_drop.png to drop\125_drop.png
# Renamed 125_drop.png to 125.png
# Copied 125_eat.png to eat\125_eat.png
# Renamed 125_eat.png to 125.png
# Copied 125_fish.png to fish\125_fish.png
# Renamed 125_fish.png to 125.png
# Copied 125_hot.png to hot\125_hot.png
# Renamed 125_hot.png to 125.png
# Copied 125_jump.png to jump\125_jump.png
# Renamed 125_jump.png to 125.png
# Copied 125_milk.png to milk\125_milk.png
# Renamed 125_milk.png to 125.png
# Copied 125_pen.png to pen\125_pen.png
# Renamed 125_pen.png to 125.png
# Copied 125_red.png to red\125_red.png
# Renamed 125_red.png to 125.png
# Copied 126_bat.png to bat\126_bat.png
# Renamed 126_bat.png to 126.png
# Copied 126_cup.png to cup\126_cup.png
# Renamed 126_cup.png to 126.png
# Copied 126_drop.png to drop\126_drop.png
# Renamed 126_drop.png to 126.png
# Copied 126_eat.png to eat\126_eat.png
# Renamed 126_eat.png to 126.png
# Copied 126_fish.png to fish\126_fish.png
# Renamed 126_fish.png to 126.png
# Copied 126_hot.png to hot\126_hot.png
# Renamed 126_hot.png to 126.png
# Copied 126_jump.png to jump\126_jump.png
# Renamed 126_jump.png to 126.png
# Copied 126_milk.png to milk\126_milk.png
# Renamed 126_milk.png to 126.png
# Copied 126_pen.png to pen\126_pen.png
# Renamed 126_pen.png to 126.png
# Copied 126_red.png to red\126_red.png
# Renamed 126_red.png to 126.png
# Copied 127_bat.png to bat\127_bat.png
# Renamed 127_bat.png to 127.png
# Copied 127_cup.png to cup\127_cup.png
# Renamed 127_cup.png to 127.png
# Copied 127_drop.png to drop\127_drop.png
# Renamed 127_drop.png to 127.png
# Copied 127_eat.png to eat\127_eat.png
# Renamed 127_eat.png to 127.png
# Copied 127_fish.png to fish\127_fish.png
# Renamed 127_fish.png to 127.png
# Copied 127_hot.png to hot\127_hot.png
# Renamed 127_hot.png to 127.png
# Copied 127_jump.png to jump\127_jump.png
# Renamed 127_jump.png to 127.png
# Copied 127_milk.png to milk\127_milk.png
# Renamed 127_milk.png to 127.png
# Copied 127_pen.png to pen\127_pen.png
# Renamed 127_pen.png to 127.png
# Copied 127_red.png to red\127_red.png
# Renamed 127_red.png to 127.png
# Copied 128_bat.png to bat\128_bat.png
# Renamed 128_bat.png to 128.png
# Copied 128_cup.png to cup\128_cup.png
# Renamed 128_cup.png to 128.png
# Copied 128_drop.png to drop\128_drop.png
# Renamed 128_drop.png to 128.png
# Copied 128_eat.png to eat\128_eat.png
# Renamed 128_eat.png to 128.png
# Copied 128_fish.png to fish\128_fish.png
# Renamed 128_fish.png to 128.png
# Copied 128_hot.png to hot\128_hot.png
# Renamed 128_hot.png to 128.png
# Copied 128_jump.png to jump\128_jump.png
# Renamed 128_jump.png to 128.png
# Copied 128_milk.png to milk\128_milk.png
# Renamed 128_milk.png to 128.png
# Copied 128_pen.png to pen\128_pen.png
# ...
# Copied 138_fish.png to fish\138_fish.png
# Renamed 138_fish.png to 138.png
# Copied 138_hot.png to hot\138_hot.png
# Renamed 138_hot.png to 138.png
# Copied 138_jump.png to jump\138_jump.png
# Renamed 138_jump.png to 138.png
# Copied 138_milk.png to milk\138_milk.png
# Renamed 138_milk.png to 138.png
# Copied 138_pen.png to pen\138_pen.png
# Renamed 138_pen.png to 138.png
# Copied 138_red.png to red\138_red.png
# Renamed 138_red.png to 138.png
# Copied 139_bat.png to bat\139_bat.png
# Renamed 139_bat.png to 139.png
# Copied 139_cup.png to cup\139_cup.png
# Renamed 139_cup.png to 139.png
# Copied 139_drop.png to drop\139_drop.png
# Renamed 139_drop.png to 139.png
# Copied 139_eat.png to eat\139_eat.png
# Renamed 139_eat.png to 139.png
# Copied 139_fish.png to fish\139_fish.png
# Renamed 139_fish.png to 139.png
# Copied 139_hot.png to hot\139_hot.png
# Renamed 139_hot.png to 139.png
# Copied 139_jump.png to jump\139_jump.png
# Renamed 139_jump.png to 139.png
# Copied 139_milk.png to milk\139_milk.png
# Renamed 139_milk.png to 139.png
# Copied 139_pen.png to pen\139_pen.png
# Renamed 139_pen.png to 139.png
# Copied 139_red.png to red\139_red.png
# Renamed 139_red.png to 139.png
# Copied 140_bat.png to bat\140_bat.png
# Renamed 140_bat.png to 140.png
# Copied 140_cup.png to cup\140_cup.png
# Renamed 140_cup.png to 140.png
# Copied 140_drop.png to drop\140_drop.png
# Renamed 140_drop.png to 140.png
# Copied 140_eat.png to eat\140_eat.png
# Renamed 140_eat.png to 140.png
# Copied 140_fish.png to fish\140_fish.png
# Renamed 140_fish.png to 140.png
# Copied 140_hot.png to hot\140_hot.png
# Renamed 140_hot.png to 140.png
# Copied 140_jump.png to jump\140_jump.png
# Renamed 140_jump.png to 140.png
# Copied 140_milk.png to milk\140_milk.png
# Renamed 140_milk.png to 140.png
# Copied 140_pen.png to pen\140_pen.png
# Renamed 140_pen.png to 140.png
# Copied 140_red.png to red\140_red.png
# Renamed 140_red.png to 140.png
# Copied 141_bat.png to bat\141_bat.png
# Renamed 141_bat.png to 141.png
# Copied 141_cup.png to cup\141_cup.png
# Renamed 141_cup.png to 141.png
# Copied 141_drop.png to drop\141_drop.png
# Renamed 141_drop.png to 141.png
# Copied 141_eat.png to eat\141_eat.png
# Renamed 141_eat.png to 141.png
# Copied 141_fish.png to fish\141_fish.png
# Renamed 141_fish.png to 141.png
# Copied 141_hot.png to hot\141_hot.png
# Renamed 141_hot.png to 141.png
# Copied 141_jump.png to jump\141_jump.png
# Renamed 141_jump.png to 141.png
# Copied 141_milk.png to milk\141_milk.png
# Renamed 141_milk.png to 141.png
# Copied 141_pen.png to pen\141_pen.png
# Renamed 141_pen.png to 141.png
# Copied 141_red.png to red\141_red.png
# Renamed 141_red.png to 141.png
# Copied 142_bat.png to bat\142_bat.png
# Renamed 142_bat.png to 142.png
# Copied 142_cup.png to cup\142_cup.png
# Renamed 142_cup.png to 142.png
# Copied 142_drop.png to drop\142_drop.png
# Renamed 142_drop.png to 142.png
# Copied 142_eat.png to eat\142_eat.png
# Renamed 142_eat.png to 142.png
# Copied 142_fish.png to fish\142_fish.png
# Renamed 142_fish.png to 142.png
# Copied 142_hot.png to hot\142_hot.png
# Renamed 142_hot.png to 142.png
# Copied 142_jump.png to jump\142_jump.png
# Renamed 142_jump.png to 142.png
# Copied 142_milk.png to milk\142_milk.png
# Renamed 142_milk.png to 142.png
# Copied 142_pen.png to pen\142_pen.png
# Renamed 142_pen.png to 142.png
# Copied 142_red.png to red\142_red.png
# Renamed 142_red.png to 142.png
# Copied 143_bat.png to bat\143_bat.png
# Renamed 143_bat.png to 143.png
# Copied 143_cup.png to cup\143_cup.png
# Renamed 143_cup.png to 143.png
# Copied 143_drop.png to drop\143_drop.png
# Renamed 143_drop.png to 143.png
# Copied 143_eat.png to eat\143_eat.png
# Renamed 143_eat.png to 143.png
# Copied 143_fish.png to fish\143_fish.png
# Renamed 143_fish.png to 143.png
# Copied 143_hot.png to hot\143_hot.png
# Renamed 143_hot.png to 143.png
# Copied 143_jump.png to jump\143_jump.png
# Renamed 143_jump.png to 143.png
# Copied 143_milk.png to milk\143_milk.png
# Renamed 143_milk.png to 143.png
# Copied 143_pen.png to pen\143_pen.png
# Renamed 143_pen.png to 143.png
# Copied 143_red.png to red\143_red.png
# Renamed 143_red.png to 143.png
# Copied 144_bat.png to bat\144_bat.png
# Renamed 144_bat.png to 144.png
# Copied 144_cup.png to cup\144_cup.png
# Renamed 144_cup.png to 144.png
# Copied 144_drop.png to drop\144_drop.png
# Renamed 144_drop.png to 144.png
# Copied 144_eat.png to eat\144_eat.png
# Renamed 144_eat.png to 144.png
# Copied 144_fish.png to fish\144_fish.png
# Renamed 144_fish.png to 144.png
# Copied 144_hot.png to hot\144_hot.png
# Renamed 144_hot.png to 144.png
# Copied 144_jump.png to jump\144_jump.png
# Renamed 144_jump.png to 144.png
# Copied 144_milk.png to milk\144_milk.png
# Renamed 144_milk.png to 144.png
# Copied 144_pen.png to pen\144_pen.png
# Renamed 144_pen.png to 144.png
# Copied 144_red.png to red\144_red.png
# Renamed 144_red.png to 144.png
# Copied 145_bat.png to bat\145_bat.png
# Renamed 145_bat.png to 145.png
# Copied 145_cup.png to cup\145_cup.png
# Renamed 145_cup.png to 145.png
# Copied 145_drop.png to drop\145_drop.png
# Renamed 145_drop.png to 145.png
# Copied 145_eat.png to eat\145_eat.png
# Renamed 145_eat.png to 145.png
# Copied 145_fish.png to fish\145_fish.png
# Renamed 145_fish.png to 145.png
# Copied 145_hot.png to hot\145_hot.png
# Renamed 145_hot.png to 145.png
# Copied 145_jump.png to jump\145_jump.png
# Renamed 145_jump.png to 145.png
# Copied 145_milk.png to milk\145_milk.png
# Renamed 145_milk.png to 145.png
# Copied 145_pen.png to pen\145_pen.png
# Renamed 145_pen.png to 145.png
# Copied 145_red.png to red\145_red.png
# Renamed 145_red.png to 145.png
# Copied 146_bat.png to bat\146_bat.png
# Renamed 146_bat.png to 146.png
# Copied 146_cup.png to cup\146_cup.png
# Renamed 146_cup.png to 146.png
# Copied 146_drop.png to drop\146_drop.png
# Renamed 146_drop.png to 146.png
# Copied 146_eat.png to eat\146_eat.png
# Renamed 146_eat.png to 146.png
# Copied 146_fish.png to fish\146_fish.png
# Renamed 146_fish.png to 146.png
# Copied 146_hot.png to hot\146_hot.png
# Renamed 146_hot.png to 146.png
# Copied 146_jump.png to jump\146_jump.png
# Renamed 146_jump.png to 146.png
# Copied 146_milk.png to milk\146_milk.png
# Renamed 146_milk.png to 146.png
# Copied 146_pen.png to pen\146_pen.png
# Renamed 146_pen.png to 146.png
# Copied 146_red.png to red\146_red.png
# Renamed 146_red.png to 146.png
# Copied 147_bat.png to bat\147_bat.png
# Renamed 147_bat.png to 147.png
# Copied 147_cup.png to cup\147_cup.png
# Renamed 147_cup.png to 147.png
# Copied 147_drop.png to drop\147_drop.png
# Renamed 147_drop.png to 147.png
# Copied 147_eat.png to eat\147_eat.png
# Renamed 147_eat.png to 147.png
# Copied 147_fish.png to fish\147_fish.png
# Renamed 147_fish.png to 147.png
# Copied 147_hot.png to hot\147_hot.png
# Renamed 147_hot.png to 147.png
# Copied 147_jump.png to jump\147_jump.png
# Renamed 147_jump.png to 147.png
# Copied 147_milk.png to milk\147_milk.png
# Renamed 147_milk.png to 147.png
# Copied 147_pen.png to pen\147_pen.png
# Renamed 147_pen.png to 147.png
# Copied 147_red.png to red\147_red.png
# Renamed 147_red.png to 147.png
# Copied 148_bat.png to bat\148_bat.png
# Renamed 148_bat.png to 148.png
# Copied 148_cup.png to cup\148_cup.png
# Renamed 148_cup.png to 148.png
# Copied 148_drop.png to drop\148_drop.png
# Renamed 148_drop.png to 148.png
# Copied 148_eat.png to eat\148_eat.png
# Renamed 148_eat.png to 148.png
# Copied 148_fish.png to fish\148_fish.png
# Renamed 148_fish.png to 148.png
# Copied 148_hot.png to hot\148_hot.png
# Renamed 148_hot.png to 148.png
# Copied 148_jump.png to jump\148_jump.png
# Renamed 148_jump.png to 148.png
# Copied 148_milk.png to milk\148_milk.png
# Renamed 148_milk.png to 148.png
# Copied 148_pen.png to pen\148_pen.png
# Renamed 148_pen.png to 148.png
# Copied 148_red.png to red\148_red.png
# Renamed 148_red.png to 148.png
# Copied 149_bat.png to bat\149_bat.png
# Renamed 149_bat.png to 149.png
# Copied 149_cup.png to cup\149_cup.png
# Renamed 149_cup.png to 149.png
# Copied 149_drop.png to drop\149_drop.png
# Renamed 149_drop.png to 149.png
# Copied 149_eat.png to eat\149_eat.png
# Renamed 149_eat.png to 149.png
# Copied 149_fish.png to fish\149_fish.png
# Renamed 149_fish.png to 149.png
# Copied 149_hot.png to hot\149_hot.png
# Renamed 149_hot.png to 149.png
# Copied 149_jump.png to jump\149_jump.png
# Renamed 149_jump.png to 149.png
# Copied 149_milk.png to milk\149_milk.png
# Renamed 149_milk.png to 149.png
# Copied 149_pen.png to pen\149_pen.png
# Renamed 149_pen.png to 149.png
# Copied 149_red.png to red\149_red.png
# Renamed 149_red.png to 149.png
# Copied 150_bat.png to bat\150_bat.png
# Renamed 150_bat.png to 150.png
# Copied 150_cup.png to cup\150_cup.png
# Renamed 150_cup.png to 150.png
# Copied 150_drop.png to drop\150_drop.png
# Renamed 150_drop.png to 150.png
# Copied 150_eat.png to eat\150_eat.png
# Renamed 150_eat.png to 150.png
# Copied 150_fish.png to fish\150_fish.png
# Renamed 150_fish.png to 150.png
# Copied 150_hot.png to hot\150_hot.png
# Renamed 150_hot.png to 150.png
# Copied 150_jump.png to jump\150_jump.png
# Renamed 150_jump.png to 150.png
# Copied 150_milk.png to milk\150_milk.png
# Renamed 150_milk.png to 150.png
# Copied 150_pen.png to pen\150_pen.png
# Renamed 150_pen.png to 150.png
# Copied 150_red.png to red\150_red.png
# Renamed 150_red.png to 150.png
# Copied 151_bat.png to bat\151_bat.png
# Renamed 151_bat.png to 151.png
# Copied 151_cup.png to cup\151_cup.png
# Renamed 151_cup.png to 151.png
# Copied 151_drop.png to drop\151_drop.png
# Renamed 151_drop.png to 151.png
# Copied 151_eat.png to eat\151_eat.png
# Renamed 151_eat.png to 151.png
# Copied 151_fish.png to fish\151_fish.png
# Renamed 151_fish.png to 151.png
# Copied 151_hot.png to hot\151_hot.png
# Renamed 151_hot.png to 151.png
# Copied 151_jump.png to jump\151_jump.png
# Renamed 151_jump.png to 151.png
# Copied 151_milk.png to milk\151_milk.png
# Renamed 151_milk.png to 151.png
# Copied 151_pen.png to pen\151_pen.png
# Renamed 151_pen.png to 151.png
# Copied 151_red.png to red\151_red.png
# Renamed 151_red.png to 151.png
# Copied 152_bat.png to bat\152_bat.png
# Renamed 152_bat.png to 152.png
# Copied 152_cup.png to cup\152_cup.png
# Renamed 152_cup.png to 152.png
# Copied 152_drop.png to drop\152_drop.png
# Renamed 152_drop.png to 152.png
# Copied 152_eat.png to eat\152_eat.png
# Renamed 152_eat.png to 152.png
# Copied 152_fish.png to fish\152_fish.png
# Renamed 152_fish.png to 152.png
# Copied 152_hot.png to hot\152_hot.png
# Renamed 152_hot.png to 152.png
# Copied 152_jump.png to jump\152_jump.png
# Renamed 152_jump.png to 152.png
# Copied 152_milk.png to milk\152_milk.png
# Renamed 152_milk.png to 152.png
# Copied 152_pen.png to pen\152_pen.png
# Renamed 152_pen.png to 152.png
# Copied 152_red.png to red\152_red.png
# Renamed 152_red.png to 152.png
# Copied 153_bat.png to bat\153_bat.png
# Renamed 153_bat.png to 153.png
# Copied 153_cup.png to cup\153_cup.png
# Renamed 153_cup.png to 153.png
# Copied 153_drop.png to drop\153_drop.png
# Renamed 153_drop.png to 153.png
# Copied 153_eat.png to eat\153_eat.png
# Renamed 153_eat.png to 153.png
# Copied 153_fish.png to fish\153_fish.png
# Renamed 153_fish.png to 153.png
# Copied 153_hot.png to hot\153_hot.png
# Renamed 153_hot.png to 153.png
# Copied 153_jump.png to jump\153_jump.png
# Renamed 153_jump.png to 153.png
# Copied 153_milk.png to milk\153_milk.png
# Renamed 153_milk.png to 153.png
# Copied 153_pen.png to pen\153_pen.png
# Renamed 153_pen.png to 153.png
# Copied 153_red.png to red\153_red.png
# Renamed 153_red.png to 153.png
# Copied 154_bat.png to bat\154_bat.png
# Renamed 154_bat.png to 154.png
# Copied 154_cup.png to cup\154_cup.png
# Renamed 154_cup.png to 154.png
# Copied 154_drop.png to drop\154_drop.png
# Renamed 154_drop.png to 154.png
# Copied 154_eat.png to eat\154_eat.png
# Renamed 154_eat.png to 154.png
# Copied 154_fish.png to fish\154_fish.png
# Renamed 154_fish.png to 154.png
# Copied 154_hot.png to hot\154_hot.png
# Renamed 154_hot.png to 154.png
# Copied 154_jump.png to jump\154_jump.png
# Renamed 154_jump.png to 154.png
# Copied 154_milk.png to milk\154_milk.png
# Renamed 154_milk.png to 154.png
# Copied 154_pen.png to pen\154_pen.png
# Renamed 154_pen.png to 154.png
# Copied 154_red.png to red\154_red.png
# Renamed 154_red.png to 154.png
# Copied 155_bat.png to bat\155_bat.png
# Renamed 155_bat.png to 155.png
# Copied 155_cup.png to cup\155_cup.png
# Renamed 155_cup.png to 155.png
# Copied 155_drop.png to drop\155_drop.png
# Renamed 155_drop.png to 155.png
# Copied 155_eat.png to eat\155_eat.png
# Renamed 155_eat.png to 155.png
# Copied 155_fish.png to fish\155_fish.png
# Renamed 155_fish.png to 155.png
# Copied 155_hot.png to hot\155_hot.png
# Renamed 155_hot.png to 155.png
# Copied 155_jump.png to jump\155_jump.png
# Renamed 155_jump.png to 155.png
# Copied 155_milk.png to milk\155_milk.png
# Renamed 155_milk.png to 155.png
# Copied 155_pen.png to pen\155_pen.png
# Renamed 155_pen.png to 155.png
# Copied 155_red.png to red\155_red.png
# Renamed 155_red.png to 155.png
# Copied 156_bat.png to bat\156_bat.png
# Renamed 156_bat.png to 156.png
# Copied 156_cup.png to cup\156_cup.png
# Renamed 156_cup.png to 156.png
# Copied 156_drop.png to drop\156_drop.png
# Renamed 156_drop.png to 156.png
# Copied 156_eat.png to eat\156_eat.png
# Renamed 156_eat.png to 156.png
# Copied 156_fish.png to fish\156_fish.png
# Renamed 156_fish.png to 156.png
# Copied 156_hot.png to hot\156_hot.png
# Renamed 156_hot.png to 156.png
# Copied 156_jump.png to jump\156_jump.png
# Renamed 156_jump.png to 156.png
# Copied 156_milk.png to milk\156_milk.png
# Renamed 156_milk.png to 156.png
# Copied 156_pen.png to pen\156_pen.png
# Renamed 156_pen.png to 156.png
# Copied 156_red.png to red\156_red.png
# Renamed 156_red.png to 156.png
# Copied 157_bat.png to bat\157_bat.png
# Renamed 157_bat.png to 157.png
# Copied 157_cup.png to cup\157_cup.png
# Renamed 157_cup.png to 157.png
# Copied 157_drop.png to drop\157_drop.png
# Renamed 157_drop.png to 157.png
# Copied 157_eat.png to eat\157_eat.png
# Renamed 157_eat.png to 157.png
# Copied 157_fish.png to fish\157_fish.png
# Renamed 157_fish.png to 157.png
# Copied 157_hot.png to hot\157_hot.png
# Renamed 157_hot.png to 157.png
# Copied 157_jump.png to jump\157_jump.png
# Renamed 157_jump.png to 157.png
# Copied 157_milk.png to milk\157_milk.png
# Renamed 157_milk.png to 157.png
# Copied 157_pen.png to pen\157_pen.png
# Renamed 157_pen.png to 157.png
# Copied 157_red.png to red\157_red.png
# Renamed 157_red.png to 157.png
# Copied 158_bat.png to bat\158_bat.png
# Renamed 158_bat.png to 158.png
# Copied 158_cup.png to cup\158_cup.png
# Renamed 158_cup.png to 158.png
# Copied 158_drop.png to drop\158_drop.png
# Renamed 158_drop.png to 158.png
# Copied 158_eat.png to eat\158_eat.png
# Renamed 158_eat.png to 158.png
# Copied 158_fish.png to fish\158_fish.png
# Renamed 158_fish.png to 158.png
# Copied 158_hot.png to hot\158_hot.png
# Renamed 158_hot.png to 158.png
# Copied 158_jump.png to jump\158_jump.png
# Renamed 158_jump.png to 158.png
# Copied 158_milk.png to milk\158_milk.png
# Renamed 158_milk.png to 158.png
# Copied 158_pen.png to pen\158_pen.png
# Renamed 158_pen.png to 158.png
# Copied 158_red.png to red\158_red.png
# Renamed 158_red.png to 158.png
# Copied 159_bat.png to bat\159_bat.png
# Renamed 159_bat.png to 159.png
# Copied 159_cup.png to cup\159_cup.png
# Renamed 159_cup.png to 159.png
# Copied 159_drop.png to drop\159_drop.png
# Renamed 159_drop.png to 159.png
# Copied 159_eat.png to eat\159_eat.png
# Renamed 159_eat.png to 159.png
# Copied 159_fish.png to fish\159_fish.png
# Renamed 159_fish.png to 159.png
# Copied 159_hot.png to hot\159_hot.png
# Renamed 159_hot.png to 159.png
# Copied 159_jump.png to jump\159_jump.png
# Renamed 159_jump.png to 159.png
# Copied 159_milk.png to milk\159_milk.png
# Renamed 159_milk.png to 159.png
# Copied 159_pen.png to pen\159_pen.png
# Renamed 159_pen.png to 159.png
# Copied 159_red.png to red\159_red.png
# Renamed 159_red.png to 159.png
# Copied 160_bat.png to bat\160_bat.png
# Renamed 160_bat.png to 160.png
# Copied 160_cup.png to cup\160_cup.png
# Renamed 160_cup.png to 160.png
# Copied 160_drop.png to drop\160_drop.png
# Renamed 160_drop.png to 160.png
# Copied 160_eat.png to eat\160_eat.png
# Renamed 160_eat.png to 160.png
# Copied 160_fish.png to fish\160_fish.png
# Renamed 160_fish.png to 160.png
# Copied 160_hot.png to hot\160_hot.png
# Renamed 160_hot.png to 160.png
# Copied 160_jump.png to jump\160_jump.png
# Renamed 160_jump.png to 160.png
# Copied 160_milk.png to milk\160_milk.png
# Renamed 160_milk.png to 160.png
# Copied 160_pen.png to pen\160_pen.png
# Renamed 160_pen.png to 160.png
# Copied 160_red.png to red\160_red.png
# Renamed 160_red.png to 160.png
#
# All images have been copied and renamed.

# %% [markdown]
# **resizing image to row & column: 224 x 224**

# %%
# Function to copy the entire directory structure and resize images
def copy_and_resize_images(source_dir, target_dir, new_size=(224, 224)):
    # Copy the directory structure
    if os.path.exists(target_dir):
        shutil.rmtree(target_dir)  # Remove if already exists to start fresh
    shutil.copytree(source_dir, target_dir)

    # Traverse the copied directory and resize all images
    for root, dirs, files in os.walk(target_dir):
        for file in files:
            if file.endswith('.png'):  # Adjust for other formats if needed
                image_path = os.path.join(root, file)
                try:
                    with Image.open(image_path) as img:
                        resized_img = img.resize(new_size, Image.LANCZOS)  # High-quality resizing
                        resized_img.save(image_path)
                        print(f"Resized and saved: {image_path}")
                except Exception as e:
                    print(f"Failed to process {image_path}: {e}")

# Paths for source and target directories
source_directory = r'D:\PycharmProjects\pro_dis_2\collected_data\6_organised_images_700'
target_directory = r'D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700'

# Run the function
copy_and_resize_images(source_directory, target_directory)

print("\nAll images have been copied and resized.")
# Out:
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\001.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\002.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\003.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\004.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\005.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\006.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\007.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\008.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\009.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\010.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\011.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\012.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\013.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\014.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\015.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\016.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\017.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\018.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\019.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\020.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\021.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\022.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\023.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\024.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\025.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\026.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\027.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\028.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\029.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\030.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\031.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\032.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\033.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\034.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\035.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\036.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\037.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\038.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\039.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\040.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\041.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\042.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\043.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\044.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\045.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\046.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\047.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\048.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\049.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\050.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\051.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\052.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\053.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\054.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\055.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\056.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\057.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\058.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\059.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\060.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\061.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\062.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\063.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\064.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\065.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\066.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\067.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\068.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\069.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\070.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\071.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\072.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\073.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\074.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\075.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\076.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\077.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\078.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\079.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\080.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\081.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\082.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\083.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\084.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\085.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\086.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\087.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\088.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\089.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\090.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\091.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\092.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\093.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\094.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\095.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\096.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\097.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\098.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\099.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\100.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\101.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\102.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\103.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\104.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\105.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\106.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\107.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\108.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\109.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\110.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\111.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\112.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\113.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\114.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\115.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\116.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\117.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\118.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\119.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\120.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\121.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\122.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\123.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\124.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\125.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\126.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\127.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\128.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\129.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\130.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\131.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\132.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\133.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\134.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\135.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\136.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\137.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\138.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\139.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\140.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\141.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\142.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\143.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\144.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\145.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\146.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\147.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\148.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\149.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\150.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\151.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\152.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\153.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\154.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\155.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\156.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\157.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\158.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\159.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\160.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\161.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\162.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\163.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\164.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\165.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\166.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\167.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\168.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\169.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\170.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\171.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\172.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\173.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\174.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\175.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\176.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\177.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\178.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\179.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\180.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\181.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\182.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\183.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\184.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\185.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\186.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\187.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\188.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\189.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\190.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\191.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\192.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\193.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\194.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\195.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\196.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\197.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\198.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\199.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\200.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\201.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\202.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\203.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\204.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\205.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\206.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\207.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\208.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\209.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\210.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\211.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\212.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\213.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\214.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\215.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\216.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\217.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\218.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\219.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\220.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\221.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\222.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\223.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\224.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\225.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\226.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\227.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\228.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\229.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\230.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\231.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\232.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\233.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\234.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\235.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\236.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\237.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\238.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\239.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\240.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\241.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\242.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\243.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\244.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\245.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\246.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\247.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\248.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\249.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\250.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\251.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\252.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\253.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\254.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\255.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\256.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\257.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\258.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\259.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\260.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\261.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\262.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\263.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\264.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\265.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\266.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\267.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\268.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\269.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\270.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\271.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\272.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\273.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\274.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\275.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\276.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\277.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\278.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\279.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\280.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\281.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\282.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\283.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\284.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\285.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\286.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\287.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\288.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\289.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\290.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\291.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\292.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\293.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\294.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\295.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\296.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\297.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\298.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\299.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\300.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\301.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\302.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\303.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\304.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\305.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\306.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\307.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\308.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\309.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\310.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\311.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\312.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\313.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\314.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\315.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\316.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\317.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\318.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\319.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\320.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\321.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\322.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\323.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\324.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\325.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\326.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\327.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\328.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\329.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\330.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\331.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\332.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\333.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\334.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\335.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\336.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\337.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\338.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\339.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\340.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\341.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\342.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\343.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\344.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\345.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\346.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\347.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\348.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\349.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\350.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\351.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\352.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\353.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\354.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\355.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\356.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\357.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\358.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\359.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\360.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\361.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\362.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\363.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\364.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\365.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\366.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\367.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\368.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\369.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\370.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\371.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\372.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\373.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\374.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\375.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\376.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\377.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\378.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\379.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\380.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\381.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\382.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\383.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\384.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\385.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\386.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\387.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\388.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\389.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\390.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\391.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\392.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\393.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\394.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\395.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\396.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\397.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\398.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\399.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\400.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\401.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\402.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\403.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\404.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\405.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\406.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\407.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\408.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\409.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\410.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\411.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\412.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\413.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\414.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\415.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\416.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\417.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\418.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\419.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\420.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\421.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\422.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\423.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\424.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\425.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\426.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\427.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\428.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\429.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\430.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\431.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\432.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\433.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\434.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\435.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\436.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\437.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\438.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\439.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\440.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\441.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\442.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\443.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\444.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\445.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\446.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\447.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\448.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\449.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\450.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\451.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\452.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\453.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\454.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\455.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\456.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\457.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\458.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\459.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\460.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\461.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\462.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\463.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\464.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\465.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\466.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\467.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\468.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\469.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\470.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\471.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\472.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\473.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\474.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\475.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\476.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\477.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\478.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\479.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\480.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\481.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\482.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\483.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\484.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\485.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\486.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\487.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\488.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\489.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\490.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\491.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\492.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\493.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\494.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\495.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\496.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\497.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\498.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\499.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\bat\500.png
# ...
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\535.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\536.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\537.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\538.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\539.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\540.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\541.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\542.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\543.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\544.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\545.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\546.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\547.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\548.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\549.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\550.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\551.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\552.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\553.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\554.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\555.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\556.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\557.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\558.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\559.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\560.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\561.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\562.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\563.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\564.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\565.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\566.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\567.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\568.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\569.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\570.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\571.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\572.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\573.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\574.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\575.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\576.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\577.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\578.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\579.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\580.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\581.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\582.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\583.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\584.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\585.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\586.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\587.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\588.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\589.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\590.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\591.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\592.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\593.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\594.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\595.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\596.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\597.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\598.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\599.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\600.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\601.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\602.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\603.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\604.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\605.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\606.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\607.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\608.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\609.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\610.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\611.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\612.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\613.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\614.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\615.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\616.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\617.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\618.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\619.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\620.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\621.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\622.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\623.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\624.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\625.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\626.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\627.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\628.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\629.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\630.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\631.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\632.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\633.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\634.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\635.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\636.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\637.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\638.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\639.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\640.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\641.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\642.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\643.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\644.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\645.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\646.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\647.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\648.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\649.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\650.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\651.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\652.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\653.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\654.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\655.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\656.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\657.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\658.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\659.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\660.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\661.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\662.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\663.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\664.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\665.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\666.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\667.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\668.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\669.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\670.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\671.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\672.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\673.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\674.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\675.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\676.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\677.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\678.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\679.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\680.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\681.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\682.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\683.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\684.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\685.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\686.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\687.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\688.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\689.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\690.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\691.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\692.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\693.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\694.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\695.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\696.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\697.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\698.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\699.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\7_resized_images_700\yes\700.png
#
# All images have been copied and resized.

# %% [markdown]
# **resizing (224 x 224) for different folder structure**

# %%
# Function to copy and resize images in the specified folder structure
def copy_and_resize_images(source_dir, target_dir, new_size=(224, 224)):
    """
    Copies the folder structure from source_dir to target_dir and resizes all images in the process.
    """
    # Create the target directory if it doesn't exist
    os.makedirs(target_dir, exist_ok=True)

    # Traverse the source directory
    for set_folder in os.listdir(source_dir):
        source_set_path = os.path.join(source_dir, set_folder)

        # Process only directories
        if os.path.isdir(source_set_path):
            target_set_path = os.path.join(target_dir, set_folder)

            # Create the corresponding directory in the target path
            os.makedirs(target_set_path, exist_ok=True)

            # Process image files within the current set folder
            for file in os.listdir(source_set_path):
                if file.endswith('.png'):
                    source_file_path = os.path.join(source_set_path, file)
                    target_file_path = os.path.join(target_set_path, file)

                    # Resize and save the image in the target directory
                    try:
                        with Image.open(source_file_path) as img:
                            resized_img = img.resize(new_size, Image.LANCZOS)  # High-quality resizing
                            resized_img.save(target_file_path)
                            print(f"Resized and saved: {target_file_path}")
                    except Exception as e:
                        print(f"Failed to process {source_file_path}: {e}")

# Define the source and target directories
source_directory = r'D:\PycharmProjects\pro_dis_2\collected_data\3_singleimg_120'
target_directory = r'D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120'

# Run the function
copy_and_resize_images(source_directory, target_directory)

print("\nAll images have been copied and resized.")
# Out:
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_001\001_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_001\001_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_001\001_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_001\001_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_001\001_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_001\001_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_001\001_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_001\001_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_001\001_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_001\001_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_002\002_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_002\002_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_002\002_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_002\002_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_002\002_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_002\002_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_002\002_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_002\002_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_002\002_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_002\002_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_003\003_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_003\003_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_003\003_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_003\003_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_003\003_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_003\003_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_003\003_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_003\003_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_003\003_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_003\003_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_004\004_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_004\004_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_004\004_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_004\004_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_004\004_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_004\004_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_004\004_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_004\004_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_004\004_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_004\004_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_005\005_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_005\005_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_005\005_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_005\005_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_005\005_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_005\005_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_005\005_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_005\005_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_005\005_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_005\005_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_006\006_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_006\006_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_006\006_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_006\006_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_006\006_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_006\006_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_006\006_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_006\006_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_006\006_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_006\006_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_007\007_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_007\007_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_007\007_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_007\007_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_007\007_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_007\007_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_007\007_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_007\007_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_007\007_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_007\007_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_008\008_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_008\008_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_008\008_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_008\008_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_008\008_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_008\008_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_008\008_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_008\008_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_008\008_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_008\008_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_009\009_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_009\009_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_009\009_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_009\009_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_009\009_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_009\009_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_009\009_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_009\009_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_009\009_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_009\009_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_010\010_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_010\010_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_010\010_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_010\010_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_010\010_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_010\010_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_010\010_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_010\010_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_010\010_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_010\010_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_011\011_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_011\011_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_011\011_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_011\011_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_011\011_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_011\011_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_011\011_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_011\011_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_011\011_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_011\011_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_012\012_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_012\012_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_012\012_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_012\012_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_012\012_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_012\012_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_012\012_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_012\012_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_012\012_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_012\012_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_013\013_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_013\013_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_013\013_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_013\013_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_013\013_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_013\013_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_013\013_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_013\013_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_013\013_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_013\013_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_014\014_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_014\014_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_014\014_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_014\014_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_014\014_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_014\014_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_014\014_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_014\014_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_014\014_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_014\014_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_015\015_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_015\015_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_015\015_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_015\015_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_015\015_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_015\015_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_015\015_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_015\015_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_015\015_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_015\015_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_016\016_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_016\016_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_016\016_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_016\016_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_016\016_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_016\016_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_016\016_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_016\016_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_016\016_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_016\016_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_017\017_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_017\017_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_017\017_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_017\017_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_017\017_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_017\017_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_017\017_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_017\017_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_017\017_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_017\017_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_018\018_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_018\018_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_018\018_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_018\018_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_018\018_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_018\018_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_018\018_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_018\018_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_018\018_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_018\018_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_019\019_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_019\019_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_019\019_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_019\019_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_019\019_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_019\019_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_019\019_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_019\019_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_019\019_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_019\019_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_020\020_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_020\020_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_020\020_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_020\020_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_020\020_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_020\020_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_020\020_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_020\020_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_020\020_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_020\020_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_021\021_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_021\021_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_021\021_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_021\021_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_021\021_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_021\021_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_021\021_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_021\021_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_021\021_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_021\021_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_022\022_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_022\022_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_022\022_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_022\022_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_022\022_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_022\022_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_022\022_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_022\022_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_022\022_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_022\022_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_023\023_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_023\023_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_023\023_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_023\023_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_023\023_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_023\023_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_023\023_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_023\023_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_023\023_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_023\023_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_024\024_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_024\024_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_024\024_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_024\024_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_024\024_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_024\024_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_024\024_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_024\024_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_024\024_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_024\024_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_025\025_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_025\025_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_025\025_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_025\025_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_025\025_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_025\025_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_025\025_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_025\025_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_025\025_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_025\025_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_026\026_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_026\026_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_026\026_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_026\026_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_026\026_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_026\026_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_026\026_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_026\026_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_026\026_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_026\026_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_027\027_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_027\027_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_027\027_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_027\027_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_027\027_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_027\027_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_027\027_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_027\027_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_027\027_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_027\027_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_028\028_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_028\028_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_028\028_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_028\028_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_028\028_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_028\028_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_028\028_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_028\028_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_028\028_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_028\028_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_029\029_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_029\029_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_029\029_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_029\029_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_029\029_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_029\029_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_029\029_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_029\029_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_029\029_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_029\029_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_030\030_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_030\030_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_030\030_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_030\030_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_030\030_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_030\030_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_030\030_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_030\030_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_030\030_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_030\030_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_031\031_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_031\031_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_031\031_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_031\031_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_031\031_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_031\031_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_031\031_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_031\031_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_031\031_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_031\031_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_032\032_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_032\032_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_032\032_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_032\032_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_032\032_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_032\032_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_032\032_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_032\032_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_032\032_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_032\032_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_033\033_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_033\033_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_033\033_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_033\033_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_033\033_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_033\033_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_033\033_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_033\033_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_033\033_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_033\033_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_034\034_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_034\034_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_034\034_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_034\034_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_034\034_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_034\034_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_034\034_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_034\034_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_034\034_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_034\034_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_035\035_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_035\035_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_035\035_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_035\035_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_035\035_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_035\035_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_035\035_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_035\035_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_035\035_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_035\035_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_036\036_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_036\036_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_036\036_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_036\036_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_036\036_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_036\036_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_036\036_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_036\036_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_036\036_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_036\036_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_037\037_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_037\037_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_037\037_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_037\037_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_037\037_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_037\037_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_037\037_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_037\037_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_037\037_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_037\037_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_038\038_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_038\038_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_038\038_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_038\038_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_038\038_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_038\038_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_038\038_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_038\038_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_038\038_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_038\038_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_039\039_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_039\039_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_039\039_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_039\039_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_039\039_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_039\039_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_039\039_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_039\039_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_039\039_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_039\039_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_040\040_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_040\040_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_040\040_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_040\040_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_040\040_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_040\040_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_040\040_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_040\040_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_040\040_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_040\040_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_041\041_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_041\041_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_041\041_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_041\041_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_041\041_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_041\041_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_041\041_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_041\041_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_041\041_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_041\041_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_042\042_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_042\042_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_042\042_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_042\042_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_042\042_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_042\042_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_042\042_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_042\042_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_042\042_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_042\042_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_043\043_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_043\043_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_043\043_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_043\043_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_043\043_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_043\043_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_043\043_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_043\043_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_043\043_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_043\043_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_044\044_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_044\044_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_044\044_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_044\044_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_044\044_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_044\044_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_044\044_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_044\044_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_044\044_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_044\044_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_045\045_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_045\045_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_045\045_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_045\045_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_045\045_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_045\045_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_045\045_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_045\045_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_045\045_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_045\045_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_046\046_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_046\046_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_046\046_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_046\046_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_046\046_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_046\046_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_046\046_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_046\046_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_046\046_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_046\046_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_047\047_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_047\047_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_047\047_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_047\047_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_047\047_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_047\047_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_047\047_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_047\047_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_047\047_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_047\047_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_048\048_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_048\048_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_048\048_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_048\048_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_048\048_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_048\048_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_048\048_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_048\048_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_048\048_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_048\048_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_049\049_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_049\049_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_049\049_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_049\049_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_049\049_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_049\049_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_049\049_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_049\049_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_049\049_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_049\049_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_050\050_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_050\050_cup.png
# ...
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_104\104_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_104\104_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_104\104_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_105\105_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_105\105_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_105\105_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_105\105_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_105\105_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_105\105_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_105\105_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_105\105_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_105\105_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_105\105_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_106\106_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_106\106_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_106\106_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_106\106_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_106\106_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_106\106_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_106\106_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_106\106_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_106\106_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_106\106_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_107\107_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_107\107_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_107\107_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_107\107_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_107\107_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_107\107_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_107\107_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_107\107_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_107\107_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_107\107_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_108\108_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_108\108_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_108\108_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_108\108_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_108\108_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_108\108_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_108\108_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_108\108_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_108\108_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_108\108_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_109\109_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_109\109_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_109\109_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_109\109_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_109\109_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_109\109_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_109\109_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_109\109_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_109\109_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_109\109_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_110\110_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_110\110_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_110\110_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_110\110_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_110\110_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_110\110_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_110\110_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_110\110_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_110\110_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_110\110_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_111\111_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_111\111_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_111\111_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_111\111_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_111\111_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_111\111_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_111\111_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_111\111_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_111\111_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_111\111_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_112\112_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_112\112_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_112\112_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_112\112_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_112\112_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_112\112_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_112\112_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_112\112_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_112\112_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_112\112_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_113\113_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_113\113_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_113\113_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_113\113_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_113\113_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_113\113_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_113\113_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_113\113_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_113\113_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_113\113_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_114\114_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_114\114_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_114\114_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_114\114_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_114\114_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_114\114_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_114\114_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_114\114_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_114\114_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_114\114_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_115\115_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_115\115_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_115\115_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_115\115_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_115\115_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_115\115_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_115\115_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_115\115_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_115\115_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_115\115_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_116\116_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_116\116_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_116\116_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_116\116_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_116\116_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_116\116_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_116\116_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_116\116_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_116\116_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_116\116_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_117\117_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_117\117_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_117\117_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_117\117_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_117\117_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_117\117_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_117\117_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_117\117_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_117\117_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_117\117_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_118\118_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_118\118_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_118\118_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_118\118_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_118\118_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_118\118_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_118\118_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_118\118_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_118\118_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_118\118_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_119\119_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_119\119_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_119\119_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_119\119_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_119\119_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_119\119_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_119\119_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_119\119_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_119\119_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_119\119_red.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_120\120_bat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_120\120_cup.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_120\120_drop.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_120\120_eat.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_120\120_fish.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_120\120_hot.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_120\120_jump.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_120\120_milk.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_120\120_pen.png
# Resized and saved: D:\PycharmProjects\pro_dis_2\collected_data\4_resized_120\set_120\120_red.png
#
# All images have been copied and resized.

# %% [markdown]
# **(one-time) dividing total datasets into specific numbers**

# %%
# Total numbers to distribute
total = 40

# Step 1: Calculate the number of elements for each group based on percentage
Train_count = int(0.7 * total)  # 60% of 40
Validation_count = int(0.15 * total)  # 20% of 40
Test_count = int(0.15 * total)  # 20% of 40

# Generate the original list of numbers
original_numbers = set(range(1, total + 1))

# Print calculated counts
print(f"Distribution counts of {total}:\nA (Train): {Train_count}, B (Validation): {Validation_count}, C (Test): {Test_count}\n")

# Step 2: Generate numbers from 1 to 40 and shuffle them
numbers = list(original_numbers)
random.shuffle(numbers)

# Step 3: Distribute the numbers into A, B, and C
Train = numbers[:Train_count]  # 24 numbers for A
Validation = numbers[Train_count:Train_count + Validation_count]  # 8 numbers for B
Test = numbers[Train_count + Validation_count:Train_count + Validation_count + Test_count]  # 8 numbers for C

# Combine all distributed numbers and convert to a set
distributed_numbers = set(Train + Validation + Test)

# Find the missing number by subtracting sets
missing_number = original_numbers - distributed_numbers

# Step 4: Sort the lists in ascending order and format numbers as strings with leading zeros
Train_sorted = [f"{num:03}" for num in sorted(Train)]
Validation_sorted = [f"{num:03}" for num in sorted(Validation)]
Test_sorted = [f"{num:03}" for num in sorted(Test)]

# Combine B and C and sort
Validation_Test_combined_sorted = sorted(Validation_sorted + Test_sorted)

print("Sorted Distribution:\n")
print(f"Train ({Train_count} numbers): {Train_sorted}\n")
print(f"Validation ({Validation_count} numbers): {Validation_sorted}\n")
print(f"Test ({Test_count} numbers): {Test_sorted}\n")
print(f"Validation and Test combined ({Validation_count + Test_count} numbers): {Validation_Test_combined_sorted}\n")
print(f"The missing number is: {missing_number}")
# Out:
# Distribution counts of 60:
# A (Train): 42, B (Validation): 9, C (Test): 9
#
# Sorted Distribution:
#
# Train (42 numbers): ['001', '002', '003', '004', '006', '012', '013', '014', '015', '017', '018', '019', '021', '023', '024', '026', '027', '028', '029', '030', '033', '034', '035', '036', '037', '038', '039', '040', '041', '043', '045', '046', '048', '050', '051', '052', '053', '054', '055', '056', '057', '059']
#
# Validation (9 numbers): ['007', '008', '010', '031', '032', '042', '047', '049', '060']
#
# Test (9 numbers): ['005', '009', '011', '016', '020', '022', '025', '044', '058']
#
# Validation and Test combined (18 numbers): ['005', '007', '008', '009', '010', '011', '016', '020', '022', '025', '031', '032', '042', '044', '047', '049', '058', '060']
#
# The missing number is: set()

# %% [markdown]
# **assigning specific images to Train, Test and Validation folders**

# %%
# Define the source and destination directories
source_dir = r'D:\New folder\6_organised_images_60'
destination_dir = r'D:\New folder\7_final_images_60'

# Copy word folders from source to Train, Test, and Validation subfolders in the destination
subfolders = ['Train', 'Test', 'Validation']
for subfolder in subfolders:
    subfolder_path = os.path.join(destination_dir, subfolder)
    for word_folder in os.listdir(source_dir):
        source_word_path = os.path.join(source_dir, word_folder)
        dest_word_path = os.path.join(subfolder_path, word_folder)

        if os.path.isdir(source_word_path):
            # Copy the word folder to the subfolder
            shutil.copytree(source_word_path, dest_word_path, dirs_exist_ok=True)
            print(f"Copied {word_folder} to {subfolder_path}")

print("\nAll word folders have been copied to Train, Test, and Validation.")
# Out:
# Copied bat to D:\New folder\7_final_images_60\Train
# Copied cup to D:\New folder\7_final_images_60\Train
# Copied drop to D:\New folder\7_final_images_60\Train
# Copied eat to D:\New folder\7_final_images_60\Train
# Copied bat to D:\New folder\7_final_images_60\Test
# Copied cup to D:\New folder\7_final_images_60\Test
# Copied drop to D:\New folder\7_final_images_60\Test
# Copied eat to D:\New folder\7_final_images_60\Test
# Copied bat to D:\New folder\7_final_images_60\Validation
# Copied cup to D:\New folder\7_final_images_60\Validation
# Copied drop to D:\New folder\7_final_images_60\Validation
# Copied eat to D:\New folder\7_final_images_60\Validation
#
# All word folders have been copied to Train, Test, and Validation.

# %%
# Define the parent directory for final_images_five\Test
final_dataset2_dir = r'D:\New folder\7_final_images_60\Train'

# List of prefixes to delete (e.g., '02.png', '03.png', etc.)
prefixes_to_delete = ['005', '007', '008', '009', '010', '011', '016', '020', '022', '025', '031', '032', '042', '044', '047', '049', '058', '060']

# Iterate through each folder in final_images_five\Test
for word_folder in os.listdir(final_dataset2_dir):
    word_folder_path = os.path.join(final_dataset2_dir, word_folder)
    if os.path.isdir(word_folder_path):
        # Iterate through files in the current word folder
        for file_name in os.listdir(word_folder_path):
            # Check if the file matches the prefix pattern
            if file_name.endswith('.png'):
                file_prefix = file_name.split('.')[0]  # Extract the prefix (e.g., '02' from '02.png')
                if file_prefix in prefixes_to_delete:
                    file_path = os.path.join(word_folder_path, file_name)
                    os.remove(file_path)
                    print(f"Deleted {file_path}")

print("\nSpecified files have been deleted in each folder.")
# Out:
# Deleted D:\New folder\7_final_images_60\Train\bat\005.png
# Deleted D:\New folder\7_final_images_60\Train\bat\007.png
# Deleted D:\New folder\7_final_images_60\Train\bat\008.png
# Deleted D:\New folder\7_final_images_60\Train\bat\009.png
# Deleted D:\New folder\7_final_images_60\Train\bat\010.png
# Deleted D:\New folder\7_final_images_60\Train\bat\011.png
# Deleted D:\New folder\7_final_images_60\Train\bat\016.png
# Deleted D:\New folder\7_final_images_60\Train\bat\020.png
# Deleted D:\New folder\7_final_images_60\Train\bat\022.png
# Deleted D:\New folder\7_final_images_60\Train\bat\025.png
# Deleted D:\New folder\7_final_images_60\Train\bat\031.png
# Deleted D:\New folder\7_final_images_60\Train\bat\032.png
# Deleted D:\New folder\7_final_images_60\Train\bat\042.png
# Deleted D:\New folder\7_final_images_60\Train\bat\044.png
# Deleted D:\New folder\7_final_images_60\Train\bat\047.png
# Deleted D:\New folder\7_final_images_60\Train\bat\049.png
# Deleted D:\New folder\7_final_images_60\Train\bat\058.png
# Deleted D:\New folder\7_final_images_60\Train\bat\060.png
# Deleted D:\New folder\7_final_images_60\Train\cup\005.png
# Deleted D:\New folder\7_final_images_60\Train\cup\007.png
# Deleted D:\New folder\7_final_images_60\Train\cup\008.png
# Deleted D:\New folder\7_final_images_60\Train\cup\009.png
# Deleted D:\New folder\7_final_images_60\Train\cup\010.png
# Deleted D:\New folder\7_final_images_60\Train\cup\011.png
# Deleted D:\New folder\7_final_images_60\Train\cup\016.png
# Deleted D:\New folder\7_final_images_60\Train\cup\020.png
# Deleted D:\New folder\7_final_images_60\Train\cup\022.png
# Deleted D:\New folder\7_final_images_60\Train\cup\025.png
# Deleted D:\New folder\7_final_images_60\Train\cup\031.png
# Deleted D:\New folder\7_final_images_60\Train\cup\032.png
# Deleted D:\New folder\7_final_images_60\Train\cup\042.png
# Deleted D:\New folder\7_final_images_60\Train\cup\044.png
# Deleted D:\New folder\7_final_images_60\Train\cup\047.png
# Deleted D:\New folder\7_final_images_60\Train\cup\049.png
# Deleted D:\New folder\7_final_images_60\Train\cup\058.png
# Deleted D:\New folder\7_final_images_60\Train\cup\060.png
# Deleted D:\New folder\7_final_images_60\Train\drop\005.png
# Deleted D:\New folder\7_final_images_60\Train\drop\007.png
# Deleted D:\New folder\7_final_images_60\Train\drop\008.png
# Deleted D:\New folder\7_final_images_60\Train\drop\009.png
# Deleted D:\New folder\7_final_images_60\Train\drop\010.png
# Deleted D:\New folder\7_final_images_60\Train\drop\011.png
# Deleted D:\New folder\7_final_images_60\Train\drop\016.png
# Deleted D:\New folder\7_final_images_60\Train\drop\020.png
# Deleted D:\New folder\7_final_images_60\Train\drop\022.png
# Deleted D:\New folder\7_final_images_60\Train\drop\025.png
# Deleted D:\New folder\7_final_images_60\Train\drop\031.png
# Deleted D:\New folder\7_final_images_60\Train\drop\032.png
# Deleted D:\New folder\7_final_images_60\Train\drop\042.png
# Deleted D:\New folder\7_final_images_60\Train\drop\044.png
# Deleted D:\New folder\7_final_images_60\Train\drop\047.png
# Deleted D:\New folder\7_final_images_60\Train\drop\049.png
# Deleted D:\New folder\7_final_images_60\Train\drop\058.png
# Deleted D:\New folder\7_final_images_60\Train\drop\060.png
# Deleted D:\New folder\7_final_images_60\Train\eat\005.png
# Deleted D:\New folder\7_final_images_60\Train\eat\007.png
# Deleted D:\New folder\7_final_images_60\Train\eat\008.png
# Deleted D:\New folder\7_final_images_60\Train\eat\009.png
# Deleted D:\New folder\7_final_images_60\Train\eat\010.png
# Deleted D:\New folder\7_final_images_60\Train\eat\011.png
# Deleted D:\New folder\7_final_images_60\Train\eat\016.png
# Deleted D:\New folder\7_final_images_60\Train\eat\020.png
# Deleted D:\New folder\7_final_images_60\Train\eat\022.png
# Deleted D:\New folder\7_final_images_60\Train\eat\025.png
# Deleted D:\New folder\7_final_images_60\Train\eat\031.png
# Deleted D:\New folder\7_final_images_60\Train\eat\032.png
# Deleted D:\New folder\7_final_images_60\Train\eat\042.png
# Deleted D:\New folder\7_final_images_60\Train\eat\044.png
# Deleted D:\New folder\7_final_images_60\Train\eat\047.png
# Deleted D:\New folder\7_final_images_60\Train\eat\049.png
# Deleted D:\New folder\7_final_images_60\Train\eat\058.png
# Deleted D:\New folder\7_final_images_60\Train\eat\060.png
#
# Specified files have been deleted in each folder.
