# %%
import os
import cv2
import random
import numpy as np
import re
import tensorflow as tf
# import keras._tf_keras.keras.models
from datetime import datetime
import shutil
from concurrent.futures import ThreadPoolExecutor, as_completed
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img, ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.applications import resnet50, efficientnet

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# 1. Extracting even number of frames from the videos (original_dataset_even_frames folder)

# %%
def extract_frames_with_priority_deletion(video_path, output_dir, gray_output_dir, target_frames=60):
    """
    Extract frames focusing on the middle section of the video and save both RGB and grayscale versions.
    If the video has fewer than 60 frames, copy the last frame to fill the deficit.
    If the video has more than 60 frames, delete 25% of extra frames from the start and 75% from the end.

    :param video_path: Path to the video file.
    :param output_dir: Directory where the RGB frames will be saved.
    :param gray_output_dir: Directory where the grayscale frames will be saved.
    :param target_frames: The number of frames to extract (default 60).
    """
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Create output directories if they don't exist
    os.makedirs(output_dir, exist_ok=True)
    os.makedirs(gray_output_dir, exist_ok=True)

    # Read and store all frames
    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)

    # If the total number of frames is less than the target, copy the last frame to fill the gap
    if total_frames < target_frames:
        # Save all existing frames first
        for i in range(total_frames):
            # Save RGB frame
            frame_filename_rgb = os.path.join(output_dir, f"frame{i+1:04d}.jpg")
            cv2.imwrite(frame_filename_rgb, frames[i])

            # Convert to grayscale and save
            gray_frame = cv2.cvtColor(frames[i], cv2.COLOR_BGR2GRAY)
            frame_filename_gray = os.path.join(gray_output_dir, f"frame{i+1:04d}.jpg")
            cv2.imwrite(frame_filename_gray, gray_frame)

        # Copy the last frame to fill the deficit
        last_frame = frames[-1]
        for i in range(total_frames, target_frames):
            # Save last RGB frame
            frame_filename_rgb = os.path.join(output_dir, f"frame{i+1:04d}.jpg")
            cv2.imwrite(frame_filename_rgb, last_frame)

            # Convert last frame to grayscale and save
            gray_last_frame = cv2.cvtColor(last_frame, cv2.COLOR_BGR2GRAY)
            frame_filename_gray = os.path.join(gray_output_dir, f"frame{i+1:04d}.jpg")
            cv2.imwrite(frame_filename_gray, gray_last_frame)

        # print(f"Copied last frame to fill the deficit for {video_path}.")
        cap.release()
        return

    # If the video has more than the target number of frames, prioritize deleting from start and end
    if total_frames > target_frames:
        frames_to_delete = total_frames - target_frames
        delete_from_end = int(frames_to_delete * 0.75)  # 75% of frames to delete from the end
        delete_from_start = frames_to_delete - delete_from_end  # 25% from the start

        middle_start = delete_from_start
        middle_end = total_frames - delete_from_end
    else:
        # Calculate the start and end points to extract the middle section
        middle_start = max((total_frames // 2) - int(target_frames // 1.5), 0)
        middle_end = min(middle_start + target_frames, total_frames)

    extracted_frame_count = 0

    # Iterate through the middle section and save frames
    for i in range(middle_start, middle_end):
        # Save RGB frame
        frame_filename_rgb = os.path.join(output_dir, f"frame{extracted_frame_count + 1:04d}.jpg")
        cv2.imwrite(frame_filename_rgb, frames[i])

        # Convert to grayscale and save
        gray_frame = cv2.cvtColor(frames[i], cv2.COLOR_BGR2GRAY)
        frame_filename_gray = os.path.join(gray_output_dir, f"frame{extracted_frame_count + 1:04d}.jpg")
        cv2.imwrite(frame_filename_gray, gray_frame)

        extracted_frame_count += 1

    cap.release()
    # print(f"Extracted {extracted_frame_count} frames from {video_path}")

def process_video(video_file, video_folder, output_folder_rgb, output_folder_gray, count):
    video_path = os.path.join(video_folder, video_file)
    word_output_dir_rgb = os.path.join(output_folder_rgb, os.path.splitext(video_file)[0])
    word_output_dir_gray = os.path.join(output_folder_gray, os.path.splitext(video_file)[0])
    print(f"{count}. Processing {video_file}...")
    extract_frames_with_priority_deletion(video_path, word_output_dir_rgb, word_output_dir_gray, target_frames=60)

def run_multithreading(video_folder, output_folder_rgb, output_folder_gray):
    video_files = [f for f in os.listdir(video_folder) if f.endswith('.mp4')]

    # Use ThreadPoolExecutor to process videos in parallel
    with ThreadPoolExecutor(max_workers=8) as executor:  # Adjust max_workers to the number of threads you want
        future_to_video = {executor.submit(process_video, video_file, video_folder, output_folder_rgb, output_folder_gray, count): video_file
                           for count, video_file in enumerate(video_files, start=1)}

        # Monitor the progress
        for future in as_completed(future_to_video):
            video_file = future_to_video[future]
            try:
                future.result()
            except Exception as exc:
                print(f'{video_file} generated an exception: {exc}')

video_folder = r'D:\pro_dis\videos\HD_720p'  # Your video folder path
output_folder_rgb = r'D:\pro_dis\original_dataset_even_frames'  # Folder to save RGB frames
output_folder_gray = r'D:\pro_dis\original_gray_dataset_even_frames'  # Folder to save grayscale frames

run_multithreading(video_folder, output_folder_rgb, output_folder_gray)

print("\nRGB and grayscale frame extraction complete!")
# Out:
# 1. Processing ace.mp4...
# 2. Processing act.mp4...
# 3. Processing add.mp4...
# 4. Processing age.mp4...
# 5. Processing aid.mp4...
# 6. Processing aids.mp4...
# 7. Processing aim.mp4...
# 8. Processing air.mp4...
# 9. Processing all.mp4...10. Processing anal.mp4...
#
# 11. Processing and.mp4...
# 12. Processing app.mp4...
# 13. Processing approx.mp4...
# 14. Processing arc.mp4...
# 15. Processing arch.mp4...
# 16. Processing are.mp4...
# 17. Processing arm.mp4...
# 18. Processing armed.mp4...
# 19. Processing arms.mp4...
# 20. Processing art.mp4...
# 21. Processing arts.mp4...22. Processing ash.mp4...
#
# 23. Processing ask.mp4...
# 24. Processing ass.mp4...
# 25. Processing aunt.mp4...
# 26. Processing auto.mp4...
# 27. Processing babe.mp4...
# 28. Processing back.mp4...
# 29. Processing bad.mp4...
# 30. Processing bag.mp4...
# 31. Processing bags.mp4...32. Processing bald.mp4...
#
# 33. Processing ball.mp4...
# 34. Processing balls.mp4...
# 35. Processing ban.mp4...
# 36. Processing band.mp4...
# 37. Processing bang.mp4...
# 38. Processing bank.mp4...
# 39. Processing bar.mp4...
# 40. Processing bare.mp4...
# 41. Processing base.mp4...
# 42. Processing bass.mp4...
# 43. Processing bat.mp4...
# 44. Processing batch.mp4...
# 45. Processing bath.mp4...
# 46. Processing bay.mp4...
# 47. Processing beach.mp4...48. Processing beam.mp4...
#
# 49. Processing bean.mp4...50. Processing bear.mp4...
#
# 51. Processing beast.mp4...
# 52. Processing beat.mp4...
# 53. Processing bed.mp4...
# 54. Processing beef.mp4...
# 55. Processing been.mp4...
# 56. Processing beer.mp4...
# 57. Processing beg.mp4...
# 58. Processing bell.mp4...
# 59. Processing belt.mp4...
# 60. Processing ben.mp4...
# 61. Processing bench.mp4...
# 62. Processing bend.mp4...
# 63. Processing best.mp4...
# 64. Processing bet.mp4...
# 65. Processing bid.mp4...
# 66. Processing big.mp4...
# 67. Processing bike.mp4...
# 68. Processing bill.mp4...
# 69. Processing bin.mp4...
# 70. Processing bind.mp4...
# 71. Processing bird.mp4...
# 72. Processing birth.mp4...
# 73. Processing bit.mp4...
# 74. Processing bitch.mp4...
# 75. Processing bite.mp4...
# 76. Processing black.mp4...
# 77. Processing blade.mp4...
# 78. Processing blame.mp4...
# 79. Processing bland.mp4...
# 80. Processing blank.mp4...
# 81. Processing blast.mp4...
# 82. Processing bleak.mp4...
# 83. Processing blend.mp4...
# 84. Processing blind.mp4...
# 85. Processing block.mp4...
# 86. Processing blond.mp4...
# 87. Processing blonde.mp4...
# 88. Processing blood.mp4...
# 89. Processing blow.mp4...
# 90. Processing blue.mp4...
# 91. Processing blues.mp4...
# 92. Processing blunt.mp4...
# 93. Processing board.mp4...
# 94. Processing boast.mp4...
# 95. Processing boat.mp4...
# 96. Processing bob.mp4...
# 97. Processing boil.mp4...
# 98. Processing bold.mp4...
# 99. Processing bomb.mp4...
# 100. Processing bond.mp4...
# 101. Processing bone.mp4...
# 102. Processing boob.mp4...
# 103. Processing book.mp4...
# 104. Processing boost.mp4...
# 105. Processing boot.mp4...
# 106. Processing booth.mp4...
# 107. Processing boots.mp4...
# 108. Processing born.mp4...
# 109. Processing boss.mp4...
# 110. Processing both.mp4...
# 111. Processing bought.mp4...
# 112. Processing bounce.mp4...
# 113. Processing bound.mp4...
# 114. Processing bow.mp4...
# 115. Processing bowl.mp4...
# 116. Processing box.mp4...
# 117. Processing boy.mp4...
# 118. Processing bra.mp4...
# 119. Processing brad.mp4...
# 120. Processing brain.mp4...
# 121. Processing brake.mp4...
# 122. Processing branch.mp4...
# 123. Processing brand.mp4...
# 124. Processing brass.mp4...
# 125. Processing brave.mp4...
# 126. Processing breach.mp4...
# 127. Processing bread.mp4...
# 128. Processing break.mp4...
# 129. Processing breast.mp4...
# 130. Processing breath.mp4...
# 131. Processing breathe.mp4...
# 132. Processing breed.mp4...
# 133. Processing brick.mp4...
# 134. Processing bride.mp4...
# 135. Processing bridge.mp4...
# 136. Processing brief.mp4...
# 137. Processing bright.mp4...
# 138. Processing bring.mp4...
# 139. Processing brisk.mp4...
# 140. Processing broad.mp4...
# 141. Processing broke.mp4...
# 142. Processing bronze.mp4...
# 143. Processing broom.mp4...
# 144. Processing brought.mp4...
# 145. Processing brown.mp4...
# 146. Processing browse.mp4...
# 147. Processing brush.mp4...
# 148. Processing bug.mp4...
# 149. Processing bugs.mp4...
# 150. Processing build.mp4...
# 151. Processing built.mp4...
# 152. Processing bulk.mp4...
# 153. Processing bull.mp4...
# 154. Processing bunch.mp4...
# 155. Processing burn.mp4...
# 156. Processing burst.mp4...
# 157. Processing bus.mp4...
# 158. Processing bush.mp4...
# 159. Processing bust.mp4...
# 160. Processing but.mp4...
# 161. Processing butt.mp4...
# 162. Processing buy.mp4...
# 163. Processing buzz.mp4...
# 164. Processing byte.mp4...
# 165. Processing cab.mp4...
# 166. Processing cache.mp4...
# 167. Processing cad.mp4...
# 168. Processing cake.mp4...
# 169. Processing call.mp4...
# 170. Processing calm.mp4...
# 171. Processing cam.mp4...
# 172. Processing came.mp4...
# 173. Processing camp.mp4...
# 174. Processing can.mp4...
# 175. Processing cap.mp4...
# 176. Processing cape.mp4...
# 177. Processing caps.mp4...
# 178. Processing car.mp4...
# 179. Processing card.mp4...
# 180. Processing cards.mp4...
# 181. Processing care.mp4...
# 182. Processing carl.mp4...
# 183. Processing cart.mp4...
# 184. Processing carve.mp4...
# 185. Processing case.mp4...
# 186. Processing cash.mp4...
# 187. Processing cast.mp4...
# 188. Processing cat.mp4...
# 189. Processing catch.mp4...
# 190. Processing caught.mp4...
# 191. Processing cause.mp4...
# 192. Processing cease.mp4...
# 193. Processing cell.mp4...
# 194. Processing cent.mp4...
# 195. Processing chad.mp4...
# 196. Processing chain.mp4...
# 197. Processing chair.mp4...
# 198. Processing chance.mp4...
# 199. Processing change.mp4...
# 200. Processing char.mp4...
# 201. Processing charge.mp4...
# 202. Processing charged.mp4...
# 203. Processing charm.mp4...
# 204. Processing chart.mp4...
# 205. Processing chase.mp4...
# 206. Processing chat.mp4...
# 207. Processing cheap.mp4...
# 208. Processing cheat.mp4...
# 209. Processing check.mp4...
# 210. Processing checked.mp4...
# 211. Processing cheek.mp4...
# 212. Processing cheer.mp4...
# 213. Processing cheese.mp4...
# 214. Processing chef.mp4...
# 215. Processing cheque.mp4...
# 216. Processing chess.mp4...
# 217. Processing chest.mp4...
# 218. Processing chick.mp4...
# 219. Processing chief.mp4...
# 220. Processing child.mp4...
# 221. Processing chip.mp4...
# 222. Processing choice.mp4...
# 223. Processing choose.mp4...
# 224. Processing chose.mp4...
# 225. Processing chrome.mp4...
# 226. Processing chuck.mp4...
# 227. Processing church.mp4...
# 228. Processing cite.mp4...
# 229. Processing claim.mp4...
# 230. Processing clash.mp4...
# 231. Processing class.mp4...
# 232. Processing clause.mp4...
# 233. Processing clay.mp4...
# 234. Processing clean.mp4...
# 235. Processing clear.mp4...
# 236. Processing clerk.mp4...
# 237. Processing click.mp4...
# 238. Processing cliff.mp4...
# 239. Processing climb.mp4...
# 240. Processing cling.mp4...
# 241. Processing clip.mp4...
# 242. Processing clips.mp4...
# 243. Processing clock.mp4...
# 244. Processing clone.mp4...
# 245. Processing close.mp4...
# 246. Processing closed.mp4...
# 247. Processing cloth.mp4...
# 248. Processing clothes.mp4...
# 249. Processing cloud.mp4...
# 250. Processing club.mp4...
# 251. Processing clue.mp4...
# 252. Processing clutch.mp4...
# 253. Processing coach.mp4...
# 254. Processing coal.mp4...
# 255. Processing coast.mp4...
# 256. Processing coat.mp4...
# 257. Processing cock.mp4...
# 258. Processing cod.mp4...
# 259. Processing code.mp4...
# 260. Processing coin.mp4...
# 261. Processing cold.mp4...
# 262. Processing com.mp4...
# 263. Processing come.mp4...
# 264. Processing con.mp4...
# 265. Processing cook.mp4...
# 266. Processing cool.mp4...
# 267. Processing cope.mp4...
# 268. Processing cord.mp4...
# 269. Processing core.mp4...
# 270. Processing corn.mp4...
# 271. Processing corps.mp4...
# 272. Processing cost.mp4...
# 273. Processing could.mp4...
# 274. Processing count.mp4...
# 275. Processing coup.mp4...
# 276. Processing court.mp4...
# 277. Processing cow.mp4...
# 278. Processing cox.mp4...279. Processing crack.mp4...
#
# 280. Processing craft.mp4...
# 281. Processing crap.mp4...
# 282. Processing crash.mp4...
# 283. Processing crawl.mp4...
# 284. Processing cream.mp4...
# 285. Processing creek.mp4...
# 286. Processing creep.mp4...
# 287. Processing crew.mp4...
# 288. Processing crime.mp4...
# 289. Processing crisp.mp4...
# 290. Processing crop.mp4...
# 291. Processing cross.mp4...
# 292. Processing crowd.mp4...
# 293. Processing crown.mp4...
# 294. Processing crude.mp4...295. Processing cruise.mp4...
#
# 296. Processing crush.mp4...
# 297. Processing cry.mp4...
# 298. Processing cup.mp4...
# 299. Processing cure.mp4...
# 300. Processing curl.mp4...
# 301. Processing curve.mp4...
# 302. Processing cut.mp4...
# 303. Processing cute.mp4...
# 304. Processing dad.mp4...
# 305. Processing dale.mp4...
# 306. Processing dam.mp4...
# 307. Processing damp.mp4...
# 308. Processing dan.mp4...
# 309. Processing dance.mp4...
# 310. Processing dare.mp4...
# 311. Processing dark.mp4...
# 312. Processing date.mp4...
# 313. Processing dates.mp4...
# 314. Processing dawn.mp4...
# 315. Processing day.mp4...
# 316. Processing days.mp4...
# 317. Processing dead.mp4...
# 318. Processing deaf.mp4...
# 319. Processing deal.mp4...
# 320. Processing dean.mp4...
# 321. Processing dear.mp4...
# 322. Processing death.mp4...
# 323. Processing debt.mp4...
# 324. Processing deck.mp4...
# 325. Processing deem.mp4...
# 326. Processing deep.mp4...
# 327. Processing deer.mp4...
# 328. Processing deft.mp4...
# 329. Processing den.mp4...
# 330. Processing depth.mp4...
# 331. Processing desk.mp4...
# 332. Processing dial.mp4...
# 333. Processing did.mp4...
# 334. Processing die.mp4...
# 335. Processing dig.mp4...
# 336. Processing dim.mp4...
# 337. Processing dip.mp4...
# 338. Processing dire.mp4...
# 339. Processing dirt.mp4...
# 340. Processing dish.mp4...
# 341. Processing disk.mp4...
# 342. Processing dive.mp4...
# 343. Processing do.mp4...
# 344. Processing dodge.mp4...
# 345. Processing doe.mp4...
# 346. Processing does.mp4...
# 347. Processing dog.mp4...
# 348. Processing dogs.mp4...
# 349. Processing doll.mp4...
# 350. Processing don.mp4...
# 351. Processing done.mp4...
# 352. Processing door.mp4...
# 353. Processing dose.mp4...
# 354. Processing dot.mp4...
# 355. Processing doubt.mp4...
# 356. Processing down.mp4...
# 357. Processing drab.mp4...
# 358. Processing draft.mp4...
# 359. Processing drag.mp4...
# 360. Processing drain.mp4...
# 361. Processing draw.mp4...
# 362. Processing drawn.mp4...
# 363. Processing dream.mp4...
# 364. Processing dress.mp4...
# 365. Processing drew.mp4...
# 366. Processing drift.mp4...
# 367. Processing drill.mp4...
# 368. Processing drink.mp4...
# 369. Processing drive.mp4...
# 370. Processing drop.mp4...
# 371. Processing drops.mp4...
# 372. Processing drown.mp4...
# 373. Processing drug.mp4...
# 374. Processing drum.mp4...
# 375. Processing drunk.mp4...
# 376. Processing dry.mp4...
# 377. Processing duck.mp4...
# 378. Processing due.mp4...
# 379. Processing duke.mp4...
# 380. Processing dull.mp4...
# 381. Processing dumb.mp4...
# 382. Processing dump.mp4...
# 383. Processing dust.mp4...
# 384. Processing dutch.mp4...
# 385. Processing each.mp4...
# 386. Processing ear.mp4...
# 387. Processing earl.mp4...
# 388. Processing earn.mp4...
# 389. Processing earth.mp4...
# 390. Processing ease.mp4...
# 391. Processing east.mp4...
# 392. Processing eat.mp4...
# 393. Processing edge.mp4...
# 394. Processing edit.mp4...
# 395. Processing egg.mp4...
# 396. Processing eight.mp4...
# 397. Processing elect.mp4...
# 398. Processing else.mp4...
# 399. Processing end.mp4...
# 400. Processing eve.mp4...
# 401. Processing eye.mp4...
# 402. Processing eyes.mp4...
# 403. Processing face.mp4...
# 404. Processing fact.mp4...
# 405. Processing fade.mp4...
# 406. Processing fail.mp4...
# 407. Processing faint.mp4...
# 408. Processing fair.mp4...
# 409. Processing faith.mp4...
# 410. Processing fake.mp4...
# 411. Processing fall.mp4...
# 412. Processing false.mp4...
# 413. Processing fame.mp4...
# 414. Processing fan.mp4...
# 415. Processing far.mp4...
# 416. Processing farm.mp4...
# 417. Processing fast.mp4...
# 418. Processing fat.mp4...
# 419. Processing fate.mp4...
# 420. Processing fault.mp4...
# 421. Processing fear.mp4...
# 422. Processing fed.mp4...
# 423. Processing fee.mp4...
# 424. Processing feed.mp4...
# 425. Processing feel.mp4...
# 426. Processing feet.mp4...
# 427. Processing fell.mp4...
# 428. Processing felt.mp4...
# 429. Processing fence.mp4...
# 430. Processing fetch.mp4...
# 431. Processing few.mp4...
# 432. Processing field.mp4...
# 433. Processing fierce.mp4...
# 434. Processing fifth.mp4...
# 435. Processing fight.mp4...
# 436. Processing file.mp4...
# 437. Processing fill.mp4...
# 438. Processing film.mp4...
# 439. Processing finance.mp4...
# 440. Processing find.mp4...
# 441. Processing fine.mp4...
# 442. Processing fire.mp4...
# 443. Processing firm.mp4...
# 444. Processing first.mp4...
# 445. Processing fish.mp4...
# 446. Processing fit.mp4...
# 447. Processing five.mp4...
# 448. Processing fix.mp4...
# 449. Processing fixed.mp4...
# 450. Processing flag.mp4...
# 451. Processing flags.mp4...
# 452. Processing flame.mp4...
# 453. Processing flash.mp4...
# 454. Processing flat.mp4...
# 455. Processing flee.mp4...
# 456. Processing fleet.mp4...
# 457. Processing flesh.mp4...
# 458. Processing flight.mp4...
# 459. Processing fling.mp4...
# 460. Processing flip.mp4...
# 461. Processing float.mp4...
# 462. Processing flood.mp4...
# 463. Processing floor.mp4...
# 464. Processing flow.mp4...
# 465. Processing flu.mp4...
# 466. Processing fly.mp4...
# 467. Processing foam.mp4...
# 468. Processing fold.mp4...
# 469. Processing folk.mp4...
# 470. Processing fond.mp4...
# 471. Processing font.mp4...
# 472. Processing food.mp4...
# 473. Processing fool.mp4...
# 474. Processing foot.mp4...
# 475. Processing for.mp4...
# 476. Processing force.mp4...
# 477. Processing forced.mp4...
# 478. Processing fork.mp4...
# 479. Processing form.mp4...
# 480. Processing fort.mp4...
# 481. Processing forth.mp4...
# 482. Processing foul.mp4...
# 483. Processing found.mp4...
# 484. Processing four.mp4...
# 485. Processing fourth.mp4...
# 486. Processing fox.mp4...
# 487. Processing frail.mp4...
# 488. Processing frame.mp4...
# 489. Processing frank.mp4...
# 490. Processing fraud.mp4...
# 491. Processing free.mp4...
# 492. Processing freeze.mp4...
# 493. Processing freight.mp4...
# 494. Processing french.mp4...
# 495. Processing fresh.mp4...
# 496. Processing friend.mp4...
# 497. Processing frog.mp4...
# 498. Processing from.mp4...
# 499. Processing front.mp4...
# 500. Processing frown.mp4...
# 501. Processing fruit.mp4...
# 502. Processing fuck.mp4...
# 503. Processing fuel.mp4...
# 504. Processing full.mp4...
# 505. Processing fun.mp4...
# 506. Processing fund.mp4...
# 507. Processing funds.mp4...
# 508. Processing gain.mp4...
# 509. Processing gains.mp4...
# 510. Processing game.mp4...
# 511. Processing gang.mp4...
# 512. Processing gap.mp4...
# 513. Processing gas.mp4...
# 514. Processing gasp.mp4...
# 515. Processing gate.mp4...
# 516. Processing gauge.mp4...
# 517. Processing gaunt.mp4...
# 518. Processing gave.mp4...
# 519. Processing gay.mp4...
# 520. Processing gaze.mp4...
# 521. Processing gear.mp4...
# 522. Processing geek.mp4...
# 523. Processing gel.mp4...
# 524. Processing gene.mp4...
# 525. Processing get.mp4...
# 526. Processing ghost.mp4...
# 527. Processing gift.mp4...
# 528. Processing girl.mp4...
# 529. Processing give.mp4...
# 530. Processing glad.mp4...
# 531. Processing glance.mp4...
# 532. Processing glass.mp4...
# 533. Processing glen.mp4...
# 534. Processing globe.mp4...
# 535. Processing gnome.mp4...
# 536. Processing go.mp4...
# 537. Processing goal.mp4...
# 538. Processing god.mp4...
# 539. Processing goes.mp4...
# 540. Processing gold.mp4...
# 541. Processing golf.mp4...
# 542. Processing gone.mp4...
# 543. Processing good.mp4...
# 544. Processing goods.mp4...
# 545. Processing got.mp4...
# 546. Processing grab.mp4...
# 547. Processing grace.mp4...
# 548. Processing grade.mp4...
# 549. Processing grain.mp4...
# 550. Processing grand.mp4...
# 551. Processing grant.mp4...
# 552. Processing graph.mp4...
# 553. Processing grasp.mp4...
# 554. Processing grass.mp4...
# 555. Processing grave.mp4...
# 556. Processing great.mp4...
# 557. Processing green.mp4...
# 558. Processing greet.mp4...
# 559. Processing grew.mp4...
# 560. Processing grey.mp4...
# 561. Processing grid.mp4...
# 562. Processing grill.mp4...
# 563. Processing grim.mp4...
# 564. Processing grin.mp4...
# 565. Processing grip.mp4...
# 566. Processing gross.mp4...
# 567. Processing ground.mp4...
# 568. Processing group.mp4...
# 569. Processing grove.mp4...
# 570. Processing grow.mp4...
# 571. Processing grown.mp4...
# 572. Processing growth.mp4...
# 573. Processing guard.mp4...
# 574. Processing guess.mp4...
# 575. Processing guest.mp4...
# 576. Processing guide.mp4...
# 577. Processing guild.mp4...
# 578. Processing guilt.mp4...
# 579. Processing gulf.mp4...
# 580. Processing gun.mp4...
# 581. Processing guns.mp4...
# 582. Processing guy.mp4...
# 583. Processing gym.mp4...
# 584. Processing had.mp4...
# 585. Processing hair.mp4...
# 586. Processing half.mp4...
# 587. Processing hall.mp4...
# 588. Processing halt.mp4...
# 589. Processing hand.mp4...
# 590. Processing hands.mp4...
# 591. Processing hang.mp4...
# 592. Processing hard.mp4...
# 593. Processing harm.mp4...
# 594. Processing harsh.mp4...
# 595. Processing has.mp4...
# 596. Processing hat.mp4...
# 597. Processing hate.mp4...
# 598. Processing have.mp4...
# 599. Processing head.mp4...
# 600. Processing heads.mp4...
# 601. Processing health.mp4...
# 602. Processing hear.mp4...
# 603. Processing heart.mp4...
# 604. Processing hearts.mp4...
# 605. Processing heat.mp4...
# 606. Processing heel.mp4...
# 607. Processing height.mp4...
# 608. Processing held.mp4...
# 609. Processing hell.mp4...
# 610. Processing help.mp4...
# 611. Processing hence.mp4...
# 612. Processing her.mp4...
# 613. Processing here.mp4...
# 614. Processing hey.mp4...
# 615. Processing hide.mp4...
# 616. Processing high.mp4...
# 617. Processing hill.mp4...
# 618. Processing hills.mp4...
# 619. Processing him.mp4...
# 620. Processing hint.mp4...
# 621. Processing hip.mp4...
# 622. Processing hire.mp4...
# 623. Processing his.mp4...
# 624. Processing hit.mp4...
# 625. Processing hold.mp4...
# 626. Processing hole.mp4...
# 627. Processing home.mp4...
# 628. Processing hood.mp4...
# 629. Processing hook.mp4...
# 630. Processing hop.mp4...
# 631. Processing hope.mp4...
# 632. Processing horn.mp4...633. Processing horse.mp4...
#
# 634. Processing host.mp4...
# 635. Processing hot.mp4...
# 636. Processing hour.mp4...
# 637. Processing hours.mp4...
# 638. Processing house.mp4...
# 639. Processing how.mp4...
# 640. Processing hub.mp4...641. Processing huge.mp4...
#
# 642. Processing hung.mp4...
# 643. Processing hunt.mp4...
# 644. Processing hurt.mp4...
# 645. Processing ice.mp4...
# 646. Processing ill.mp4...
# 647. Processing in.mp4...
# 648. Processing inch.mp4...
# 649. Processing ink.mp4...
# 650. Processing inter.mp4...
# 651. Processing intro.mp4...
# 652. Processing isle.mp4...
# 653. Processing its.mp4...
# 654. Processing jack.mp4...
# 655. Processing jam.mp4...
# 656. Processing jane.mp4...
# 657. Processing jazz.mp4...
# 658. Processing jean.mp4...
# 659. Processing jeans.mp4...
# 660. Processing jeep.mp4...
# 661. Processing jet.mp4...
# 662. Processing jew.mp4...
# 663. Processing job.mp4...
# 664. Processing joe.mp4...
# 665. Processing john.mp4...
# 666. Processing join.mp4...
# 667. Processing joint.mp4...
# 668. Processing joke.mp4...
# 669. Processing joy.mp4...
# 670. Processing judge.mp4...
# 671. Processing juice.mp4...
# 672. Processing jump.mp4...
# 673. Processing just.mp4...
# 674. Processing keen.mp4...
# 675. Processing keep.mp4...
# 676. Processing ken.mp4...
# 677. Processing kept.mp4...
# 678. Processing key.mp4...
# 679. Processing kick.mp4...
# 680. Processing kid.mp4...
# 681. Processing kill.mp4...
# 682. Processing kind.mp4...
# 683. Processing king.mp4...
# 684. Processing kiss.mp4...
# 685. Processing kit.mp4...
# 686. Processing knee.mp4...
# 687. Processing knew.mp4...
# 688. Processing knife.mp4...
# 689. Processing knight.mp4...
# 690. Processing knit.mp4...
# 691. Processing knives.mp4...
# 692. Processing knock.mp4...
# 693. Processing know.mp4...
# 694. Processing known.mp4...
# 695. Processing lab.mp4...
# 696. Processing lack.mp4...
# 697. Processing lad.mp4...
# 698. Processing laid.mp4...
# 699. Processing lake.mp4...
# 700. Processing lame.mp4...
# 701. Processing lamp.mp4...
# 702. Processing land.mp4...
# 703. Processing lands.mp4...
# 704. Processing lane.mp4...
# 705. Processing large.mp4...
# 706. Processing last.mp4...
# 707. Processing late.mp4...
# 708. Processing laugh.mp4...
# 709. Processing launch.mp4...
# 710. Processing law.mp4...
# 711. Processing lawn.mp4...
# 712. Processing lay.mp4...
# 713. Processing lead.mp4...
# 714. Processing leaf.mp4...
# 715. Processing league.mp4...
# 716. Processing lean.mp4...
# 717. Processing leap.mp4...
# 718. Processing learn.mp4...
# 719. Processing lease.mp4...
# 720. Processing least.mp4...
# 721. Processing leave.mp4...
# 722. Processing leaves.mp4...
# 723. Processing led.mp4...
# 724. Processing left.mp4...
# 725. Processing leg.mp4...
# 726. Processing lend.mp4...
# 727. Processing length.mp4...
# 728. Processing lens.mp4...
# 729. Processing less.mp4...
# 730. Processing let.mp4...
# 731. Processing lie.mp4...
# 732. Processing life.mp4...
# 733. Processing lift.mp4...
# 734. Processing light.mp4...
# 735. Processing lights.mp4...
# 736. Processing like.mp4...
# 737. Processing limp.mp4...
# 738. Processing line.mp4...
# 739. Processing lines.mp4...
# 740. Processing link.mp4...
# 741. Processing linked.mp4...
# 742. Processing links.mp4...
# 743. Processing lip.mp4...
# 744. Processing list.mp4...
# 745. Processing lists.mp4...
# 746. Processing live.mp4...
# 747. Processing lived.mp4...
# 748. Processing lives.mp4...
# 749. Processing load.mp4...
# 750. Processing loads.mp4...
# 751. Processing loan.mp4...
# 752. Processing lock.mp4...
# 753. Processing lodge.mp4...
# 754. Processing log.mp4...
# 755. Processing long.mp4...
# 756. Processing look.mp4...
# 757. Processing loop.mp4...
# 758. Processing loose.mp4...
# 759. Processing lord.mp4...
# 760. Processing lose.mp4...
# 761. Processing loss.mp4...
# 762. Processing lost.mp4...
# 763. Processing lot.mp4...
# 764. Processing lots.mp4...
# 765. Processing loud.mp4...
# 766. Processing lounge.mp4...
# 767. Processing love.mp4...
# 768. Processing low.mp4...
# 769. Processing luck.mp4...
# 770. Processing lunch.mp4...
# 771. Processing lung.mp4...
# 772. Processing lush.mp4...
# 773. Processing mac.mp4...
# 774. Processing mad.mp4...
# 775. Processing made.mp4...
# 776. Processing mail.mp4...
# 777. Processing main.mp4...
# 778. Processing make.mp4...
# 779. Processing male.mp4...
# 780. Processing mall.mp4...
# 781. Processing man.mp4...
# 782. Processing map.mp4...
# 783. Processing march.mp4...
# 784. Processing mark.mp4...
# 785. Processing marked.mp4...
# 786. Processing mart.mp4...
# 787. Processing mask.mp4...
# 788. Processing mass.mp4...
# 789. Processing mat.mp4...
# 790. Processing match.mp4...
# 791. Processing mate.mp4...
# 792. Processing math.mp4...
# 793. Processing max.mp4...
# 794. Processing may.mp4...
# 795. Processing mayor.mp4...
# 796. Processing meal.mp4...
# 797. Processing mean.mp4...
# 798. Processing means.mp4...
# 799. Processing meant.mp4...
# 800. Processing meat.mp4...
# 801. Processing meet.mp4...
# 802. Processing melt.mp4...
# 803. Processing men.mp4...
# 804. Processing mere.mp4...
# 805. Processing merge.mp4...
# 806. Processing mesh.mp4...
# 807. Processing mess.mp4...
# 808. Processing met.mp4...
# 809. Processing metal.mp4...
# 810. Processing mic.mp4...
# 811. Processing mice.mp4...
# 812. Processing mid.mp4...
# 813. Processing might.mp4...
# 814. Processing mild.mp4...
# 815. Processing mile.mp4...
# 816. Processing milk.mp4...
# 817. Processing mill.mp4...
# 818. Processing mind.mp4...
# 819. Processing mine.mp4...
# 820. Processing mint.mp4...
# 821. Processing miss.mp4...
# 822. Processing mix.mp4...
# 823. Processing mixed.mp4...
# 824. Processing mod.mp4...
# 825. Processing mode.mp4...
# 826. Processing moist.mp4...
# 827. Processing mom.mp4...
# 828. Processing month.mp4...
# 829. Processing mood.mp4...
# 830. Processing moon.mp4...
# 831. Processing more.mp4...
# 832. Processing most.mp4...
# 833. Processing mount.mp4...
# 834. Processing mouse.mp4...
# 835. Processing mouth.mp4...
# 836. Processing move.mp4...
# 837. Processing much.mp4...
# 838. Processing mud.mp4...
# 839. Processing mum.mp4...
# 840. Processing must.mp4...
# 841. Processing myth.mp4...
# 842. Processing nail.mp4...
# 843. Processing name.mp4...
# 844. Processing near.mp4...
# 845. Processing neat.mp4...
# 846. Processing neck.mp4...
# 847. Processing need.mp4...
# 848. Processing needs.mp4...
# 849. Processing nerve.mp4...
# 850. Processing nest.mp4...
# 851. Processing net.mp4...
# 852. Processing new.mp4...
# 853. Processing news.mp4...
# 854. Processing next.mp4...
# 855. Processing nice.mp4...
# 856. Processing nick.mp4...
# 857. Processing night.mp4...
# 858. Processing nights.mp4...
# 859. Processing nine.mp4...
# 860. Processing no.mp4...
# 861. Processing nod.mp4...
# 862. Processing node.mp4...
# 863. Processing noise.mp4...
# 864. Processing none.mp4...
# 865. Processing noon.mp4...
# 866. Processing nor.mp4...
# 867. Processing norm.mp4...
# 868. Processing north.mp4...
# 869. Processing nose.mp4...
# 870. Processing not.mp4...
# 871. Processing note.mp4...
# 872. Processing notes.mp4...
# 873. Processing now.mp4...
# 874. Processing nude.mp4...
# 875. Processing nuke.mp4...
# 876. Processing null.mp4...
# 877. Processing numb.mp4...
# 878. Processing nurse.mp4...
# 879. Processing nuts.mp4...
# 880. Processing oak.mp4...
# 881. Processing odd.mp4...
# 882. Processing odds.mp4...
# 883. Processing off.mp4...
# 884. Processing oil.mp4...
# 885. Processing old.mp4...
# 886. Processing once.mp4...
# 887. Processing one.mp4...
# 888. Processing our.mp4...
# 889. Processing out.mp4...
# 890. Processing owe.mp4...
# 891. Processing own.mp4...
# 892. Processing pace.mp4...
# 893. Processing pack.mp4...
# 894. Processing pad.mp4...
# 895. Processing page.mp4...
# 896. Processing paid.mp4...
# 897. Processing pain.mp4...
# 898. Processing paint.mp4...
# 899. Processing pair.mp4...
# 900. Processing pairs.mp4...
# 901. Processing pal.mp4...
# 902. Processing pale.mp4...
# 903. Processing palm.mp4...
# 904. Processing pan.mp4...
# 905. Processing park.mp4...
# 906. Processing part.mp4...
# 907. Processing parts.mp4...
# 908. Processing pass.mp4...
# 909. Processing passed.mp4...
# 910. Processing past.mp4...
# 911. Processing paste.mp4...
# 912. Processing pat.mp4...
# 913. Processing patch.mp4...
# 914. Processing path.mp4...
# 915. Processing pause.mp4...
# 916. Processing pay.mp4...
# 917. Processing peace.mp4...
# 918. Processing peak.mp4...
# 919. Processing pearl.mp4...
# 920. Processing pee.mp4...
# 921. Processing peer.mp4...
# 922. Processing pen.mp4...
# 923. Processing per.mp4...
# 924. Processing pet.mp4...
# 925. Processing petrol.mp4...
# 926. Processing phase.mp4...
# 927. Processing phone.mp4...
# 928. Processing phrase.mp4...
# 929. Processing pick.mp4...
# 930. Processing picked.mp4...
# 931. Processing pie.mp4...
# 932. Processing piece.mp4...
# 933. Processing pig.mp4...
# 934. Processing pile.mp4...
# 935. Processing pill.mp4...
# 936. Processing pills.mp4...
# 937. Processing pin.mp4...
# 938. Processing pine.mp4...
# 939. Processing pink.mp4...
# 940. Processing pipe.mp4...
# 941. Processing piss.mp4...
# 942. Processing pit.mp4...
# 943. Processing pitch.mp4...
# 944. Processing place.mp4...
# 945. Processing plain.mp4...
# 946. Processing plan.mp4...
# 947. Processing plane.mp4...
# 948. Processing plant.mp4...
# 949. Processing plants.mp4...
# 950. Processing plate.mp4...
# 951. Processing play.mp4...
# 952. Processing plead.mp4...
# 953. Processing please.mp4...
# 954. Processing plot.mp4...
# 955. Processing plug.mp4...
# 956. Processing plump.mp4...
# 957. Processing plunge.mp4...
# 958. Processing plus.mp4...
# 959. Processing point.mp4...
# 960. Processing pole.mp4...
# 961. Processing poll.mp4...
# 962. Processing pond.mp4...
# 963. Processing pool.mp4...
# 964. Processing poor.mp4...
# 965. Processing pop.mp4...
# 966. Processing pope.mp4...
# 967. Processing port.mp4...
# 968. Processing pose.mp4...
# 969. Processing posh.mp4...
# 970. Processing post.mp4...
# 971. Processing pot.mp4...
# 972. Processing pound.mp4...
# 973. Processing pour.mp4...
# 974. Processing praise.mp4...
# 975. Processing pray.mp4...
# 976. Processing press.mp4...
# 977. Processing price.mp4...
# 978. Processing pride.mp4...
# 979. Processing priest.mp4...
# 980. Processing prime.mp4...
# 981. Processing prince.mp4...
# 982. Processing print.mp4...
# 983. Processing prize.mp4...
# 984. Processing pro.mp4...985. Processing probe.mp4...
#
# 986. Processing prompt.mp4...
# 987. Processing proof.mp4...
# 988. Processing pros.mp4...
# 989. Processing proud.mp4...
# 990. Processing prove.mp4...
# 991. Processing pub.mp4...
# 992. Processing pull.mp4...
# 993. Processing pulse.mp4...
# 994. Processing pump.mp4...
# 995. Processing punk.mp4...
# 996. Processing pure.mp4...
# 997. Processing push.mp4...
# 998. Processing put.mp4...
# 999. Processing quaint.mp4...
# 1000. Processing queen.mp4...
# 1001. Processing queer.mp4...
# 1002. Processing quest.mp4...
# 1003. Processing quick.mp4...
# 1004. Processing quit.mp4...
# 1005. Processing quite.mp4...
# 1006. Processing quiz.mp4...
# 1007. Processing quote.mp4...
# 1008. Processing race.mp4...
# 1009. Processing rack.mp4...
# 1010. Processing raid.mp4...
# 1011. Processing rail.mp4...
# 1012. Processing rain.mp4...
# 1013. Processing raise.mp4...
# 1014. Processing raised.mp4...
# 1015. Processing ram.mp4...
# 1016. Processing ran.mp4...
# 1017. Processing ranch.mp4...
# 1018. Processing range.mp4...
# 1019. Processing rank.mp4...
# 1020. Processing rap.mp4...
# 1021. Processing rare.mp4...
# 1022. Processing rat.mp4...
# 1023. Processing rate.mp4...
# 1024. Processing rates.mp4...
# 1025. Processing rats.mp4...
# 1026. Processing raw.mp4...
# 1027. Processing ray.mp4...
# 1028. Processing reach.mp4...
# 1029. Processing react.mp4...
# 1030. Processing read.mp4...
# 1031. Processing rear.mp4...
# 1032. Processing red.mp4...
# 1033. Processing refer.mp4...
# 1034. Processing reign.mp4...
# 1035. Processing rent.mp4...
# 1036. Processing rest.mp4...
# 1037. Processing rice.mp4...
# 1038. Processing rich.mp4...
# 1039. Processing rick.mp4...
# 1040. Processing rid.mp4...
# 1041. Processing ride.mp4...
# 1042. Processing ridge.mp4...
# 1043. Processing right.mp4...
# 1044. Processing rights.mp4...
# 1045. Processing ring.mp4...
# 1046. Processing rip.mp4...
# 1047. Processing ripe.mp4...
# 1048. Processing rise.mp4...
# 1049. Processing risk.mp4...
# 1050. Processing road.mp4...
# 1051. Processing roast.mp4...
# 1052. Processing rob.mp4...
# 1053. Processing rock.mp4...
# 1054. Processing rod.mp4...
# 1055. Processing role.mp4...
# 1056. Processing roll.mp4...
# 1057. Processing rom.mp4...
# 1058. Processing roof.mp4...
# 1059. Processing room.mp4...
# 1060. Processing root.mp4...1061. Processing rope.mp4...
#
# 1062. Processing rose.mp4...
# 1063. Processing ross.mp4...
# 1064. Processing rough.mp4...
# 1065. Processing round.mp4...
# 1066. Processing route.mp4...
# 1067. Processing row.mp4...
# 1068. Processing rub.mp4...
# 1069. Processing rude.mp4...
# 1070. Processing rule.mp4...
# 1071. Processing run.mp4...
# 1072. Processing rush.mp4...
# 1073. Processing ruth.mp4...
# 1074. Processing sack.mp4...
# 1075. Processing sad.mp4...
# 1076. Processing safe.mp4...
# 1077. Processing sage.mp4...
# 1078. Processing said.mp4...
# 1079. Processing sail.mp4...
# 1080. Processing saint.mp4...
# 1081. Processing sake.mp4...
# 1082. Processing sale.mp4...
# 1083. Processing sales.mp4...
# 1084. Processing salt.mp4...
# 1085. Processing same.mp4...
# 1086. Processing sand.mp4...
# 1087. Processing sane.mp4...
# 1088. Processing sap.mp4...
# 1089. Processing sat.mp4...
# 1090. Processing sauce.mp4...
# 1091. Processing save.mp4...
# 1092. Processing saw.mp4...
# 1093. Processing say.mp4...
# 1094. Processing scale.mp4...
# 1095. Processing scan.mp4...
# 1096. Processing scant.mp4...
# 1097. Processing scarce.mp4...
# 1098. Processing scene.mp4...
# 1099. Processing scheme.mp4...
# 1100. Processing school.mp4...
# 1101. Processing scope.mp4...
# 1102. Processing score.mp4...
# 1103. Processing scratch.mp4...
# 1104. Processing scream.mp4...
# 1105. Processing screen.mp4...
# 1106. Processing screw.mp4...
# 1107. Processing script.mp4...
# 1108. Processing scroll.mp4...
# 1109. Processing sea.mp4...
# 1110. Processing seal.mp4...
# 1111. Processing sealed.mp4...
# 1112. Processing search.mp4...
# 1113. Processing seat.mp4...
# 1114. Processing see.mp4...
# 1115. Processing seed.mp4...
# 1116. Processing seek.mp4...
# 1117. Processing seem.mp4...
# 1118. Processing seen.mp4...
# 1119. Processing seize.mp4...
# 1120. Processing self.mp4...
# 1121. Processing sell.mp4...
# 1122. Processing send.mp4...
# 1123. Processing sense.mp4...
# 1124. Processing sent.mp4...
# 1125. Processing serve.mp4...
# 1126. Processing set.mp4...
# 1127. Processing seven.mp4...
# 1128. Processing sex.mp4...
# 1129. Processing shade.mp4...
# 1130. Processing shake.mp4...
# 1131. Processing shall.mp4...
# 1132. Processing shame.mp4...
# 1133. Processing shape.mp4...
# 1134. Processing shaped.mp4...
# 1135. Processing share.mp4...
# 1136. Processing sharp.mp4...
# 1137. Processing she.mp4...
# 1138. Processing shed.mp4...
# 1139. Processing sheep.mp4...
# 1140. Processing sheer.mp4...
# 1141. Processing sheet.mp4...
# 1142. Processing shelf.mp4...
# 1143. Processing shell.mp4...
# 1144. Processing shield.mp4...
# 1145. Processing shift.mp4...
# 1146. Processing shine.mp4...
# 1147. Processing ship.mp4...
# 1148. Processing shirt.mp4...
# 1149. Processing shit.mp4...
# 1150. Processing shock.mp4...
# 1151. Processing shoe.mp4...
# 1152. Processing shoot.mp4...
# 1153. Processing shop.mp4...
# 1154. Processing shore.mp4...
# 1155. Processing short.mp4...
# 1156. Processing shorts.mp4...
# 1157. Processing shot.mp4...
# 1158. Processing should.mp4...
# 1159. Processing shout.mp4...
# 1160. Processing show.mp4...
# 1161. Processing shown.mp4...
# 1162. Processing shrewd.mp4...
# 1163. Processing shrill.mp4...
# 1164. Processing shrug.mp4...
# 1165. Processing shut.mp4...
# 1166. Processing shy.mp4...
# 1167. Processing sick.mp4...
# 1168. Processing side.mp4...
# 1169. Processing sigh.mp4...
# 1170. Processing sight.mp4...
# 1171. Processing sign.mp4...
# 1172. Processing silk.mp4...
# 1173. Processing sin.mp4...
# 1174. Processing since.mp4...
# 1175. Processing sing.mp4...
# 1176. Processing sink.mp4...
# 1177. Processing sir.mp4...
# 1178. Processing sit.mp4...
# 1179. Processing site.mp4...
# 1180. Processing six.mp4...
# 1181. Processing sixth.mp4...
# 1182. Processing size.mp4...
# 1183. Processing sized.mp4...
# 1184. Processing ski.mp4...
# 1185. Processing skill.mp4...1186. Processing skilled.mp4...
#
# 1187. Processing skin.mp4...
# 1188. Processing skip.mp4...
# 1189. Processing skirt.mp4...
# 1190. Processing sky.mp4...
# 1191. Processing slack.mp4...
# 1192. Processing slam.mp4...
# 1193. Processing slave.mp4...
# 1194. Processing sleek.mp4...
# 1195. Processing sleep.mp4...
# 1196. Processing sleeve.mp4...
# 1197. Processing slick.mp4...
# 1198. Processing slide.mp4...
# 1199. Processing slight.mp4...
# 1200. Processing slim.mp4...
# 1201. Processing slip.mp4...
# 1202. Processing slope.mp4...
# 1203. Processing slot.mp4...
# 1204. Processing slow.mp4...
# 1205. Processing small.mp4...
# 1206. Processing smart.mp4...
# 1207. Processing smash.mp4...
# 1208. Processing smell.mp4...
# 1209. Processing smile.mp4...
# 1210. Processing smith.mp4...
# 1211. Processing smoke.mp4...
# 1212. Processing smooth.mp4...
# 1213. Processing smug.mp4...
# 1214. Processing snap.mp4...
# 1215. Processing snide.mp4...
# 1216. Processing snow.mp4...
# 1217. Processing snug.mp4...
# 1218. Processing soap.mp4...
# 1219. Processing soft.mp4...
# 1220. Processing soil.mp4...
# 1221. Processing sold.mp4...
# 1222. Processing sole.mp4...
# 1223. Processing solve.mp4...
# 1224. Processing some.mp4...
# 1225. Processing son.mp4...
# 1226. Processing song.mp4...
# 1227. Processing soon.mp4...
# 1228. Processing sore.mp4...
# 1229. Processing sort.mp4...
# 1230. Processing sought.mp4...
# 1231. Processing soul.mp4...
# 1232. Processing sound.mp4...
# 1233. Processing soup.mp4...
# 1234. Processing sour.mp4...
# 1235. Processing source.mp4...
# 1236. Processing south.mp4...
# 1237. Processing soy.mp4...
# 1238. Processing spa.mp4...
# 1239. Processing space.mp4...
# 1240. Processing span.mp4...
# 1241. Processing spare.mp4...1242. Processing sparse.mp4...
#
# 1243. Processing speak.mp4...
# 1244. Processing speech.mp4...
# 1245. Processing speed.mp4...
# 1246. Processing spell.mp4...
# 1247. Processing spend.mp4...
# 1248. Processing spent.mp4...
# 1249. Processing sphere.mp4...
# 1250. Processing spill.mp4...
# 1251. Processing spin.mp4...
# 1252. Processing split.mp4...
# 1253. Processing spoil.mp4...
# 1254. Processing spoilt.mp4...
# 1255. Processing spoke.mp4...
# 1256. Processing sport.mp4...
# 1257. Processing sports.mp4...
# 1258. Processing spot.mp4...
# 1259. Processing spouse.mp4...
# 1260. Processing spray.mp4...
# 1261. Processing spread.mp4...
# 1262. Processing spring.mp4...
# 1263. Processing sprint.mp4...
# 1264. Processing spy.mp4...
# 1265. Processing squad.mp4...
# 1266. Processing square.mp4...
# 1267. Processing squeeze.mp4...
# 1268. Processing stack.mp4...
# 1269. Processing staff.mp4...
# 1270. Processing stage.mp4...
# 1271. Processing staid.mp4...
# 1272. Processing stairs.mp4...
# 1273. Processing stake.mp4...
# 1274. Processing stale.mp4...
# 1275. Processing stamp.mp4...
# 1276. Processing stance.mp4...
# 1277. Processing stand.mp4...
# 1278. Processing star.mp4...
# 1279. Processing stare.mp4...
# 1280. Processing start.mp4...
# 1281. Processing stat.mp4...
# 1282. Processing state.mp4...
# 1283. Processing staunch.mp4...
# 1284. Processing stay.mp4...
# 1285. Processing steal.mp4...
# 1286. Processing steam.mp4...
# 1287. Processing steel.mp4...
# 1288. Processing steep.mp4...
# 1289. Processing stem.mp4...
# 1290. Processing step.mp4...
# 1291. Processing stick.mp4...
# 1292. Processing stiff.mp4...
# 1293. Processing still.mp4...
# 1294. Processing stir.mp4...
# 1295. Processing stock.mp4...
# 1296. Processing stocks.mp4...
# 1297. Processing stone.mp4...
# 1298. Processing stood.mp4...
# 1299. Processing stop.mp4...
# 1300. Processing stopped.mp4...
# 1301. Processing stops.mp4...
# 1302. Processing store.mp4...
# 1303. Processing stores.mp4...
# 1304. Processing storm.mp4...
# 1305. Processing stout.mp4...
# 1306. Processing straight.mp4...
# 1307. Processing strain.mp4...
# 1308. Processing strange.mp4...
# 1309. Processing strap.mp4...
# 1310. Processing stream.mp4...
# 1311. Processing street.mp4...
# 1312. Processing strength.mp4...
# 1313. Processing stress.mp4...
# 1314. Processing stretch.mp4...
# 1315. Processing strict.mp4...
# 1316. Processing strike.mp4...
# 1317. Processing string.mp4...
# 1318. Processing strip.mp4...
# 1319. Processing stroke.mp4...
# 1320. Processing strong.mp4...
# 1321. Processing struck.mp4...
# 1322. Processing stuck.mp4...
# 1323. Processing stud.mp4...
# 1324. Processing stuff.mp4...
# 1325. Processing style.mp4...
# 1326. Processing sub.mp4...
# 1327. Processing such.mp4...
# 1328. Processing suck.mp4...
# 1329. Processing sucks.mp4...
# 1330. Processing sue.mp4...
# 1331. Processing suite.mp4...
# 1332. Processing sum.mp4...
# 1333. Processing sun.mp4...
# 1334. Processing super.mp4...
# 1335. Processing sure.mp4...1336. Processing surf.mp4...
#
# 1337. Processing swap.mp4...
# 1338. Processing swear.mp4...
# 1339. Processing sweep.mp4...
# 1340. Processing sweet.mp4...
# 1341. Processing swift.mp4...
# 1342. Processing swim.mp4...
# 1343. Processing swing.mp4...
# 1344. Processing switch.mp4...
# 1345. Processing sword.mp4...
# 1346. Processing tab.mp4...1347. Processing tag.mp4...
#
# 1348. Processing tail.mp4...
# 1349. Processing take.mp4...
# 1350. Processing tale.mp4...
# 1351. Processing talk.mp4...
# 1352. Processing tall.mp4...
# 1353. Processing tame.mp4...
# 1354. Processing tan.mp4...
# 1355. Processing tank.mp4...
# 1356. Processing tap.mp4...
# 1357. Processing tape.mp4...
# 1358. Processing task.mp4...
# 1359. Processing taste.mp4...
# 1360. Processing taught.mp4...
# 1361. Processing tax.mp4...
# 1362. Processing tea.mp4...
# 1363. Processing teach.mp4...
# 1364. Processing team.mp4...
# 1365. Processing tear.mp4...
# 1366. Processing tears.mp4...
# 1367. Processing tech.mp4...
# 1368. Processing ted.mp4...
# 1369. Processing teen.mp4...
# 1370. Processing teens.mp4...
# 1371. Processing teeth.mp4...
# 1372. Processing tell.mp4...
# 1373. Processing tempt.mp4...
# 1374. Processing ten.mp4...
# 1375. Processing tend.mp4...
# 1376. Processing term.mp4...
# 1377. Processing terms.mp4...
# 1378. Processing test.mp4...
# 1379. Processing text.mp4...
# 1380. Processing than.mp4...
# 1381. Processing thank.mp4...
# 1382. Processing thanks.mp4...
# 1383. Processing that.mp4...
# 1384. Processing the.mp4...
# 1385. Processing theft.mp4...
# 1386. Processing their.mp4...
# 1387. Processing them.mp4...
# 1388. Processing theme.mp4...
# 1389. Processing then.mp4...
# 1390. Processing there.mp4...
# 1391. Processing these.mp4...
# 1392. Processing they.mp4...
# 1393. Processing thick.mp4...
# 1394. Processing thin.mp4...
# 1395. Processing thing.mp4...
# 1396. Processing think.mp4...
# 1397. Processing third.mp4...
# 1398. Processing this.mp4...
# 1399. Processing those.mp4...
# 1400. Processing thought.mp4...
# 1401. Processing thread.mp4...
# 1402. Processing threat.mp4...
# 1403. Processing three.mp4...
# 1404. Processing throat.mp4...
# 1405. Processing through.mp4...
# 1406. Processing throw.mp4...
# 1407. Processing thrust.mp4...
# 1408. Processing thus.mp4...
# 1409. Processing tide.mp4...
# 1410. Processing tie.mp4...
# 1411. Processing tied.mp4...
# 1412. Processing tight.mp4...
# 1413. Processing tile.mp4...
# 1414. Processing till.mp4...
# 1415. Processing time.mp4...
# 1416. Processing tin.mp4...
# 1417. Processing tip.mp4...
# 1418. Processing tire.mp4...
# 1419. Processing tired.mp4...
# 1420. Processing toe.mp4...
# 1421. Processing told.mp4...
# 1422. Processing toll.mp4...
# 1423. Processing tom.mp4...
# 1424. Processing ton.mp4...
# 1425. Processing tone.mp4...
# 1426. Processing tongue.mp4...
# 1427. Processing too.mp4...
# 1428. Processing took.mp4...
# 1429. Processing tool.mp4...
# 1430. Processing tooth.mp4...
# 1431. Processing top.mp4...
# 1432. Processing tops.mp4...
# 1433. Processing toss.mp4...
# 1434. Processing touch.mp4...
# 1435. Processing tough.mp4...
# 1436. Processing tour.mp4...
# 1437. Processing town.mp4...
# 1438. Processing toy.mp4...
# 1439. Processing trace.mp4...
# 1440. Processing track.mp4...
# 1441. Processing tracks.mp4...
# 1442. Processing trade.mp4...
# 1443. Processing trail.mp4...
# 1444. Processing train.mp4...
# 1445. Processing trans.mp4...
# 1446. Processing trap.mp4...1447. Processing tray.mp4...
#
# 1448. Processing treat.mp4...
# 1449. Processing tree.mp4...
# 1450. Processing trek.mp4...
# 1451. Processing trend.mp4...
# 1452. Processing tribe.mp4...
# 1453. Processing trick.mp4...
# 1454. Processing tried.mp4...
# 1455. Processing trim.mp4...
# 1456. Processing trip.mp4...
# 1457. Processing trite.mp4...
# 1458. Processing troop.mp4...
# 1459. Processing troy.mp4...
# 1460. Processing truck.mp4...
# 1461. Processing true.mp4...
# 1462. Processing trunk.mp4...
# 1463. Processing trust.mp4...
# 1464. Processing truth.mp4...
# 1465. Processing try.mp4...
# 1466. Processing tub.mp4...
# 1467. Processing tube.mp4...
# 1468. Processing tuck.mp4...
# 1469. Processing tune.mp4...
# 1470. Processing turn.mp4...
# 1471. Processing twelve.mp4...
# 1472. Processing twice.mp4...
# 1473. Processing twin.mp4...
# 1474. Processing twist.mp4...
# 1475. Processing two.mp4...
# 1476. Processing type.mp4...
# 1477. Processing urge.mp4...
# 1478. Processing use.mp4...
# 1479. Processing used.mp4...
# 1480. Processing vain.mp4...
# 1481. Processing valve.mp4...
# 1482. Processing van.mp4...
# 1483. Processing vast.mp4...
# 1484. Processing vat.mp4...
# 1485. Processing verse.mp4...
# 1486. Processing vice.mp4...
# 1487. Processing view.mp4...
# 1488. Processing vile.mp4...
# 1489. Processing voice.mp4...
# 1490. Processing void.mp4...
# 1491. Processing volt.mp4...
# 1492. Processing vote.mp4...
# 1493. Processing wage.mp4...
# 1494. Processing wait.mp4...
# 1495. Processing wake.mp4...
# 1496. Processing walk.mp4...
# 1497. Processing wall.mp4...
# 1498. Processing want.mp4...
# 1499. Processing war.mp4...
# 1500. Processing ward.mp4...
# 1501. Processing warm.mp4...
# 1502. Processing warmth.mp4...
# 1503. Processing warn.mp4...
# 1504. Processing was.mp4...
# 1505. Processing wash.mp4...
# 1506. Processing waste.mp4...
# 1507. Processing watch.mp4...
# 1508. Processing watt.mp4...
# 1509. Processing wave.mp4...
# 1510. Processing way.mp4...
# 1511. Processing ways.mp4...
# 1512. Processing weak.mp4...
# 1513. Processing wealth.mp4...
# 1514. Processing wear.mp4...
# 1515. Processing web.mp4...
# 1516. Processing week.mp4...
# 1517. Processing weigh.mp4...
# 1518. Processing weight.mp4...
# 1519. Processing weird.mp4...
# 1520. Processing well.mp4...
# 1521. Processing went.mp4...
# 1522. Processing were.mp4...
# 1523. Processing west.mp4...
# 1524. Processing wet.mp4...
# 1525. Processing what.mp4...
# 1526. Processing wheat.mp4...
# 1527. Processing wheel.mp4...
# 1528. Processing wheels.mp4...
# 1529. Processing when.mp4...
# 1530. Processing where.mp4...
# 1531. Processing which.mp4...
# 1532. Processing while.mp4...
# 1533. Processing whilst.mp4...
# 1534. Processing white.mp4...
# 1535. Processing who.mp4...
# 1536. Processing whole.mp4...
# 1537. Processing whom.mp4...
# 1538. Processing whose.mp4...
# 1539. Processing why.mp4...
# 1540. Processing wide.mp4...
# 1541. Processing width.mp4...
# 1542. Processing wife.mp4...
# 1543. Processing wild.mp4...
# 1544. Processing will.mp4...
# 1545. Processing win.mp4...
# 1546. Processing wind.mp4...
# 1547. Processing wine.mp4...
# 1548. Processing wing.mp4...
# 1549. Processing wipe.mp4...
# 1550. Processing wire.mp4...
# 1551. Processing wired.mp4...
# 1552. Processing wise.mp4...
# 1553. Processing wish.mp4...
# 1554. Processing with.mp4...
# 1555. Processing wolf.mp4...
# 1556. Processing won.mp4...
# 1557. Processing wood.mp4...
# 1558. Processing woods.mp4...
# 1559. Processing wool.mp4...
# 1560. Processing word.mp4...
# 1561. Processing words.mp4...
# 1562. Processing work.mp4...
# 1563. Processing worked.mp4...
# 1564. Processing works.mp4...
# 1565. Processing world.mp4...
# 1566. Processing worse.mp4...
# 1567. Processing worst.mp4...
# 1568. Processing worth.mp4...
# 1569. Processing would.mp4...
# 1570. Processing wound.mp4...
# 1571. Processing wow.mp4...
# 1572. Processing wrap.mp4...
# 1573. Processing write.mp4...
# 1574. Processing wrong.mp4...
# 1575. Processing wrote.mp4...
# 1576. Processing yard.mp4...
# 1577. Processing year.mp4...
# 1578. Processing yes.mp4...
# 1579. Processing yet.mp4...
# 1580. Processing yield.mp4...
# 1581. Processing york.mp4...
# 1582. Processing you.mp4...
# 1583. Processing young.mp4...
# 1584. Processing your.mp4...
# 1585. Processing yours.mp4...
# 1586. Processing youth.mp4...
# 1587. Processing zip.mp4...
# 1588. Processing zone.mp4...
# 1589. Processing zoo.mp4...
# 1590. Processing zoom.mp4...
#
# RGB and grayscale frame extraction complete!

# %% [markdown]
# 2.1. Augmenting even number of frames from the original_dataset_even_frames folder (augmented_dataset_uneven_frames folder)

# %%
# ImageDataGenerator for basic augmentations (horizontal flip, brightness)
datagen = ImageDataGenerator(
    horizontal_flip=True,
    brightness_range=[0.8, 1.2]  # Adjusting brightness (color jittering)
)

# Function to apply noise to an image
def add_noise(image):
    # Check if the image is grayscale (2D) or has an extra channel dimension (3D)
    if len(image.shape) == 2:
        row, col = image.shape  # Grayscale image (2D)
    else:
        row, col, ch = image.shape  # In case it still has a third dimension

    mean = 0
    sigma = 0.1  # Fixed sigma value (standard deviation) for Gaussian noise
    gauss = np.random.normal(mean, sigma, (row, col))

    # Ensure that the noise is applied consistently across channels if any exist
    if len(image.shape) == 2:  # Grayscale
        noisy_image = np.clip(image + gauss * 255, 0, 255).astype(np.uint8)
    else:  # If for some reason it has channels, apply the same noise across all channels
        noisy_image = np.clip(image + gauss[:, :, np.newaxis] * 255, 0, 255).astype(np.uint8)

    return noisy_image

# Function to augment and save augmented frames
def augment_and_save_frame(image_path, output_dir, count):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Load grayscale image
    img = img_to_array(img)  # Convert image to array for augmentation

    # Apply horizontal flipping and brightness adjustments
    img = datagen.random_transform(img)

    # Add noise to 30% of the frames
    if random.random() < 0.3:
        img = add_noise(img)

    # Convert back to image format and save augmented frame with consistent naming
    aug_img = array_to_img(img, scale=False)
    aug_img.save(f"{output_dir}/frame{count:04d}.jpg")  # Augmented frame saved with sequential naming

# Function to randomly shift frames temporally
def temporal_shift(frames):
    shift_amount = random.randint(-2, 2)  # Shift between -2 to +2 frames
    return np.roll(frames, shift_amount, axis=0)

# Function to augment frames with all techniques and store only augmented frames
def augment_frames(frame_dir, output_dir):
    # List all frame files in the directory
    frames = sorted(os.listdir(frame_dir))

    # Randomly remove or duplicate 10% of frames to simulate frame corruption/duplication
    num_modify = int(0.1 * len(frames))
    modify_indices = random.sample(range(len(frames)), num_modify)

    # Read all frames into a list for easier manipulation
    all_frames = [cv2.imread(os.path.join(frame_dir, frame), cv2.IMREAD_GRAYSCALE) for frame in frames]

    # Apply temporal shifting to the entire sequence
    shifted_frames = temporal_shift(np.array(all_frames))

    # Save augmented frames to output directory
    for count, frame_name in enumerate(frames):
        frame_path = os.path.join(frame_dir, frame_name)

        # If the frame is selected for modification (removal or duplication)
        if count in modify_indices:
            if random.random() < 0.5:  # Randomly decide whether to remove or duplicate
                # Duplicate frame (copy it again)
                augment_and_save_frame(frame_path, output_dir, count + len(frames))  # Save augmented frame after originals
            else:
                # Skip the frame to simulate removal
                continue

        # Apply augmentation to the frame and save it
        augment_and_save_frame(frame_path, output_dir, count + 1)

# Function to process each word directory in parallel
def process_word_dir(word_dir, count):
    word_frame_dir = os.path.join(original_frames_folder, word_dir)
    output_word_dir = os.path.join(augmented_frames_folder, word_dir)  # New output directory
    os.makedirs(output_word_dir, exist_ok=True)  # Create output directory
    if os.path.isdir(word_frame_dir):
        print(f"{count}. Augmenting grayscale frames for {word_dir}...")
        augment_frames(word_frame_dir, output_word_dir)

# Main function to handle multi-threading
def augment_all_words():
    word_dirs = [word_dir for word_dir in os.listdir(original_frames_folder) if os.path.isdir(os.path.join(original_frames_folder, word_dir))]

    # Use ThreadPoolExecutor for multi-threading
    with ThreadPoolExecutor(max_workers=8) as executor:  # Adjust the number of threads as needed
        for count, word_dir in enumerate(word_dirs, start=1):
            executor.submit(process_word_dir, word_dir, count)

    print("\nAll grayscale frames augmented and saved in 'augmented_gray_dataset_uneven_frames'.")

# Path where the original grayscale frames are stored
original_frames_folder = r'D:\pro_dis\original_gray_dataset_even_frames'

# Output folder for storing only augmented grayscale frames
augmented_frames_folder = r'D:\pro_dis\augmented_gray_dataset_uneven_frames'

# Run the multi-threading process
augment_all_words()
# Out:
# 1. Augmenting grayscale frames for ace...
# 2. Augmenting grayscale frames for act...
# 3. Augmenting grayscale frames for add...
# 4. Augmenting grayscale frames for age...
# 5. Augmenting grayscale frames for aid...
# 6. Augmenting grayscale frames for aids...
# 7. Augmenting grayscale frames for aim...
# 8. Augmenting grayscale frames for air...
# 9. Augmenting grayscale frames for all...
# 10. Augmenting grayscale frames for anal...
# 11. Augmenting grayscale frames for and...
# 12. Augmenting grayscale frames for app...
# 13. Augmenting grayscale frames for approx...
# 14. Augmenting grayscale frames for arc...
# 15. Augmenting grayscale frames for arch...
# 16. Augmenting grayscale frames for are...
# 17. Augmenting grayscale frames for arm...
# 18. Augmenting grayscale frames for armed...
# 19. Augmenting grayscale frames for arms...
# 20. Augmenting grayscale frames for art...
# 21. Augmenting grayscale frames for arts...
# 22. Augmenting grayscale frames for ash...
# 23. Augmenting grayscale frames for ask...
# 24. Augmenting grayscale frames for ass...
# 25. Augmenting grayscale frames for aunt...
# 26. Augmenting grayscale frames for auto...
# 27. Augmenting grayscale frames for babe...
# 28. Augmenting grayscale frames for back...
# 29. Augmenting grayscale frames for bad...
# 30. Augmenting grayscale frames for bag...
# 31. Augmenting grayscale frames for bags...
# 32. Augmenting grayscale frames for bald...
# 33. Augmenting grayscale frames for ball...
# 34. Augmenting grayscale frames for balls...
# 35. Augmenting grayscale frames for ban...
# 36. Augmenting grayscale frames for band...
# 37. Augmenting grayscale frames for bang...
# 38. Augmenting grayscale frames for bank...
# 39. Augmenting grayscale frames for bar...
# 40. Augmenting grayscale frames for bare...
# 41. Augmenting grayscale frames for base...
# 42. Augmenting grayscale frames for bass...
# 43. Augmenting grayscale frames for bat...
# 44. Augmenting grayscale frames for batch...
# 45. Augmenting grayscale frames for bath...
# 46. Augmenting grayscale frames for bay...
# 47. Augmenting grayscale frames for beach...
# 48. Augmenting grayscale frames for beam...
# 49. Augmenting grayscale frames for bean...
# 50. Augmenting grayscale frames for bear...
# 51. Augmenting grayscale frames for beast...
# 52. Augmenting grayscale frames for beat...
# 53. Augmenting grayscale frames for bed...54. Augmenting grayscale frames for beef...
#
# 55. Augmenting grayscale frames for been...
# 56. Augmenting grayscale frames for beer...
# 57. Augmenting grayscale frames for beg...
# 58. Augmenting grayscale frames for bell...
# 59. Augmenting grayscale frames for belt...
# 60. Augmenting grayscale frames for ben...
# 61. Augmenting grayscale frames for bench...
# 62. Augmenting grayscale frames for bend...
# 63. Augmenting grayscale frames for best...
# 64. Augmenting grayscale frames for bet...
# 65. Augmenting grayscale frames for bid...
# 66. Augmenting grayscale frames for big...
# 67. Augmenting grayscale frames for bike...
# 68. Augmenting grayscale frames for bill...
# 69. Augmenting grayscale frames for bin...
# 70. Augmenting grayscale frames for bind...
# 71. Augmenting grayscale frames for bird...
# 72. Augmenting grayscale frames for birth...
# 73. Augmenting grayscale frames for bit...
# 74. Augmenting grayscale frames for bitch...
# 75. Augmenting grayscale frames for bite...76. Augmenting grayscale frames for black...
#
# 77. Augmenting grayscale frames for blade...
# 78. Augmenting grayscale frames for blame...79. Augmenting grayscale frames for bland...
#
# 80. Augmenting grayscale frames for blank...
# 81. Augmenting grayscale frames for blast...
# 82. Augmenting grayscale frames for bleak...
# 83. Augmenting grayscale frames for blend...
# 84. Augmenting grayscale frames for blind...
# 85. Augmenting grayscale frames for block...
# 86. Augmenting grayscale frames for blond...
# 87. Augmenting grayscale frames for blonde...
# 88. Augmenting grayscale frames for blood...
# 89. Augmenting grayscale frames for blow...
# 90. Augmenting grayscale frames for blue...
# 91. Augmenting grayscale frames for blues...
# 92. Augmenting grayscale frames for blunt...
# 93. Augmenting grayscale frames for board...
# 94. Augmenting grayscale frames for boast...
# 95. Augmenting grayscale frames for boat...
# 96. Augmenting grayscale frames for bob...
# 97. Augmenting grayscale frames for boil...
# 98. Augmenting grayscale frames for bold...
# 99. Augmenting grayscale frames for bomb...
# 100. Augmenting grayscale frames for bond...
# 101. Augmenting grayscale frames for bone...
# 102. Augmenting grayscale frames for boob...
# 103. Augmenting grayscale frames for book...
# 104. Augmenting grayscale frames for boost...
# 105. Augmenting grayscale frames for boot...
# 106. Augmenting grayscale frames for booth...
# 107. Augmenting grayscale frames for boots...
# 108. Augmenting grayscale frames for born...
# 109. Augmenting grayscale frames for boss...
# 110. Augmenting grayscale frames for both...
# 111. Augmenting grayscale frames for bought...
# 112. Augmenting grayscale frames for bounce...
# 113. Augmenting grayscale frames for bound...
# 114. Augmenting grayscale frames for bow...
# 115. Augmenting grayscale frames for bowl...
# 116. Augmenting grayscale frames for box...
# 117. Augmenting grayscale frames for boy...
# 118. Augmenting grayscale frames for bra...
# 119. Augmenting grayscale frames for brad...
# 120. Augmenting grayscale frames for brain...
# 121. Augmenting grayscale frames for brake...
# 122. Augmenting grayscale frames for branch...
# 123. Augmenting grayscale frames for brand...
# 124. Augmenting grayscale frames for brass...
# 125. Augmenting grayscale frames for brave...
# 126. Augmenting grayscale frames for breach...
# 127. Augmenting grayscale frames for bread...
# 128. Augmenting grayscale frames for break...
# 129. Augmenting grayscale frames for breast...
# 130. Augmenting grayscale frames for breath...
# 131. Augmenting grayscale frames for breathe...
# 132. Augmenting grayscale frames for breed...
# 133. Augmenting grayscale frames for brick...
# 134. Augmenting grayscale frames for bride...
# 135. Augmenting grayscale frames for bridge...
# 136. Augmenting grayscale frames for brief...
# 137. Augmenting grayscale frames for bright...
# 138. Augmenting grayscale frames for bring...
# 139. Augmenting grayscale frames for brisk...
# 140. Augmenting grayscale frames for broad...
# 141. Augmenting grayscale frames for broke...
# 142. Augmenting grayscale frames for bronze...
# 143. Augmenting grayscale frames for broom...
# 144. Augmenting grayscale frames for brought...
# 145. Augmenting grayscale frames for brown...
# 146. Augmenting grayscale frames for browse...
# 147. Augmenting grayscale frames for brush...
# 148. Augmenting grayscale frames for bug...
# 149. Augmenting grayscale frames for bugs...
# 150. Augmenting grayscale frames for build...
# 151. Augmenting grayscale frames for built...
# 152. Augmenting grayscale frames for bulk...
# 153. Augmenting grayscale frames for bull...
# 154. Augmenting grayscale frames for bunch...
# 155. Augmenting grayscale frames for burn...
# 156. Augmenting grayscale frames for burst...
# 157. Augmenting grayscale frames for bus...
# 158. Augmenting grayscale frames for bush...
# 159. Augmenting grayscale frames for bust...
# 160. Augmenting grayscale frames for but...
# 161. Augmenting grayscale frames for butt...
# 162. Augmenting grayscale frames for buy...
# 163. Augmenting grayscale frames for buzz...
# 164. Augmenting grayscale frames for byte...
# 165. Augmenting grayscale frames for cab...
# 166. Augmenting grayscale frames for cache...
# 167. Augmenting grayscale frames for cad...
# 168. Augmenting grayscale frames for cake...
# 169. Augmenting grayscale frames for call...
# 170. Augmenting grayscale frames for calm...
# 171. Augmenting grayscale frames for cam...
# 172. Augmenting grayscale frames for came...
# 173. Augmenting grayscale frames for camp...
# 174. Augmenting grayscale frames for can...
# 175. Augmenting grayscale frames for cap...
# 176. Augmenting grayscale frames for cape...
# 177. Augmenting grayscale frames for caps...
# 178. Augmenting grayscale frames for car...
# 179. Augmenting grayscale frames for card...
# 181. Augmenting grayscale frames for care...
# 180. Augmenting grayscale frames for cards...
# 182. Augmenting grayscale frames for carl...
# 183. Augmenting grayscale frames for cart...
# 184. Augmenting grayscale frames for carve...
# 185. Augmenting grayscale frames for case...
# 186. Augmenting grayscale frames for cash...
# 187. Augmenting grayscale frames for cast...
# 188. Augmenting grayscale frames for cat...
# 189. Augmenting grayscale frames for catch...
# 190. Augmenting grayscale frames for caught...
# 191. Augmenting grayscale frames for cause...
# 192. Augmenting grayscale frames for cease...
# 193. Augmenting grayscale frames for cell...
# 194. Augmenting grayscale frames for cent...
# 195. Augmenting grayscale frames for chad...
# 196. Augmenting grayscale frames for chain...
# 197. Augmenting grayscale frames for chair...
# 198. Augmenting grayscale frames for chance...
# 199. Augmenting grayscale frames for change...
# 200. Augmenting grayscale frames for char...
# 201. Augmenting grayscale frames for charge...
# 202. Augmenting grayscale frames for charged...
# 203. Augmenting grayscale frames for charm...204. Augmenting grayscale frames for chart...
#
# 205. Augmenting grayscale frames for chase...
# 206. Augmenting grayscale frames for chat...
# 207. Augmenting grayscale frames for cheap...
# 208. Augmenting grayscale frames for cheat...
# 209. Augmenting grayscale frames for check...
# 210. Augmenting grayscale frames for checked...
# 211. Augmenting grayscale frames for cheek...
# 212. Augmenting grayscale frames for cheer...
# 213. Augmenting grayscale frames for cheese...
# 214. Augmenting grayscale frames for chef...
# 215. Augmenting grayscale frames for cheque...
# 216. Augmenting grayscale frames for chess...
# 217. Augmenting grayscale frames for chest...
# 218. Augmenting grayscale frames for chick...
# 219. Augmenting grayscale frames for chief...
# 220. Augmenting grayscale frames for child...
# 221. Augmenting grayscale frames for chip...
# 222. Augmenting grayscale frames for choice...
# 223. Augmenting grayscale frames for choose...
# 224. Augmenting grayscale frames for chose...
# 225. Augmenting grayscale frames for chrome...
# 226. Augmenting grayscale frames for chuck...
# 227. Augmenting grayscale frames for church...
# 228. Augmenting grayscale frames for cite...
# 229. Augmenting grayscale frames for claim...
# 230. Augmenting grayscale frames for clash...
# 231. Augmenting grayscale frames for class...
# 232. Augmenting grayscale frames for clause...
# 233. Augmenting grayscale frames for clay...
# 234. Augmenting grayscale frames for clean...
# 235. Augmenting grayscale frames for clear...
# 236. Augmenting grayscale frames for clerk...
# 237. Augmenting grayscale frames for click...
# 238. Augmenting grayscale frames for cliff...
# 239. Augmenting grayscale frames for climb...
# 240. Augmenting grayscale frames for cling...
# 241. Augmenting grayscale frames for clip...
# 242. Augmenting grayscale frames for clips...
# 243. Augmenting grayscale frames for clock...
# 244. Augmenting grayscale frames for clone...
# 245. Augmenting grayscale frames for close...
# 246. Augmenting grayscale frames for closed...
# 247. Augmenting grayscale frames for cloth...
# 248. Augmenting grayscale frames for clothes...
# 249. Augmenting grayscale frames for cloud...
# 250. Augmenting grayscale frames for club...
# 251. Augmenting grayscale frames for clue...
# 252. Augmenting grayscale frames for clutch...
# 253. Augmenting grayscale frames for coach...
# 254. Augmenting grayscale frames for coal...
# 255. Augmenting grayscale frames for coast...
# 256. Augmenting grayscale frames for coat...
# 257. Augmenting grayscale frames for cock...
# 258. Augmenting grayscale frames for cod...
# 259. Augmenting grayscale frames for code...
# 260. Augmenting grayscale frames for coin...
# 261. Augmenting grayscale frames for cold...
# 262. Augmenting grayscale frames for com...
# 263. Augmenting grayscale frames for come...
# 264. Augmenting grayscale frames for con...
# 265. Augmenting grayscale frames for cook...
# 266. Augmenting grayscale frames for cool...
# 267. Augmenting grayscale frames for cope...
# 268. Augmenting grayscale frames for cord...
# 269. Augmenting grayscale frames for core...
# 270. Augmenting grayscale frames for corn...
# 271. Augmenting grayscale frames for corps...
# 272. Augmenting grayscale frames for cost...
# 273. Augmenting grayscale frames for could...
# 274. Augmenting grayscale frames for count...
# 275. Augmenting grayscale frames for coup...
# 276. Augmenting grayscale frames for court...
# 277. Augmenting grayscale frames for cow...
# 278. Augmenting grayscale frames for cox...
# 279. Augmenting grayscale frames for crack...
# 280. Augmenting grayscale frames for craft...
# 281. Augmenting grayscale frames for crap...
# 282. Augmenting grayscale frames for crash...
# 283. Augmenting grayscale frames for crawl...
# 284. Augmenting grayscale frames for cream...
# 285. Augmenting grayscale frames for creek...
# 286. Augmenting grayscale frames for creep...
# 287. Augmenting grayscale frames for crew...
# 288. Augmenting grayscale frames for crime...
# 289. Augmenting grayscale frames for crisp...
# 290. Augmenting grayscale frames for crop...
# 291. Augmenting grayscale frames for cross...
# 292. Augmenting grayscale frames for crowd...
# 293. Augmenting grayscale frames for crown...
# 294. Augmenting grayscale frames for crude...
# 295. Augmenting grayscale frames for cruise...
# 296. Augmenting grayscale frames for crush...
# 297. Augmenting grayscale frames for cry...
# 298. Augmenting grayscale frames for cup...
# 299. Augmenting grayscale frames for cure...
# 300. Augmenting grayscale frames for curl...
# 301. Augmenting grayscale frames for curve...
# 302. Augmenting grayscale frames for cut...
# 303. Augmenting grayscale frames for cute...
# 304. Augmenting grayscale frames for dad...
# 305. Augmenting grayscale frames for dale...
# 306. Augmenting grayscale frames for dam...
# 307. Augmenting grayscale frames for damp...
# 308. Augmenting grayscale frames for dan...
# 309. Augmenting grayscale frames for dance...
# 310. Augmenting grayscale frames for dare...
# 311. Augmenting grayscale frames for dark...
# 312. Augmenting grayscale frames for date...
# 313. Augmenting grayscale frames for dates...
# 314. Augmenting grayscale frames for dawn...
# 315. Augmenting grayscale frames for day...
# 316. Augmenting grayscale frames for days...
# 317. Augmenting grayscale frames for dead...
# 318. Augmenting grayscale frames for deaf...
# 319. Augmenting grayscale frames for deal...
# 320. Augmenting grayscale frames for dean...
# 321. Augmenting grayscale frames for dear...
# 322. Augmenting grayscale frames for death...
# 323. Augmenting grayscale frames for debt...
# 324. Augmenting grayscale frames for deck...
# 325. Augmenting grayscale frames for deem...
# 326. Augmenting grayscale frames for deep...
# 327. Augmenting grayscale frames for deer...
# 328. Augmenting grayscale frames for deft...
# 329. Augmenting grayscale frames for den...
# 330. Augmenting grayscale frames for depth...
# 331. Augmenting grayscale frames for desk...
# 332. Augmenting grayscale frames for dial...
# 333. Augmenting grayscale frames for did...
# 334. Augmenting grayscale frames for die...
# 335. Augmenting grayscale frames for dig...
# 336. Augmenting grayscale frames for dim...
# 337. Augmenting grayscale frames for dip...
# 338. Augmenting grayscale frames for dire...
# 339. Augmenting grayscale frames for dirt...
# 340. Augmenting grayscale frames for dish...
# 341. Augmenting grayscale frames for disk...
# 342. Augmenting grayscale frames for dive...
# 343. Augmenting grayscale frames for do...
# 344. Augmenting grayscale frames for dodge...
# 345. Augmenting grayscale frames for doe...
# 346. Augmenting grayscale frames for does...
# 347. Augmenting grayscale frames for dog...
# 348. Augmenting grayscale frames for dogs...
# 349. Augmenting grayscale frames for doll...
# 350. Augmenting grayscale frames for don...
# 351. Augmenting grayscale frames for done...
# 352. Augmenting grayscale frames for door...
# 353. Augmenting grayscale frames for dose...
# 354. Augmenting grayscale frames for dot...
# 355. Augmenting grayscale frames for doubt...
# 356. Augmenting grayscale frames for down...
# 357. Augmenting grayscale frames for drab...
# 358. Augmenting grayscale frames for draft...
# 359. Augmenting grayscale frames for drag...
# 360. Augmenting grayscale frames for drain...
# 361. Augmenting grayscale frames for draw...
# 362. Augmenting grayscale frames for drawn...
# 363. Augmenting grayscale frames for dream...
# 364. Augmenting grayscale frames for dress...
# 365. Augmenting grayscale frames for drew...
# 366. Augmenting grayscale frames for drift...
# 367. Augmenting grayscale frames for drill...
# 368. Augmenting grayscale frames for drink...
# 369. Augmenting grayscale frames for drive...
# 370. Augmenting grayscale frames for drop...
# 371. Augmenting grayscale frames for drops...
# 372. Augmenting grayscale frames for drown...
# 373. Augmenting grayscale frames for drug...
# 374. Augmenting grayscale frames for drum...
# 375. Augmenting grayscale frames for drunk...
# 376. Augmenting grayscale frames for dry...
# 377. Augmenting grayscale frames for duck...
# 378. Augmenting grayscale frames for due...
# 379. Augmenting grayscale frames for duke...
# 380. Augmenting grayscale frames for dull...
# 381. Augmenting grayscale frames for dumb...
# 382. Augmenting grayscale frames for dump...
# 383. Augmenting grayscale frames for dust...
# 384. Augmenting grayscale frames for dutch...
# 385. Augmenting grayscale frames for each...
# 386. Augmenting grayscale frames for ear...
# 387. Augmenting grayscale frames for earl...
# 388. Augmenting grayscale frames for earn...
# 389. Augmenting grayscale frames for earth...
# 390. Augmenting grayscale frames for ease...
# 391. Augmenting grayscale frames for east...
# 392. Augmenting grayscale frames for eat...
# 393. Augmenting grayscale frames for edge...
# 394. Augmenting grayscale frames for edit...
# 395. Augmenting grayscale frames for egg...
# 396. Augmenting grayscale frames for eight...
# 397. Augmenting grayscale frames for elect...
# 398. Augmenting grayscale frames for else...
# 399. Augmenting grayscale frames for end...
# 400. Augmenting grayscale frames for eve...
# 401. Augmenting grayscale frames for eye...
# 402. Augmenting grayscale frames for eyes...
# 403. Augmenting grayscale frames for face...
# 404. Augmenting grayscale frames for fact...
# 405. Augmenting grayscale frames for fade...
# 406. Augmenting grayscale frames for fail...
# 407. Augmenting grayscale frames for faint...
# 408. Augmenting grayscale frames for fair...
# 409. Augmenting grayscale frames for faith...
# 410. Augmenting grayscale frames for fake...
# 411. Augmenting grayscale frames for fall...
# 412. Augmenting grayscale frames for false...
# 413. Augmenting grayscale frames for fame...
# 414. Augmenting grayscale frames for fan...
# 415. Augmenting grayscale frames for far...
# 416. Augmenting grayscale frames for farm...
# 417. Augmenting grayscale frames for fast...
# 418. Augmenting grayscale frames for fat...
# 419. Augmenting grayscale frames for fate...
# 420. Augmenting grayscale frames for fault...
# 421. Augmenting grayscale frames for fear...
# 422. Augmenting grayscale frames for fed...
# 423. Augmenting grayscale frames for fee...
# 424. Augmenting grayscale frames for feed...
# 425. Augmenting grayscale frames for feel...
# 426. Augmenting grayscale frames for feet...
# 427. Augmenting grayscale frames for fell...
# 428. Augmenting grayscale frames for felt...
# 429. Augmenting grayscale frames for fence...
# 430. Augmenting grayscale frames for fetch...
# 431. Augmenting grayscale frames for few...
# 432. Augmenting grayscale frames for field...
# 433. Augmenting grayscale frames for fierce...
# 434. Augmenting grayscale frames for fifth...
# 435. Augmenting grayscale frames for fight...
# 436. Augmenting grayscale frames for file...
# 437. Augmenting grayscale frames for fill...
# 438. Augmenting grayscale frames for film...
# 439. Augmenting grayscale frames for finance...
# 440. Augmenting grayscale frames for find...
# 441. Augmenting grayscale frames for fine...
# 442. Augmenting grayscale frames for fire...
# 443. Augmenting grayscale frames for firm...
# 444. Augmenting grayscale frames for first...
# 445. Augmenting grayscale frames for fish...
# 446. Augmenting grayscale frames for fit...
# 447. Augmenting grayscale frames for five...
# 448. Augmenting grayscale frames for fix...
# 449. Augmenting grayscale frames for fixed...
# 450. Augmenting grayscale frames for flag...
# 451. Augmenting grayscale frames for flags...
# 452. Augmenting grayscale frames for flame...
# 453. Augmenting grayscale frames for flash...
# 454. Augmenting grayscale frames for flat...
# 455. Augmenting grayscale frames for flee...
# 456. Augmenting grayscale frames for fleet...
# 457. Augmenting grayscale frames for flesh...
# 458. Augmenting grayscale frames for flight...
# 459. Augmenting grayscale frames for fling...
# 460. Augmenting grayscale frames for flip...
# 461. Augmenting grayscale frames for float...
# 462. Augmenting grayscale frames for flood...
# 463. Augmenting grayscale frames for floor...
# 464. Augmenting grayscale frames for flow...
# 465. Augmenting grayscale frames for flu...
# 466. Augmenting grayscale frames for fly...
# 467. Augmenting grayscale frames for foam...
# 468. Augmenting grayscale frames for fold...
# 469. Augmenting grayscale frames for folk...
# 470. Augmenting grayscale frames for fond...
# 471. Augmenting grayscale frames for font...
# 472. Augmenting grayscale frames for food...
# 473. Augmenting grayscale frames for fool...
# 474. Augmenting grayscale frames for foot...
# 475. Augmenting grayscale frames for for...
# 476. Augmenting grayscale frames for force...
# 477. Augmenting grayscale frames for forced...
# 478. Augmenting grayscale frames for fork...
# 479. Augmenting grayscale frames for form...
# 480. Augmenting grayscale frames for fort...
# 481. Augmenting grayscale frames for forth...
# 482. Augmenting grayscale frames for foul...
# 483. Augmenting grayscale frames for found...
# 484. Augmenting grayscale frames for four...
# 485. Augmenting grayscale frames for fourth...
# 486. Augmenting grayscale frames for fox...
# 487. Augmenting grayscale frames for frail...
# 488. Augmenting grayscale frames for frame...
# 489. Augmenting grayscale frames for frank...
# 490. Augmenting grayscale frames for fraud...
# 491. Augmenting grayscale frames for free...
# 492. Augmenting grayscale frames for freeze...
# 493. Augmenting grayscale frames for freight...
# 494. Augmenting grayscale frames for french...
# 495. Augmenting grayscale frames for fresh...
# 496. Augmenting grayscale frames for friend...
# 497. Augmenting grayscale frames for frog...
# 498. Augmenting grayscale frames for from...
# 499. Augmenting grayscale frames for front...
# 500. Augmenting grayscale frames for frown...
# 501. Augmenting grayscale frames for fruit...
# 502. Augmenting grayscale frames for fuck...
# 503. Augmenting grayscale frames for fuel...
# 504. Augmenting grayscale frames for full...
# 505. Augmenting grayscale frames for fun...
# 506. Augmenting grayscale frames for fund...
# 507. Augmenting grayscale frames for funds...
# 508. Augmenting grayscale frames for gain...
# 509. Augmenting grayscale frames for gains...
# 510. Augmenting grayscale frames for game...
# 511. Augmenting grayscale frames for gang...
# 512. Augmenting grayscale frames for gap...
# 513. Augmenting grayscale frames for gas...
# 514. Augmenting grayscale frames for gasp...
# 515. Augmenting grayscale frames for gate...
# 516. Augmenting grayscale frames for gauge...
# 517. Augmenting grayscale frames for gaunt...
# 518. Augmenting grayscale frames for gave...
# 519. Augmenting grayscale frames for gay...
# 520. Augmenting grayscale frames for gaze...
# 521. Augmenting grayscale frames for gear...
# 522. Augmenting grayscale frames for geek...
# 523. Augmenting grayscale frames for gel...
# 524. Augmenting grayscale frames for gene...
# 525. Augmenting grayscale frames for get...
# 526. Augmenting grayscale frames for ghost...
# 527. Augmenting grayscale frames for gift...
# 528. Augmenting grayscale frames for girl...
# 529. Augmenting grayscale frames for give...
# 530. Augmenting grayscale frames for glad...
# 531. Augmenting grayscale frames for glance...
# 532. Augmenting grayscale frames for glass...
# 533. Augmenting grayscale frames for glen...
# 534. Augmenting grayscale frames for globe...
# 535. Augmenting grayscale frames for gnome...
# 536. Augmenting grayscale frames for go...
# 537. Augmenting grayscale frames for goal...
# 538. Augmenting grayscale frames for god...
# 539. Augmenting grayscale frames for goes...
# 540. Augmenting grayscale frames for gold...
# 541. Augmenting grayscale frames for golf...
# 542. Augmenting grayscale frames for gone...
# 543. Augmenting grayscale frames for good...
# 544. Augmenting grayscale frames for goods...
# 545. Augmenting grayscale frames for got...
# 546. Augmenting grayscale frames for grab...
# 547. Augmenting grayscale frames for grace...
# 548. Augmenting grayscale frames for grade...
# 549. Augmenting grayscale frames for grain...
# 550. Augmenting grayscale frames for grand...
# 551. Augmenting grayscale frames for grant...
# 552. Augmenting grayscale frames for graph...
# 553. Augmenting grayscale frames for grasp...
# 554. Augmenting grayscale frames for grass...
# 555. Augmenting grayscale frames for grave...
# 556. Augmenting grayscale frames for great...
# 557. Augmenting grayscale frames for green...
# 558. Augmenting grayscale frames for greet...
# 559. Augmenting grayscale frames for grew...
# 560. Augmenting grayscale frames for grey...
# 561. Augmenting grayscale frames for grid...
# 562. Augmenting grayscale frames for grill...
# 563. Augmenting grayscale frames for grim...
# 564. Augmenting grayscale frames for grin...
# 565. Augmenting grayscale frames for grip...
# 566. Augmenting grayscale frames for gross...
# 567. Augmenting grayscale frames for ground...
# 568. Augmenting grayscale frames for group...
# 569. Augmenting grayscale frames for grove...
# 570. Augmenting grayscale frames for grow...
# 571. Augmenting grayscale frames for grown...
# 572. Augmenting grayscale frames for growth...
# 573. Augmenting grayscale frames for guard...
# 574. Augmenting grayscale frames for guess...
# 575. Augmenting grayscale frames for guest...
# 576. Augmenting grayscale frames for guide...
# 577. Augmenting grayscale frames for guild...
# 578. Augmenting grayscale frames for guilt...
# 579. Augmenting grayscale frames for gulf...
# 580. Augmenting grayscale frames for gun...
# 581. Augmenting grayscale frames for guns...582. Augmenting grayscale frames for guy...
#
# 583. Augmenting grayscale frames for gym...
# 584. Augmenting grayscale frames for had...
# 585. Augmenting grayscale frames for hair...
# 586. Augmenting grayscale frames for half...
# 587. Augmenting grayscale frames for hall...
# 588. Augmenting grayscale frames for halt...
# 589. Augmenting grayscale frames for hand...
# 590. Augmenting grayscale frames for hands...
# 591. Augmenting grayscale frames for hang...
# 592. Augmenting grayscale frames for hard...
# 593. Augmenting grayscale frames for harm...
# 594. Augmenting grayscale frames for harsh...
# 595. Augmenting grayscale frames for has...
# 596. Augmenting grayscale frames for hat...
# 597. Augmenting grayscale frames for hate...
# 598. Augmenting grayscale frames for have...
# 599. Augmenting grayscale frames for head...
# 600. Augmenting grayscale frames for heads...
# 601. Augmenting grayscale frames for health...
# 602. Augmenting grayscale frames for hear...
# 603. Augmenting grayscale frames for heart...
# 604. Augmenting grayscale frames for hearts...
# 605. Augmenting grayscale frames for heat...
# 606. Augmenting grayscale frames for heel...
# 607. Augmenting grayscale frames for height...
# 608. Augmenting grayscale frames for held...
# 609. Augmenting grayscale frames for hell...
# 610. Augmenting grayscale frames for help...
# 611. Augmenting grayscale frames for hence...
# 612. Augmenting grayscale frames for her...
# 613. Augmenting grayscale frames for here...
# 614. Augmenting grayscale frames for hey...
# 615. Augmenting grayscale frames for hide...
# 616. Augmenting grayscale frames for high...
# 617. Augmenting grayscale frames for hill...
# 618. Augmenting grayscale frames for hills...
# 619. Augmenting grayscale frames for him...
# 620. Augmenting grayscale frames for hint...
# 621. Augmenting grayscale frames for hip...
# 622. Augmenting grayscale frames for hire...
# 623. Augmenting grayscale frames for his...
# 625. Augmenting grayscale frames for hold...
# 624. Augmenting grayscale frames for hit...
# 626. Augmenting grayscale frames for hole...
# 627. Augmenting grayscale frames for home...
# 628. Augmenting grayscale frames for hood...
# 629. Augmenting grayscale frames for hook...
# 630. Augmenting grayscale frames for hop...
# 631. Augmenting grayscale frames for hope...
# 632. Augmenting grayscale frames for horn...
# 633. Augmenting grayscale frames for horse...
# 634. Augmenting grayscale frames for host...
# 636. Augmenting grayscale frames for hour...635. Augmenting grayscale frames for hot...
#
# 637. Augmenting grayscale frames for hours...
# 638. Augmenting grayscale frames for house...
# 639. Augmenting grayscale frames for how...
# 640. Augmenting grayscale frames for hub...
# 641. Augmenting grayscale frames for huge...
# 642. Augmenting grayscale frames for hung...
# 643. Augmenting grayscale frames for hunt...
# 644. Augmenting grayscale frames for hurt...
# 645. Augmenting grayscale frames for ice...
# 646. Augmenting grayscale frames for ill...
# 647. Augmenting grayscale frames for in...
# 648. Augmenting grayscale frames for inch...
# 649. Augmenting grayscale frames for ink...
# 650. Augmenting grayscale frames for inter...
# 651. Augmenting grayscale frames for intro...
# 652. Augmenting grayscale frames for isle...
# 653. Augmenting grayscale frames for its...
# 654. Augmenting grayscale frames for jack...
# 655. Augmenting grayscale frames for jam...
# 656. Augmenting grayscale frames for jane...
# 657. Augmenting grayscale frames for jazz...
# 658. Augmenting grayscale frames for jean...
# 659. Augmenting grayscale frames for jeans...
# 660. Augmenting grayscale frames for jeep...
# 661. Augmenting grayscale frames for jet...
# 662. Augmenting grayscale frames for jew...
# 663. Augmenting grayscale frames for job...
# 664. Augmenting grayscale frames for joe...
# 665. Augmenting grayscale frames for john...
# 666. Augmenting grayscale frames for join...
# 667. Augmenting grayscale frames for joint...
# 668. Augmenting grayscale frames for joke...
# 669. Augmenting grayscale frames for joy...
# 670. Augmenting grayscale frames for judge...
# 671. Augmenting grayscale frames for juice...
# 672. Augmenting grayscale frames for jump...
# 673. Augmenting grayscale frames for just...
# 674. Augmenting grayscale frames for keen...
# 675. Augmenting grayscale frames for keep...
# 676. Augmenting grayscale frames for ken...
# 677. Augmenting grayscale frames for kept...
# 678. Augmenting grayscale frames for key...
# 679. Augmenting grayscale frames for kick...680. Augmenting grayscale frames for kid...
#
# 681. Augmenting grayscale frames for kill...
# 682. Augmenting grayscale frames for kind...
# 683. Augmenting grayscale frames for king...
# 684. Augmenting grayscale frames for kiss...
# 685. Augmenting grayscale frames for kit...
# 686. Augmenting grayscale frames for knee...
# 687. Augmenting grayscale frames for knew...
# 688. Augmenting grayscale frames for knife...
# 689. Augmenting grayscale frames for knight...
# 690. Augmenting grayscale frames for knit...
# 691. Augmenting grayscale frames for knives...
# 692. Augmenting grayscale frames for knock...
# 693. Augmenting grayscale frames for know...
# 694. Augmenting grayscale frames for known...
# 695. Augmenting grayscale frames for lab...
# 696. Augmenting grayscale frames for lack...
# 697. Augmenting grayscale frames for lad...
# 698. Augmenting grayscale frames for laid...
# 699. Augmenting grayscale frames for lake...
# 700. Augmenting grayscale frames for lame...
# 701. Augmenting grayscale frames for lamp...
# 702. Augmenting grayscale frames for land...
# 703. Augmenting grayscale frames for lands...
# 704. Augmenting grayscale frames for lane...
# 705. Augmenting grayscale frames for large...
# 706. Augmenting grayscale frames for last...
# 707. Augmenting grayscale frames for late...
# 708. Augmenting grayscale frames for laugh...
# 709. Augmenting grayscale frames for launch...
# 710. Augmenting grayscale frames for law...
# 711. Augmenting grayscale frames for lawn...
# 712. Augmenting grayscale frames for lay...
# 713. Augmenting grayscale frames for lead...
# 714. Augmenting grayscale frames for leaf...
# 715. Augmenting grayscale frames for league...
# 716. Augmenting grayscale frames for lean...
# 717. Augmenting grayscale frames for leap...
# 718. Augmenting grayscale frames for learn...
# 719. Augmenting grayscale frames for lease...
# 720. Augmenting grayscale frames for least...
# 721. Augmenting grayscale frames for leave...
# 722. Augmenting grayscale frames for leaves...
# 723. Augmenting grayscale frames for led...
# 724. Augmenting grayscale frames for left...
# 725. Augmenting grayscale frames for leg...
# 726. Augmenting grayscale frames for lend...
# 727. Augmenting grayscale frames for length...
# 728. Augmenting grayscale frames for lens...
# 729. Augmenting grayscale frames for less...
# 730. Augmenting grayscale frames for let...
# 731. Augmenting grayscale frames for lie...
# 732. Augmenting grayscale frames for life...
# 733. Augmenting grayscale frames for lift...
# 734. Augmenting grayscale frames for light...
# 735. Augmenting grayscale frames for lights...
# 736. Augmenting grayscale frames for like...
# 737. Augmenting grayscale frames for limp...
# 738. Augmenting grayscale frames for line...
# 739. Augmenting grayscale frames for lines...
# 740. Augmenting grayscale frames for link...
# 741. Augmenting grayscale frames for linked...
# 742. Augmenting grayscale frames for links...
# 743. Augmenting grayscale frames for lip...
# 744. Augmenting grayscale frames for list...
# 745. Augmenting grayscale frames for lists...
# 746. Augmenting grayscale frames for live...
# 747. Augmenting grayscale frames for lived...
# 748. Augmenting grayscale frames for lives...
# 749. Augmenting grayscale frames for load...
# 750. Augmenting grayscale frames for loads...
# 751. Augmenting grayscale frames for loan...
# 752. Augmenting grayscale frames for lock...
# 753. Augmenting grayscale frames for lodge...
# 754. Augmenting grayscale frames for log...
# 755. Augmenting grayscale frames for long...
# 756. Augmenting grayscale frames for look...
# 757. Augmenting grayscale frames for loop...
# 758. Augmenting grayscale frames for loose...
# 759. Augmenting grayscale frames for lord...
# 760. Augmenting grayscale frames for lose...
# 761. Augmenting grayscale frames for loss...
# 762. Augmenting grayscale frames for lost...
# 763. Augmenting grayscale frames for lot...
# 764. Augmenting grayscale frames for lots...
# 765. Augmenting grayscale frames for loud...
# 766. Augmenting grayscale frames for lounge...
# 767. Augmenting grayscale frames for love...
# 768. Augmenting grayscale frames for low...
# 769. Augmenting grayscale frames for luck...
# 770. Augmenting grayscale frames for lunch...
# 771. Augmenting grayscale frames for lung...
# 772. Augmenting grayscale frames for lush...
# 773. Augmenting grayscale frames for mac...
# 774. Augmenting grayscale frames for mad...
# 775. Augmenting grayscale frames for made...
# 776. Augmenting grayscale frames for mail...
# 777. Augmenting grayscale frames for main...
# 778. Augmenting grayscale frames for make...
# 779. Augmenting grayscale frames for male...
# 780. Augmenting grayscale frames for mall...
# 781. Augmenting grayscale frames for man...
# 782. Augmenting grayscale frames for map...
# 783. Augmenting grayscale frames for march...
# 784. Augmenting grayscale frames for mark...
# 785. Augmenting grayscale frames for marked...
# 786. Augmenting grayscale frames for mart...
# 787. Augmenting grayscale frames for mask...
# 788. Augmenting grayscale frames for mass...
# 789. Augmenting grayscale frames for mat...
# 790. Augmenting grayscale frames for match...
# 791. Augmenting grayscale frames for mate...
# 792. Augmenting grayscale frames for math...
# 793. Augmenting grayscale frames for max...
# 794. Augmenting grayscale frames for may...
# 795. Augmenting grayscale frames for mayor...
# 796. Augmenting grayscale frames for meal...
# 797. Augmenting grayscale frames for mean...
# 798. Augmenting grayscale frames for means...
# 799. Augmenting grayscale frames for meant...
# 800. Augmenting grayscale frames for meat...
# 801. Augmenting grayscale frames for meet...
# 802. Augmenting grayscale frames for melt...
# 803. Augmenting grayscale frames for men...
# 804. Augmenting grayscale frames for mere...
# 805. Augmenting grayscale frames for merge...
# 806. Augmenting grayscale frames for mesh...
# 807. Augmenting grayscale frames for mess...
# 808. Augmenting grayscale frames for met...
# 809. Augmenting grayscale frames for metal...
# 810. Augmenting grayscale frames for mic...
# 811. Augmenting grayscale frames for mice...
# 812. Augmenting grayscale frames for mid...
# 813. Augmenting grayscale frames for might...
# 814. Augmenting grayscale frames for mild...
# 815. Augmenting grayscale frames for mile...
# 816. Augmenting grayscale frames for milk...
# 817. Augmenting grayscale frames for mill...
# 818. Augmenting grayscale frames for mind...
# 819. Augmenting grayscale frames for mine...
# 820. Augmenting grayscale frames for mint...
# 821. Augmenting grayscale frames for miss...
# 822. Augmenting grayscale frames for mix...
# 823. Augmenting grayscale frames for mixed...
# 824. Augmenting grayscale frames for mod...
# 825. Augmenting grayscale frames for mode...
# 826. Augmenting grayscale frames for moist...
# 827. Augmenting grayscale frames for mom...
# 828. Augmenting grayscale frames for month...
# 829. Augmenting grayscale frames for mood...
# 830. Augmenting grayscale frames for moon...
# 831. Augmenting grayscale frames for more...
# 832. Augmenting grayscale frames for most...
# 833. Augmenting grayscale frames for mount...
# 834. Augmenting grayscale frames for mouse...
# 835. Augmenting grayscale frames for mouth...
# 836. Augmenting grayscale frames for move...
# 837. Augmenting grayscale frames for much...
# 838. Augmenting grayscale frames for mud...
# 839. Augmenting grayscale frames for mum...
# 840. Augmenting grayscale frames for must...
# 841. Augmenting grayscale frames for myth...
# 842. Augmenting grayscale frames for nail...
# 843. Augmenting grayscale frames for name...
# 844. Augmenting grayscale frames for near...
# 845. Augmenting grayscale frames for neat...
# 846. Augmenting grayscale frames for neck...
# 847. Augmenting grayscale frames for need...
# 848. Augmenting grayscale frames for needs...
# 849. Augmenting grayscale frames for nerve...
# 850. Augmenting grayscale frames for nest...
# 851. Augmenting grayscale frames for net...
# 852. Augmenting grayscale frames for new...
# 853. Augmenting grayscale frames for news...
# 854. Augmenting grayscale frames for next...
# 855. Augmenting grayscale frames for nice...
# 856. Augmenting grayscale frames for nick...
# 857. Augmenting grayscale frames for night...
# 858. Augmenting grayscale frames for nights...
# 859. Augmenting grayscale frames for nine...
# 860. Augmenting grayscale frames for no...
# 861. Augmenting grayscale frames for nod...
# 862. Augmenting grayscale frames for node...
# 863. Augmenting grayscale frames for noise...
# 864. Augmenting grayscale frames for none...
# 865. Augmenting grayscale frames for noon...
# 866. Augmenting grayscale frames for nor...
# 867. Augmenting grayscale frames for norm...
# 868. Augmenting grayscale frames for north...
# 869. Augmenting grayscale frames for nose...
# 870. Augmenting grayscale frames for not...
# 871. Augmenting grayscale frames for note...
# 872. Augmenting grayscale frames for notes...
# 873. Augmenting grayscale frames for now...
# 874. Augmenting grayscale frames for nude...
# 875. Augmenting grayscale frames for nuke...
# 876. Augmenting grayscale frames for null...
# 877. Augmenting grayscale frames for numb...
# 878. Augmenting grayscale frames for nurse...
# 879. Augmenting grayscale frames for nuts...
# 880. Augmenting grayscale frames for oak...
# 881. Augmenting grayscale frames for odd...
# 882. Augmenting grayscale frames for odds...
# 883. Augmenting grayscale frames for off...
# 884. Augmenting grayscale frames for oil...
# 885. Augmenting grayscale frames for old...
# 886. Augmenting grayscale frames for once...
# 887. Augmenting grayscale frames for one...
# 888. Augmenting grayscale frames for our...
# 889. Augmenting grayscale frames for out...890. Augmenting grayscale frames for owe...
#
# 891. Augmenting grayscale frames for own...
# 892. Augmenting grayscale frames for pace...
# 893. Augmenting grayscale frames for pack...
# 894. Augmenting grayscale frames for pad...
# 895. Augmenting grayscale frames for page...
# 896. Augmenting grayscale frames for paid...
# 897. Augmenting grayscale frames for pain...
# 898. Augmenting grayscale frames for paint...
# 899. Augmenting grayscale frames for pair...
# 900. Augmenting grayscale frames for pairs...
# 901. Augmenting grayscale frames for pal...
# 902. Augmenting grayscale frames for pale...
# 903. Augmenting grayscale frames for palm...
# 904. Augmenting grayscale frames for pan...
# 905. Augmenting grayscale frames for park...
# 906. Augmenting grayscale frames for part...
# 907. Augmenting grayscale frames for parts...
# 908. Augmenting grayscale frames for pass...
# 909. Augmenting grayscale frames for passed...
# 910. Augmenting grayscale frames for past...
# 911. Augmenting grayscale frames for paste...
# 912. Augmenting grayscale frames for pat...
# 913. Augmenting grayscale frames for patch...
# 914. Augmenting grayscale frames for path...
# 915. Augmenting grayscale frames for pause...
# 916. Augmenting grayscale frames for pay...
# 917. Augmenting grayscale frames for peace...
# 918. Augmenting grayscale frames for peak...
# 919. Augmenting grayscale frames for pearl...
# 920. Augmenting grayscale frames for pee...
# 921. Augmenting grayscale frames for peer...
# 922. Augmenting grayscale frames for pen...
# 923. Augmenting grayscale frames for per...
# 924. Augmenting grayscale frames for pet...
# 925. Augmenting grayscale frames for petrol...
# 926. Augmenting grayscale frames for phase...
# 927. Augmenting grayscale frames for phone...
# 928. Augmenting grayscale frames for phrase...
# 929. Augmenting grayscale frames for pick...
# 930. Augmenting grayscale frames for picked...
# 931. Augmenting grayscale frames for pie...
# 932. Augmenting grayscale frames for piece...
# 933. Augmenting grayscale frames for pig...
# 934. Augmenting grayscale frames for pile...
# 935. Augmenting grayscale frames for pill...
# 936. Augmenting grayscale frames for pills...
# 937. Augmenting grayscale frames for pin...
# 938. Augmenting grayscale frames for pine...
# 939. Augmenting grayscale frames for pink...
# 940. Augmenting grayscale frames for pipe...
# 941. Augmenting grayscale frames for piss...
# 942. Augmenting grayscale frames for pit...
# 943. Augmenting grayscale frames for pitch...
# 944. Augmenting grayscale frames for place...
# 945. Augmenting grayscale frames for plain...
# 946. Augmenting grayscale frames for plan...
# 947. Augmenting grayscale frames for plane...
# 948. Augmenting grayscale frames for plant...
# 949. Augmenting grayscale frames for plants...
# 950. Augmenting grayscale frames for plate...
# 951. Augmenting grayscale frames for play...
# 952. Augmenting grayscale frames for plead...
# 953. Augmenting grayscale frames for please...
# 954. Augmenting grayscale frames for plot...
# 955. Augmenting grayscale frames for plug...
# 956. Augmenting grayscale frames for plump...
# 957. Augmenting grayscale frames for plunge...
# 958. Augmenting grayscale frames for plus...
# 959. Augmenting grayscale frames for point...
# 960. Augmenting grayscale frames for pole...
# 961. Augmenting grayscale frames for poll...
# 962. Augmenting grayscale frames for pond...
# 963. Augmenting grayscale frames for pool...
# 964. Augmenting grayscale frames for poor...
# 965. Augmenting grayscale frames for pop...
# 966. Augmenting grayscale frames for pope...
# 967. Augmenting grayscale frames for port...
# 968. Augmenting grayscale frames for pose...
# 969. Augmenting grayscale frames for posh...
# 970. Augmenting grayscale frames for post...
# 971. Augmenting grayscale frames for pot...
# 972. Augmenting grayscale frames for pound...
# 973. Augmenting grayscale frames for pour...
# 974. Augmenting grayscale frames for praise...
# 975. Augmenting grayscale frames for pray...
# 976. Augmenting grayscale frames for press...
# 977. Augmenting grayscale frames for price...
# 978. Augmenting grayscale frames for pride...
# 979. Augmenting grayscale frames for priest...
# 980. Augmenting grayscale frames for prime...
# 981. Augmenting grayscale frames for prince...
# 982. Augmenting grayscale frames for print...
# 983. Augmenting grayscale frames for prize...
# 984. Augmenting grayscale frames for pro...
# 985. Augmenting grayscale frames for probe...
# 986. Augmenting grayscale frames for prompt...
# 987. Augmenting grayscale frames for proof...
# 988. Augmenting grayscale frames for pros...
# 989. Augmenting grayscale frames for proud...
# 990. Augmenting grayscale frames for prove...
# 991. Augmenting grayscale frames for pub...
# 992. Augmenting grayscale frames for pull...
# 993. Augmenting grayscale frames for pulse...
# 994. Augmenting grayscale frames for pump...
# 995. Augmenting grayscale frames for punk...
# 996. Augmenting grayscale frames for pure...
# 997. Augmenting grayscale frames for push...
# 998. Augmenting grayscale frames for put...
# 999. Augmenting grayscale frames for quaint...
# 1000. Augmenting grayscale frames for queen...
# 1001. Augmenting grayscale frames for queer...
# 1002. Augmenting grayscale frames for quest...
# 1003. Augmenting grayscale frames for quick...
# 1004. Augmenting grayscale frames for quit...
# 1005. Augmenting grayscale frames for quite...
# 1006. Augmenting grayscale frames for quiz...
# 1007. Augmenting grayscale frames for quote...
# 1008. Augmenting grayscale frames for race...
# 1009. Augmenting grayscale frames for rack...
# 1010. Augmenting grayscale frames for raid...
# 1011. Augmenting grayscale frames for rail...
# 1012. Augmenting grayscale frames for rain...
# 1013. Augmenting grayscale frames for raise...
# 1014. Augmenting grayscale frames for raised...
# 1015. Augmenting grayscale frames for ram...
# 1016. Augmenting grayscale frames for ran...
# 1017. Augmenting grayscale frames for ranch...
# 1018. Augmenting grayscale frames for range...
# 1019. Augmenting grayscale frames for rank...
# 1020. Augmenting grayscale frames for rap...
# 1021. Augmenting grayscale frames for rare...
# 1022. Augmenting grayscale frames for rat...
# 1023. Augmenting grayscale frames for rate...
# 1024. Augmenting grayscale frames for rates...
# 1025. Augmenting grayscale frames for rats...
# 1026. Augmenting grayscale frames for raw...
# 1027. Augmenting grayscale frames for ray...
# 1028. Augmenting grayscale frames for reach...
# 1029. Augmenting grayscale frames for react...
# 1030. Augmenting grayscale frames for read...
# 1031. Augmenting grayscale frames for rear...
# 1032. Augmenting grayscale frames for red...
# 1033. Augmenting grayscale frames for refer...
# 1034. Augmenting grayscale frames for reign...
# 1035. Augmenting grayscale frames for rent...
# 1036. Augmenting grayscale frames for rest...
# 1037. Augmenting grayscale frames for rice...
# 1038. Augmenting grayscale frames for rich...
# 1039. Augmenting grayscale frames for rick...
# 1040. Augmenting grayscale frames for rid...
# 1041. Augmenting grayscale frames for ride...
# 1042. Augmenting grayscale frames for ridge...
# 1043. Augmenting grayscale frames for right...
# 1044. Augmenting grayscale frames for rights...
# 1045. Augmenting grayscale frames for ring...
# 1046. Augmenting grayscale frames for rip...
# 1047. Augmenting grayscale frames for ripe...
# 1048. Augmenting grayscale frames for rise...
# 1049. Augmenting grayscale frames for risk...
# 1050. Augmenting grayscale frames for road...
# 1051. Augmenting grayscale frames for roast...
# 1052. Augmenting grayscale frames for rob...
# 1053. Augmenting grayscale frames for rock...
# 1054. Augmenting grayscale frames for rod...
# 1055. Augmenting grayscale frames for role...
# 1056. Augmenting grayscale frames for roll...
# 1057. Augmenting grayscale frames for rom...
# 1058. Augmenting grayscale frames for roof...
# 1059. Augmenting grayscale frames for room...
# 1060. Augmenting grayscale frames for root...
# 1061. Augmenting grayscale frames for rope...
# 1062. Augmenting grayscale frames for rose...
# ...
# 1250. Augmenting grayscale frames for spill...
# 1251. Augmenting grayscale frames for spin...
# 1252. Augmenting grayscale frames for split...
# 1253. Augmenting grayscale frames for spoil...
# 1254. Augmenting grayscale frames for spoilt...
# 1255. Augmenting grayscale frames for spoke...
# 1256. Augmenting grayscale frames for sport...
# 1257. Augmenting grayscale frames for sports...
# 1258. Augmenting grayscale frames for spot...
# 1259. Augmenting grayscale frames for spouse...
# 1260. Augmenting grayscale frames for spray...
# 1261. Augmenting grayscale frames for spread...
# 1262. Augmenting grayscale frames for spring...
# 1263. Augmenting grayscale frames for sprint...
# 1264. Augmenting grayscale frames for spy...
# 1265. Augmenting grayscale frames for squad...
# 1266. Augmenting grayscale frames for square...
# 1267. Augmenting grayscale frames for squeeze...
# 1268. Augmenting grayscale frames for stack...
# 1269. Augmenting grayscale frames for staff...
# 1270. Augmenting grayscale frames for stage...
# 1271. Augmenting grayscale frames for staid...
# 1272. Augmenting grayscale frames for stairs...
# 1273. Augmenting grayscale frames for stake...
# 1274. Augmenting grayscale frames for stale...
# 1275. Augmenting grayscale frames for stamp...
# 1276. Augmenting grayscale frames for stance...
# 1277. Augmenting grayscale frames for stand...
# 1278. Augmenting grayscale frames for star...
# 1279. Augmenting grayscale frames for stare...
# 1280. Augmenting grayscale frames for start...
# 1281. Augmenting grayscale frames for stat...
# 1282. Augmenting grayscale frames for state...
# 1283. Augmenting grayscale frames for staunch...
# 1284. Augmenting grayscale frames for stay...
# 1285. Augmenting grayscale frames for steal...
# 1286. Augmenting grayscale frames for steam...
# 1287. Augmenting grayscale frames for steel...
# 1288. Augmenting grayscale frames for steep...
# 1289. Augmenting grayscale frames for stem...
# 1290. Augmenting grayscale frames for step...
# 1291. Augmenting grayscale frames for stick...
# 1292. Augmenting grayscale frames for stiff...
# 1293. Augmenting grayscale frames for still...
# 1294. Augmenting grayscale frames for stir...
# 1295. Augmenting grayscale frames for stock...
# 1296. Augmenting grayscale frames for stocks...
# 1297. Augmenting grayscale frames for stone...
# 1298. Augmenting grayscale frames for stood...
# 1299. Augmenting grayscale frames for stop...
# 1300. Augmenting grayscale frames for stopped...
# 1301. Augmenting grayscale frames for stops...
# 1302. Augmenting grayscale frames for store...
# 1303. Augmenting grayscale frames for stores...
# 1304. Augmenting grayscale frames for storm...
# 1305. Augmenting grayscale frames for stout...
# 1306. Augmenting grayscale frames for straight...
# 1307. Augmenting grayscale frames for strain...
# 1308. Augmenting grayscale frames for strange...
# 1309. Augmenting grayscale frames for strap...
# 1310. Augmenting grayscale frames for stream...
# 1311. Augmenting grayscale frames for street...
# 1312. Augmenting grayscale frames for strength...
# 1313. Augmenting grayscale frames for stress...
# 1314. Augmenting grayscale frames for stretch...
# 1315. Augmenting grayscale frames for strict...
# 1316. Augmenting grayscale frames for strike...
# 1317. Augmenting grayscale frames for string...
# 1318. Augmenting grayscale frames for strip...
# 1319. Augmenting grayscale frames for stroke...
# 1320. Augmenting grayscale frames for strong...
# 1321. Augmenting grayscale frames for struck...
# 1322. Augmenting grayscale frames for stuck...
# 1323. Augmenting grayscale frames for stud...
# 1324. Augmenting grayscale frames for stuff...
# 1325. Augmenting grayscale frames for style...
# 1326. Augmenting grayscale frames for sub...
# 1327. Augmenting grayscale frames for such...
# 1328. Augmenting grayscale frames for suck...
# 1329. Augmenting grayscale frames for sucks...
# 1330. Augmenting grayscale frames for sue...
# 1331. Augmenting grayscale frames for suite...
# 1332. Augmenting grayscale frames for sum...
# 1333. Augmenting grayscale frames for sun...
# 1334. Augmenting grayscale frames for super...
# 1335. Augmenting grayscale frames for sure...
# 1336. Augmenting grayscale frames for surf...
# 1337. Augmenting grayscale frames for swap...
# 1338. Augmenting grayscale frames for swear...
# 1339. Augmenting grayscale frames for sweep...
# 1340. Augmenting grayscale frames for sweet...
# 1341. Augmenting grayscale frames for swift...
# 1342. Augmenting grayscale frames for swim...
# 1343. Augmenting grayscale frames for swing...
# 1344. Augmenting grayscale frames for switch...
# 1345. Augmenting grayscale frames for sword...
# 1346. Augmenting grayscale frames for tab...
# 1347. Augmenting grayscale frames for tag...
# 1348. Augmenting grayscale frames for tail...
# 1349. Augmenting grayscale frames for take...
# 1350. Augmenting grayscale frames for tale...
# 1351. Augmenting grayscale frames for talk...
# 1352. Augmenting grayscale frames for tall...
# 1353. Augmenting grayscale frames for tame...
# 1354. Augmenting grayscale frames for tan...
# 1355. Augmenting grayscale frames for tank...
# 1356. Augmenting grayscale frames for tap...
# 1357. Augmenting grayscale frames for tape...
# 1358. Augmenting grayscale frames for task...
# 1359. Augmenting grayscale frames for taste...
# 1360. Augmenting grayscale frames for taught...
# 1361. Augmenting grayscale frames for tax...
# 1362. Augmenting grayscale frames for tea...
# 1363. Augmenting grayscale frames for teach...
# 1364. Augmenting grayscale frames for team...
# 1365. Augmenting grayscale frames for tear...
# 1366. Augmenting grayscale frames for tears...
# 1367. Augmenting grayscale frames for tech...
# 1368. Augmenting grayscale frames for ted...
# 1369. Augmenting grayscale frames for teen...
# 1370. Augmenting grayscale frames for teens...
# 1371. Augmenting grayscale frames for teeth...
# 1372. Augmenting grayscale frames for tell...
# 1373. Augmenting grayscale frames for tempt...
# 1374. Augmenting grayscale frames for ten...
# 1375. Augmenting grayscale frames for tend...
# 1376. Augmenting grayscale frames for term...
# 1377. Augmenting grayscale frames for terms...
# 1378. Augmenting grayscale frames for test...
# 1379. Augmenting grayscale frames for text...
# 1380. Augmenting grayscale frames for than...
# 1381. Augmenting grayscale frames for thank...
# 1382. Augmenting grayscale frames for thanks...
# 1383. Augmenting grayscale frames for that...
# 1384. Augmenting grayscale frames for the...
# 1385. Augmenting grayscale frames for theft...
# 1386. Augmenting grayscale frames for their...
# 1387. Augmenting grayscale frames for them...
# 1388. Augmenting grayscale frames for theme...
# 1389. Augmenting grayscale frames for then...
# 1390. Augmenting grayscale frames for there...
# 1391. Augmenting grayscale frames for these...
# 1392. Augmenting grayscale frames for they...
# 1393. Augmenting grayscale frames for thick...
# 1394. Augmenting grayscale frames for thin...
# 1395. Augmenting grayscale frames for thing...
# 1396. Augmenting grayscale frames for think...
# 1397. Augmenting grayscale frames for third...
# 1398. Augmenting grayscale frames for this...
# 1399. Augmenting grayscale frames for those...
# 1400. Augmenting grayscale frames for thought...
# 1401. Augmenting grayscale frames for thread...
# 1402. Augmenting grayscale frames for threat...
# 1403. Augmenting grayscale frames for three...
# 1404. Augmenting grayscale frames for throat...
# 1405. Augmenting grayscale frames for through...
# 1406. Augmenting grayscale frames for throw...
# 1407. Augmenting grayscale frames for thrust...
# 1408. Augmenting grayscale frames for thus...
# 1409. Augmenting grayscale frames for tide...
# 1410. Augmenting grayscale frames for tie...
# 1411. Augmenting grayscale frames for tied...
# 1412. Augmenting grayscale frames for tight...
# 1413. Augmenting grayscale frames for tile...
# 1414. Augmenting grayscale frames for till...
# 1415. Augmenting grayscale frames for time...
# 1416. Augmenting grayscale frames for tin...
# 1417. Augmenting grayscale frames for tip...
# 1418. Augmenting grayscale frames for tire...
# 1419. Augmenting grayscale frames for tired...
# 1420. Augmenting grayscale frames for toe...
# 1421. Augmenting grayscale frames for told...
# 1422. Augmenting grayscale frames for toll...
# 1423. Augmenting grayscale frames for tom...
# 1424. Augmenting grayscale frames for ton...
# 1425. Augmenting grayscale frames for tone...
# 1426. Augmenting grayscale frames for tongue...
# 1427. Augmenting grayscale frames for too...
# 1428. Augmenting grayscale frames for took...
# 1429. Augmenting grayscale frames for tool...
# 1430. Augmenting grayscale frames for tooth...
# 1431. Augmenting grayscale frames for top...
# 1432. Augmenting grayscale frames for tops...
# 1433. Augmenting grayscale frames for toss...
# 1434. Augmenting grayscale frames for touch...
# 1435. Augmenting grayscale frames for tough...
# 1436. Augmenting grayscale frames for tour...
# 1437. Augmenting grayscale frames for town...
# 1438. Augmenting grayscale frames for toy...
# 1439. Augmenting grayscale frames for trace...
# 1440. Augmenting grayscale frames for track...
# 1441. Augmenting grayscale frames for tracks...
# 1442. Augmenting grayscale frames for trade...
# 1443. Augmenting grayscale frames for trail...
# 1444. Augmenting grayscale frames for train...1445. Augmenting grayscale frames for trans...
#
# 1446. Augmenting grayscale frames for trap...
# 1447. Augmenting grayscale frames for tray...
# 1448. Augmenting grayscale frames for treat...
# 1449. Augmenting grayscale frames for tree...
# 1450. Augmenting grayscale frames for trek...
# 1451. Augmenting grayscale frames for trend...
# 1452. Augmenting grayscale frames for tribe...
# 1453. Augmenting grayscale frames for trick...
# 1454. Augmenting grayscale frames for tried...
# 1455. Augmenting grayscale frames for trim...
# 1456. Augmenting grayscale frames for trip...
# 1457. Augmenting grayscale frames for trite...
# 1458. Augmenting grayscale frames for troop...
# 1459. Augmenting grayscale frames for troy...
# 1460. Augmenting grayscale frames for truck...
# 1461. Augmenting grayscale frames for true...
# 1462. Augmenting grayscale frames for trunk...
# 1463. Augmenting grayscale frames for trust...
# 1464. Augmenting grayscale frames for truth...
# 1465. Augmenting grayscale frames for try...
# 1466. Augmenting grayscale frames for tub...
# 1467. Augmenting grayscale frames for tube...1468. Augmenting grayscale frames for tuck...
#
# 1469. Augmenting grayscale frames for tune...
# 1470. Augmenting grayscale frames for turn...
# 1471. Augmenting grayscale frames for twelve...
# 1472. Augmenting grayscale frames for twice...
# 1473. Augmenting grayscale frames for twin...
# 1474. Augmenting grayscale frames for twist...
# 1475. Augmenting grayscale frames for two...
# 1476. Augmenting grayscale frames for type...
# 1477. Augmenting grayscale frames for urge...
# 1478. Augmenting grayscale frames for use...
# 1479. Augmenting grayscale frames for used...
# 1480. Augmenting grayscale frames for vain...
# 1481. Augmenting grayscale frames for valve...
# 1482. Augmenting grayscale frames for van...
# 1483. Augmenting grayscale frames for vast...
# 1484. Augmenting grayscale frames for vat...
# 1485. Augmenting grayscale frames for verse...1486. Augmenting grayscale frames for vice...
#
# 1487. Augmenting grayscale frames for view...
# 1488. Augmenting grayscale frames for vile...
# 1489. Augmenting grayscale frames for voice...
# 1490. Augmenting grayscale frames for void...
# 1491. Augmenting grayscale frames for volt...
# 1492. Augmenting grayscale frames for vote...
# 1493. Augmenting grayscale frames for wage...
# 1494. Augmenting grayscale frames for wait...
# 1495. Augmenting grayscale frames for wake...
# 1496. Augmenting grayscale frames for walk...
# 1497. Augmenting grayscale frames for wall...
# 1498. Augmenting grayscale frames for want...
# 1499. Augmenting grayscale frames for war...
# 1500. Augmenting grayscale frames for ward...
# 1501. Augmenting grayscale frames for warm...
# 1502. Augmenting grayscale frames for warmth...
# 1503. Augmenting grayscale frames for warn...
# 1504. Augmenting grayscale frames for was...
# 1505. Augmenting grayscale frames for wash...
# 1506. Augmenting grayscale frames for waste...
# 1507. Augmenting grayscale frames for watch...
# 1508. Augmenting grayscale frames for watt...
# 1509. Augmenting grayscale frames for wave...
# 1510. Augmenting grayscale frames for way...
# 1511. Augmenting grayscale frames for ways...
# 1512. Augmenting grayscale frames for weak...
# 1513. Augmenting grayscale frames for wealth...
# 1514. Augmenting grayscale frames for wear...
# 1515. Augmenting grayscale frames for web...
# 1516. Augmenting grayscale frames for week...
# 1517. Augmenting grayscale frames for weigh...
# 1518. Augmenting grayscale frames for weight...
# 1519. Augmenting grayscale frames for weird...
# 1520. Augmenting grayscale frames for well...
# 1521. Augmenting grayscale frames for went...
# 1522. Augmenting grayscale frames for were...
# 1523. Augmenting grayscale frames for west...
# 1524. Augmenting grayscale frames for wet...
# 1525. Augmenting grayscale frames for what...
# 1526. Augmenting grayscale frames for wheat...
# 1527. Augmenting grayscale frames for wheel...
# 1528. Augmenting grayscale frames for wheels...
# 1529. Augmenting grayscale frames for when...
# 1530. Augmenting grayscale frames for where...
# 1531. Augmenting grayscale frames for which...
# 1532. Augmenting grayscale frames for while...
# 1533. Augmenting grayscale frames for whilst...
# 1534. Augmenting grayscale frames for white...
# 1535. Augmenting grayscale frames for who...
# 1536. Augmenting grayscale frames for whole...
# 1537. Augmenting grayscale frames for whom...
# 1538. Augmenting grayscale frames for whose...
# 1539. Augmenting grayscale frames for why...
# 1540. Augmenting grayscale frames for wide...
# 1541. Augmenting grayscale frames for width...
# 1542. Augmenting grayscale frames for wife...
# 1543. Augmenting grayscale frames for wild...
# 1544. Augmenting grayscale frames for will...
# 1545. Augmenting grayscale frames for win...
# 1546. Augmenting grayscale frames for wind...
# 1547. Augmenting grayscale frames for wine...
# 1548. Augmenting grayscale frames for wing...
# 1549. Augmenting grayscale frames for wipe...
# 1550. Augmenting grayscale frames for wire...
# 1551. Augmenting grayscale frames for wired...
# 1552. Augmenting grayscale frames for wise...
# 1553. Augmenting grayscale frames for wish...
# 1554. Augmenting grayscale frames for with...
# 1555. Augmenting grayscale frames for wolf...
# 1556. Augmenting grayscale frames for won...
# 1557. Augmenting grayscale frames for wood...
# 1558. Augmenting grayscale frames for woods...
# 1559. Augmenting grayscale frames for wool...
# 1560. Augmenting grayscale frames for word...
# 1561. Augmenting grayscale frames for words...
# 1562. Augmenting grayscale frames for work...
# 1563. Augmenting grayscale frames for worked...
# 1564. Augmenting grayscale frames for works...
# 1565. Augmenting grayscale frames for world...
# 1566. Augmenting grayscale frames for worse...
# 1567. Augmenting grayscale frames for worst...
# 1568. Augmenting grayscale frames for worth...
# 1569. Augmenting grayscale frames for would...
# 1570. Augmenting grayscale frames for wound...
# 1571. Augmenting grayscale frames for wow...
# 1572. Augmenting grayscale frames for wrap...
# 1573. Augmenting grayscale frames for write...
# 1574. Augmenting grayscale frames for wrong...
# 1575. Augmenting grayscale frames for wrote...
# 1576. Augmenting grayscale frames for yard...
# 1577. Augmenting grayscale frames for year...
# 1578. Augmenting grayscale frames for yes...
# 1579. Augmenting grayscale frames for yet...
# 1580. Augmenting grayscale frames for yield...
# 1581. Augmenting grayscale frames for york...
# 1582. Augmenting grayscale frames for you...
# 1583. Augmenting grayscale frames for young...
# 1584. Augmenting grayscale frames for your...
# 1585. Augmenting grayscale frames for yours...
# 1586. Augmenting grayscale frames for youth...
# 1587. Augmenting grayscale frames for zip...
# 1588. Augmenting grayscale frames for zone...
# 1589. Augmenting grayscale frames for zoo...
# 1590. Augmenting grayscale frames for zoom...
#
# All grayscale frames augmented and saved in 'augmented_gray_dataset_uneven_frames'.

# %% [markdown]
# 2.2. augmented_dataset_uneven_frames are created. Limiting these to 60 frames (augmented_dataset_even_frames folder)

# %%
# Function to ensure there are exactly 60 frames with proper naming convention
def ensure_60_frames(frame_dir, output_dir, target_frames=60):
    # List all frame files in the directory
    frames = sorted(os.listdir(frame_dir))

    # If fewer than 60 frames, duplicate the last frame until there are 60
    if len(frames) < target_frames:
        last_frame_path = os.path.join(frame_dir, frames[-1])
        for i in range(len(frames), target_frames):
            new_frame_path = os.path.join(output_dir, f"frame{i+1:04d}.jpg")
            shutil.copy(last_frame_path, new_frame_path)  # Directly copy the last frame

    # If more than 60 frames, remove extra frames from the end
    elif len(frames) > target_frames:
        for i in range(target_frames, len(frames)):
            os.remove(os.path.join(frame_dir, frames[i]))

    # Copy all frames to the output directory with the updated naming convention
    for count, frame in enumerate(sorted(os.listdir(frame_dir))):
        input_frame_path = os.path.join(frame_dir, frame)
        output_frame_path = os.path.join(output_dir, f"frame{count+1:04d}.jpg")
        shutil.copy(input_frame_path, output_frame_path)  # Directly copy the frame

# Path where the augmented uneven grayscale frames are stored
uneven_frames_folder = r'D:\pro_dis\augmented_gray_dataset_uneven_frames'

# Output folder for storing frames with exactly 60 frames in grayscale
even_frames_folder = r'D:\pro_dis\augmented_gray_dataset_even_frames'

# Ensure all folders in "augmented_gray_dataset_uneven_frames" have exactly 60 frames and save them to "augmented_gray_dataset_even_frames"
for word_dir in os.listdir(uneven_frames_folder):
    word_frame_dir = os.path.join(uneven_frames_folder, word_dir)
    output_word_dir = os.path.join(even_frames_folder, word_dir)
    os.makedirs(output_word_dir, exist_ok=True)  # Create output directory for each word

    if os.path.isdir(word_frame_dir):
        print(f"Ensuring 60 frames for {word_dir}...")
        ensure_60_frames(word_frame_dir, output_word_dir)

print("\nAll folders processed and saved with exactly 60 frames in 'augmented_gray_dataset_even_frames'.")
# Out:
# Ensuring 60 frames for Bat...
# Ensuring 60 frames for Big...
# Ensuring 60 frames for Book...
# Ensuring 60 frames for Car...
# Ensuring 60 frames for Cat...
# Ensuring 60 frames for Cup...
# Ensuring 60 frames for Dog...
# Ensuring 60 frames for Drop...
# Ensuring 60 frames for Eat...
# Ensuring 60 frames for Fast...
# Ensuring 60 frames for Fish...
# Ensuring 60 frames for Fun...
# Ensuring 60 frames for Go...
# Ensuring 60 frames for Hat...
# Ensuring 60 frames for Hot...
# Ensuring 60 frames for Jump...
# Ensuring 60 frames for Kick...
# Ensuring 60 frames for Leg...
# Ensuring 60 frames for Milk...
# Ensuring 60 frames for No...
# Ensuring 60 frames for Pen...
# Ensuring 60 frames for Pick...
# Ensuring 60 frames for Red...
# Ensuring 60 frames for Run...
# Ensuring 60 frames for Sit...
# Ensuring 60 frames for Stop...
# Ensuring 60 frames for Sun...
# Ensuring 60 frames for Top...
# Ensuring 60 frames for Win...
# Ensuring 60 frames for Yes...
#
# All folders processed and saved with exactly 60 frames in 'augmented_gray_dataset_even_frames'.

# %% [markdown]
# 3. Cropping the mouth region with basic algorithm and saving it in different folders (original_dataset_mouth_cropped, augmented_dataset_mouth_cropped folders)

# %%
# Path to the Haar Cascade for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Helper function for natural sorting
def natural_sort_key(s, _nsre=re.compile('([0-9]+)')):
    """
    Helper function to sort strings containing numbers in human order.
    Example: frame2.jpg comes before frame10.jpg
    """
    return [int(text) if text.isdigit() else text.lower() for text in _nsre.split(s)]

# Updated function to crop the mouth region with new parameters
def crop_mouth_region(image, height_ratio=0.8, width_ratio=0.8, scale_factor=0.5):
    """
    Crop the mouth region from the detected face with adjustable height, width, and starting position.

    :param image: The input frame (already grayscale in this case).
    :param height_ratio: Proportion of the lower face height to crop (default 0.8 = 80%).
    :param width_ratio: Proportion of the face width to crop (default 0.8 = 80%).
    :param scale_factor: Proportion of the lower part of the face to start the crop (default 0.5 = 50%).
    :return: Cropped mouth region.
    """
    # Since the image is already grayscale, we skip the conversion step

    # Detect face directly using grayscale image
    faces = face_cascade.detectMultiScale(image, 1.3, 5)

    if len(faces) == 0:
        # If no face is detected, return a placeholder (black image of expected size)
        h, w = image.shape  # Adjust for grayscale (no channel)
        placeholder = np.zeros((int(h * height_ratio), int(w * width_ratio)), dtype=np.uint8)
        return placeholder

    for (x, y, w, h) in faces:
        # Calculate crop width and height based on ratios
        crop_width = int(w * width_ratio)
        crop_height = int(h * height_ratio)

        # Calculate coordinates to start cropping based on scale_factor and centering width crop
        crop_x = x + (w - crop_width) // 2  # Center the width
        crop_y = int(y + h * scale_factor)  # Start cropping from lower part of the face

        # Ensure the crop coordinates are within image bounds
        crop_x = max(0, crop_x)
        crop_y = max(0, crop_y)
        crop_width = min(crop_width, image.shape[1] - crop_x)
        crop_height = min(crop_height, image.shape[0] - crop_y)

        # Crop the mouth region based on adjusted height and width
        mouth_region = image[crop_y:crop_y + crop_height, crop_x:crop_x + crop_width]

        return mouth_region

# Function for resizing and normalization
def resize_and_normalize(image, target_size=(128, 128)):
    """
    Resize the image to the target size and normalize pixel values.

    :param image: Cropped mouth region.
    :param target_size: Target size for resizing (default is 128x128).
    :return: Resized and normalized image.
    """
    resized_image = cv2.resize(image, target_size)
    normalized_image = resized_image / 255.0
    return normalized_image

# Function to process frames, crop the mouth region, resize, and normalize
def process_frames_for_feature_extraction(frame_dir, output_dir, target_size=(128, 128)):
    """
    Process frames by cropping the mouth region, resizing to 128x128, and normalizing.

    :param frame_dir: Directory where the frames are stored.
    :param output_dir: Output directory for the processed frames.
    :param target_size: The size for resizing the cropped image.
    """
    os.makedirs(output_dir, exist_ok=True)

    # Apply natural sorting to the frames
    frames = sorted(os.listdir(frame_dir), key=natural_sort_key)

    for count, frame_name in enumerate(frames):
        frame_path = os.path.join(frame_dir, frame_name)
        frame = cv2.imread(frame_path, cv2.IMREAD_GRAYSCALE)  # Directly read in grayscale mode

        if frame is None:
            print(f"Warning: Could not read {frame_path}. Skipping.")
            continue

        # Step 1: Crop the mouth region
        mouth = crop_mouth_region(frame)

        if mouth is not None:
            # Step 2: Resize and normalize the cropped mouth region to 128x128
            resized_normalized_mouth = resize_and_normalize(mouth, target_size)

            # Save the resized and normalized frame
            save_path = os.path.join(output_dir, f"frame{count + 1:04d}.jpg")
            cv2.imwrite(save_path, (resized_normalized_mouth * 255).astype(np.uint8))  # Save as image with 0-255 pixel values

        else:
            print(f"Warning: No mouth detected in {frame_name}. Using placeholder.")

# Paths for original and augmented grayscale datasets
original_gray_frames_folder = r'D:\pro_dis\original_gray_dataset_even_frames'  # Original grayscale frames
augmented_gray_frames_folder = r'D:\pro_dis\augmented_gray_dataset_even_frames'  # Augmented grayscale frames

# Output folders for processed frames
original_gray_output_folder = r'D:\pro_dis\original_gray_dataset_mouth_cropped'  # Mouth-cropped original grayscale dataset
augmented_gray_output_folder = r'D:\pro_dis\augmented_gray_dataset_mouth_cropped'  # Mouth-cropped augmented grayscale dataset

# Process the original grayscale dataset (crop mouth, resize, normalize)
for word_dir in os.listdir(original_gray_frames_folder):
    word_frame_dir = os.path.join(original_gray_frames_folder, word_dir)
    output_dir = os.path.join(original_gray_output_folder, word_dir)  # Output folder for original grayscale dataset
    print(f"Processing {word_dir} from original grayscale dataset...")
    process_frames_for_feature_extraction(word_frame_dir, output_dir, target_size=(128, 128))

print("\nMouth cropping, resizing (128x128), and normalization complete for original datasets!\n")

# Process the augmented grayscale dataset (crop mouth, resize, normalize)
for word_dir in os.listdir(augmented_gray_frames_folder):
    word_frame_dir = os.path.join(augmented_gray_frames_folder, word_dir)
    output_dir = os.path.join(augmented_gray_output_folder, word_dir)  # Output folder for augmented grayscale dataset
    print(f"Processing {word_dir} from augmented grayscale dataset...")
    process_frames_for_feature_extraction(word_frame_dir, output_dir, target_size=(128, 128))

print("\nMouth cropping, resizing (128x128), and normalization complete for augmented datasets!")
# Out:
# Processing Bat from original grayscale dataset...
# Processing Big from original grayscale dataset...
# Processing Book from original grayscale dataset...
# Processing Car from original grayscale dataset...
# Processing Cat from original grayscale dataset...
# Processing Cup from original grayscale dataset...
# Processing Dog from original grayscale dataset...
# Processing Drop from original grayscale dataset...
# Processing Eat from original grayscale dataset...
# Processing Fast from original grayscale dataset...
# Processing Fish from original grayscale dataset...
# Processing Fun from original grayscale dataset...
# Processing Go from original grayscale dataset...
# Processing Hat from original grayscale dataset...
# Processing Hot from original grayscale dataset...
# Processing Jump from original grayscale dataset...
# Processing Kick from original grayscale dataset...
# Processing Leg from original grayscale dataset...
# Processing Milk from original grayscale dataset...
# Processing No from original grayscale dataset...
# Processing Pen from original grayscale dataset...
# Processing Pick from original grayscale dataset...
# Processing Red from original grayscale dataset...
# Processing Run from original grayscale dataset...
# Processing Sit from original grayscale dataset...
# Processing Stop from original grayscale dataset...
# Processing Sun from original grayscale dataset...
# Processing Top from original grayscale dataset...
# Processing Win from original grayscale dataset...
# Processing Yes from original grayscale dataset...
#
# Mouth cropping, resizing (128x128), and normalization complete for original datasets!
#
# Processing Bat from augmented grayscale dataset...
# Processing Big from augmented grayscale dataset...
# Processing Book from augmented grayscale dataset...
# Processing Car from augmented grayscale dataset...
# Processing Cat from augmented grayscale dataset...
# Processing Cup from augmented grayscale dataset...
# Processing Dog from augmented grayscale dataset...
# Processing Drop from augmented grayscale dataset...
# Processing Eat from augmented grayscale dataset...
# Processing Fast from augmented grayscale dataset...
# Processing Fish from augmented grayscale dataset...
# Processing Fun from augmented grayscale dataset...
# Processing Go from augmented grayscale dataset...
# Processing Hat from augmented grayscale dataset...
# Processing Hot from augmented grayscale dataset...
# Processing Jump from augmented grayscale dataset...
# Processing Kick from augmented grayscale dataset...
# Processing Leg from augmented grayscale dataset...
# Processing Milk from augmented grayscale dataset...
# Processing No from augmented grayscale dataset...
# Processing Pen from augmented grayscale dataset...
# Processing Pick from augmented grayscale dataset...
# Processing Red from augmented grayscale dataset...
# Processing Run from augmented grayscale dataset...
# Processing Sit from augmented grayscale dataset...
# Processing Stop from augmented grayscale dataset...
# Processing Sun from augmented grayscale dataset...
# Processing Top from augmented grayscale dataset...
# Processing Win from augmented grayscale dataset...
# Processing Yes from augmented grayscale dataset...
#
# Mouth cropping, resizing (128x128), and normalization complete for augmented datasets!

# %% [markdown]
# 4. feature extraction using 3DCNN, 2DCNN and 2DRESNET. New 2DCNN is used to connect output of 3DCNN and input of 2DRESNET

# %%
# Define the 3D-CNN layer for spatio-temporal feature extraction
def build_3d_cnn(input_shape):
    input_3d = layers.Input(shape=input_shape)
    x = layers.Conv3D(32, (3, 3, 3), activation='relu')(input_3d)
    x = layers.MaxPooling3D(pool_size=(2, 2, 2))(x)

    x = layers.Conv3D(64, (3, 3, 3), activation='relu')(x)
    x = layers.MaxPooling3D(pool_size=(2, 2, 2))(x)

    x = layers.Conv3D(128, (3, 3, 3), activation='relu')(x)
    x = layers.MaxPooling3D(pool_size=(2, 2, 2))(x)

    x = layers.Flatten()(x)
    model = models.Model(inputs=input_3d, outputs=x)
    return model

# Define the 2D ResNet model for spatial refinement
def build_2d_resnet(input_shape):
    resnet = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(input_shape[0], input_shape[1], 3))
    for layer in resnet.layers:
        layer.trainable = False
    return resnet

# Helper function to find factors
def find_factors(n):
    factors = [(i, n // i) for i in range(1, int(n**0.5) + 1) if n % i == 0]
    return factors[-1]  # Get the largest factors that multiply to n

# Define the combined end-to-end model (3D-CNN + ResNet)
def build_combined_model(input_shape_3d, input_shape_2d, num_classes=30):
    input_3d = layers.Input(shape=input_shape_3d)
    cnn_3d = build_3d_cnn(input_shape_3d)(input_3d)

    # Calculate a suitable reshaped size for ResNet
    flattened_size = cnn_3d.shape[1]
    reshaped_height, reshaped_width = find_factors(flattened_size)

    # Define the reshaped size
    reshaped_size = (reshaped_height, reshaped_width, -1)
    reshaped_features = layers.Reshape(reshaped_size)(cnn_3d)

    # Convert the reshaped features to 3 channels for compatibility with ResNet
    reshaped_features = layers.Conv2D(3, (1, 1), padding='same', activation='relu')(reshaped_features)

    # Apply ResNet to the reshaped features
    resnet = build_2d_resnet((reshaped_height, reshaped_width, 3))
    refined_features = resnet(reshaped_features)

    # Global Average Pooling
    pooling = layers.GlobalAveragePooling2D()(refined_features)

    # Final output layer (classification layer with softmax activation)
    output = layers.Dense(num_classes, activation='softmax')(pooling)

    # Build the full model
    model = models.Model(inputs=input_3d, outputs=output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# Example usage:
input_shape_3d = (60, 128, 128, 1)  # 60 frames, 128x128, 1 channel (grayscale)
input_shape_2d = (128, 128, 1)      # Each frame is 128x128, 1 channel

# Build the combined model
model = build_combined_model(input_shape_3d, input_shape_2d, num_classes=30)

# Print model summary to understand the architecture
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_30 (InputLayer)     │ (None, 60, 128, 128,   │             0 │
# │                                 │ 1)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_21 (Functional)      │ (None, 125440)         │       277,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_15 (Reshape)            │ (None, 320, 392, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 320, 392, 3)    │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 10, 13, 2048)   │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 30)             │        61,470 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,926,756 (91.27 MB)
#  Trainable params: 339,044 (1.29 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# 4. feature extraction using 3DCNN and EfficientNet.

# %%
# Define the 3D-CNN layer for spatio-temporal feature extraction
def build_3d_cnn(input_shape):
    """
    This function builds a 3D CNN model for capturing spatio-temporal features
    from a sequence of video frames (e.g., lip movements over time).
    """
    model = models.Sequential()

    # 3D convolutional layer with 32 filters, (3x3x3) kernel size
    model.add(layers.Conv3D(32, (3, 3, 3), activation='relu', input_shape=input_shape))

    # MaxPooling3D layer to downsample the input after the convolution
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))

    # Second 3D convolutional layer with 64 filters
    model.add(layers.Conv3D(64, (3, 3, 3), activation='relu'))

    # Another MaxPooling3D layer to further downsample the features
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))

    # Third 3D convolutional layer with 128 filters
    model.add(layers.Conv3D(128, (3, 3, 3), activation='relu'))

    # MaxPooling again to reduce the spatial and temporal dimensions
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))

    # Flatten the output to feed it into the next stage (EfficientNet)
    model.add(layers.Flatten())

    return model

# Define the EfficientNet model for spatial refinement
def build_efficientnet(input_shape):
    """
    This function creates an EfficientNetB0 model for refining spatial features.
    """
    # Pre-trained EfficientNetB0 model (on ImageNet), without the top (final classification layers)
    efficientnet_model = efficientnet.EfficientNetB0(
        weights='imagenet', include_top=False, input_shape=input_shape
    )

    # Freeze all layers initially (for fine-tuning later)
    for layer in efficientnet_model.layers:
        layer.trainable = False

    return efficientnet_model

# Define the combined end-to-end model (3D-CNN + EfficientNet)
def build_combined_model(input_shape_3d, input_shape_2d, num_classes):
    """
    This function builds an end-to-end model that first applies 3D-CNN for spatio-temporal feature extraction,
    then uses EfficientNet for spatial refinement, and finally includes a classification layer.
    """
    # 3D-CNN Input Layer (for the sequence of frames)
    input_3d = layers.Input(shape=input_shape_3d)

    # Apply the 3D-CNN to the input sequence of frames
    cnn_3d = build_3d_cnn(input_shape_3d)(input_3d)

    # Dense layer to reduce the size for compatibility with EfficientNet input
    dense_features = layers.Dense(input_shape_2d[0] * input_shape_2d[1] * input_shape_2d[2], activation='relu')(cnn_3d)
    reshaped_features = layers.Reshape(input_shape_2d)(dense_features)

    # 2D EfficientNet (Refines spatial features of individual frames)
    efficientnet_model = build_efficientnet(input_shape_2d)

    # Apply EfficientNet to the reshaped features
    refined_features = efficientnet_model(reshaped_features)

    # Global Average Pooling (reduces the feature map size by averaging)
    pooling = layers.GlobalAveragePooling2D()(refined_features)

    # Final output layer (classification layer with softmax activation for word classification)
    output = layers.Dense(num_classes, activation='softmax')(pooling)  # Assuming 30 classes (words)

    # Build the full model (from input_3d to output)
    model = models.Model(inputs=input_3d, outputs=output)

    # Compile the model with Adam optimizer and categorical crossentropy loss
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# Example usage:
# 3D input shape: 60 frames, each frame is 128x128, with 1 channel (grayscale)
input_shape_3d = (60, 128, 128, 1)

# 2D input shape: Each frame is resized to be compatible with EfficientNet input (32x32)
input_shape_2d = (32, 32, 3)

# Build the combined model with EfficientNet
model = build_combined_model(input_shape_3d, input_shape_2d, num_classes=30)

# Print model summary to understand the architecture
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional_44"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_37 (InputLayer)     │ (None, 60, 128, 128,   │             0 │
# │                                 │ 1)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_3 (Sequential)       │ (None, 125440)         │       277,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3072)           │   385,354,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_17 (Reshape)            │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 1, 1, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 30)             │        38,430 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 389,720,321 (1.45 GB)
#  Trainable params: 385,670,750 (1.44 GB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %% [markdown]
# 4. Saving the last model in .h5 format

# %%
# Save the model as a .h5 file
model.save('feature_extraction_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# 4. Performing Data Preparation means building training, validation and test dataset
